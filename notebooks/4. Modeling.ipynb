# %% [markdown]
# <a href="https://colab.research.google.com/github/truc-nmt/tiki_discount_rate/blob/main/notebooks/4.%20Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 4: Modeling - TrucNMT**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install dill catboost xgboost

# %%
import os
import sys
import pandas as pd
import numpy as np
from dataclasses import dataclass

# Packages for logger
import logging
from datetime import datetime

# Packages for model evaluation
import dill
import pickle
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GridSearchCV, train_test_split


# Packages for data transformation
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder

# Packages for model trainer
from catboost import CatBoostRegressor
from sklearn.ensemble import (
    AdaBoostRegressor,
    GradientBoostingRegressor,
    RandomForestRegressor
)

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score, f1_score, recall_score, precision_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %% [markdown]
# ## **Logger**

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
logs_path = os.path.join(os.getcwd(), "logs", LOG_FILE)
os.makedirs(logs_path, exist_ok=True)

LOG_FILE_PATH = os.path.join(logs_path, LOG_FILE)

logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(lineno)d %(name)s - %(levelname)s - %(message)s",
    level=logging.INFO,
)

# %% [markdown]
# ## **Exception**

# %%
def error_message_detail(error, error_detail:sys):

    _, _, exc_tb = error_detail.exc_info()          # Get info about traceback(Info about error position)
    file_name = exc_tb.tb_frame.f_code.co_filename  # Get name of file script Python from "exc_tb"
    error_message="Error occured in python script name [{0}] line number [{1}] error message[{2}]".format(
    file_name,exc_tb.tb_lineno,str(error))

    return error_message


class CustomException(Exception):

    def __init__(self, error_message, error_detail:sys):
        super().__init__(error_message)
        self.error_message = error_message_detail(error_message, error_detail=error_detail)

    def __str__(self):
        return self.error_message

# %% [markdown]
# ## **Utils**

# %%
def save_object(file_path, obj):
    try:
        dir_path = os.path.dirname(file_path) #  is used to get the directory path of the file_path.
        os.makedirs(dir_path, exist_ok=True)

        with open(file_path, "wb") as file_obj:
            pickle.dump(obj, file_obj)

    except Exception as e:
        raise CustomException(e, sys)


def load_object(file_path):
    try:
        with open(file_path, "rb") as file_obj:
            return pickle.load(file_obj)

    except Exception as e:
        raise CustomException(e, sys)

def evaluate_models(X_train, y_train, X_test, y_test, models, param):
    try:
        report = {}

        for model_name, model in models.items():
            para = param[model_name]

            gs = GridSearchCV(model, para, cv=3)
            gs.fit(X_train, y_train)

            model.set_params(**gs.best_params_)
            model.fit(X_train, y_train)

            y_train_pred = model.predict(X_train)
            y_test_pred = model.predict(X_test)

            train_r2_score = r2_score(y_train, y_train_pred)
            test_r2_score = r2_score(y_test, y_test_pred)
            mse = mean_squared_error(y_test, y_test_pred)
            mae = mean_absolute_error(y_test, y_test_pred)

            report[model_name] = (train_r2_score, test_r2_score, mse, mae)

        return report

    except Exception as e:
        raise CustomException(e, sys)

# %% [markdown]
# ##**1. Data Ingestion**

# %%
@dataclass
class DataIngestionConfig:
    train_path: str = os.path.join('/content/data', 'train.csv')
    test_path: str = os.path.join('/content/data', 'test.csv')
    raw_path: str = os.path.join('/content/data', 'raw.csv')

class DataIngestion:

    def __init__(self):
        self.ingestion_config = DataIngestionConfig()

    def initiate_data_ingestion(self):
        logging.info("Entered the data ingestion method or component")

        try:
            df = pd.read_csv('/content/Data_Tiki_Cleaned.csv')
            logging.info("Read the dataset as dataframe")

            os.makedirs(os.path.dirname(self.ingestion_config.train_path), exist_ok= True)

            df.to_csv(self.ingestion_config.raw_path, index = False, header = True)

            logging.info("Train test split initiated")

            # Make dataset
            train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
            train_set.to_csv(self.ingestion_config.train_path, index = False, header = True)
            test_set.to_csv(self.ingestion_config.test_path, index = False, header = True)


            logging.info("Data Ingestion Completed!")

            return(
                self.ingestion_config.train_path,
                self.ingestion_config.test_path,
            )

        except Exception as e:
            raise CustomException(e, sys)

# %% [markdown]
# ##**2. Data Transformation**

# %%
class MultiColumnLabelEncoder:

    def __init__(self, columns=None):
        self.columns = columns if columns else []

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_ = X.copy()
        for col in self.columns:
            le = LabelEncoder()
            X_[col] = le.fit_transform(X_[col])
        return X_

    def fit_transform(self, X, y=None):
        return self.fit(X).transform(X)

@dataclass
class DataTransformationConfig:
    preprocessor_obj_file_path = os.path.join("data", "preprocessor.pkl")

class DataTransformation:

    def __init__(self):
        self.data_transformation_config = DataTransformationConfig()

    def get_data_transformation_object(self):
        '''

        This function is responsible for data transformation

        '''

        '''
            Information of columns data types after cleaned and filled null values!
            RangeIndex: 1916 entries, 0 to 1915
            Data columns (total 24 columns):
            #   Column             Non-Null Count  Dtype
            ---  ------             --------------  -----
            0   Name               1916 non-null   object
            1   Link Product       1916 non-null   object
            2   Store              1916 non-null   object
            3   Type               1916 non-null   object
            4   Author Name        1916 non-null   object
            5   Short Description  1916 non-null   object
            6   Publisher          1916 non-null   object
            7   Translators        1916 non-null   object
            8   Categories         1916 non-null   object
            9   Width              1916 non-null   float64
            10  Length             1916 non-null   float64
            11  Height             1916 non-null   float64
            12  Product ID         1916 non-null   int64
            13  Price              1916 non-null   int64
            14  Original Price     1916 non-null   int64
            15  Discount           1916 non-null   int64
            16  Discount Rate      1916 non-null   int64
            17  Rating             1916 non-null   float64
            18  Review Count       1916 non-null   int64
            19  Quantity Sold      1916 non-null   float64
            20  Number of page     1916 non-null   float64
            21  Range Price        1916 non-null   object
            22  Publication Date   1916 non-null   object
            23  Publication Year   1916 non-null   float64
            dtypes: float64(7), int64(6), object(11)
        '''
        try:

            # numerical_columns = df.select_dtypes(include=['number']).columns.tolist()

            numerical_columns = [
                                'Width',
                                'Length',
                                'Height',
                                'Product_ID',
                                'Price',
                                'Original_Price',
                                'Discount',
                                # 'Discount_Rate', # target
                                'Rating',
                                'Review_Count',
                                'Quantity_Sold',
                                'Number_of_page',
                                'Publication_Year'
                                ]
            # categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
            categorical_columns = [
                                'Store',
                                'Type',
                                'Author_Name',
                                'Publisher',
                                'Translators',
                                'Categories',
                                'Range_Price',
                            ]

            # Pipeline

            num_pipeline = Pipeline(
                steps = [
                    # ("imputer", SimpleImputer(strategy="median")),
                    ("scaler", StandardScaler())
                ]
            )

            cate_pipeline = Pipeline(
                steps=[
                    ("label_encoder", MultiColumnLabelEncoder(columns=categorical_columns)),
                    ("scaler", StandardScaler(with_mean=False))
                ]
            )

            # Log info

            logging.info(f"Categorical columns: {categorical_columns}")
            logging.info(f"Numerical columns: {numerical_columns}")

            # Preprocessor

            preprocessor = ColumnTransformer(
                [
                    ("num_pipeline", num_pipeline, numerical_columns),
                    ("cate_pipeline", cate_pipeline, categorical_columns),
                ]
            )

            return preprocessor

        except Exception as e:
            raise CustomException(e, sys)

    def initiate_data_transformation(self, train_path, test_path):

        try:
            train_df = pd.read_csv(train_path)
            test_df = pd.read_csv(test_path)

            # print(train_df.columns)
            # print(test_df.columns)

            logging.info("read train and test data completed!")
            logging.info("Obtaining preprocessing object")

            preprocessing_obj = self.get_data_transformation_object()

            target_column_name = "Discount_Rate"
            numerical_columns = train_df.select_dtypes(include=['number']).columns.tolist()
            # print(numerical_columns)


            input_feature_train_df = train_df.drop(columns=[target_column_name], axis = 1)
            # print(input_feature_train_df.info)
            target_feature_train_df = train_df[target_column_name]

            input_feature_test_df = test_df.drop(columns=[target_column_name], axis = 1)
            target_feature_test_df = test_df[target_column_name]

            logging.info(f"Applying preprocessing object on training dataframe and testing dataframe")

            input_feature_train_arr = preprocessing_obj.fit_transform(input_feature_train_df)
            input_feature_test_arr = preprocessing_obj.transform(input_feature_test_df)

            train_arr = np.c_[input_feature_train_arr, np.array(target_feature_train_df)]
            test_arr = np.c_[input_feature_test_arr, np.array(target_feature_test_df)]

            logging.info(f"Saved preprocessing object.")

            save_object(
                file_path= self.data_transformation_config.preprocessor_obj_file_path,
                obj=preprocessing_obj
            )

            return(train_arr, test_arr, self.data_transformation_config.preprocessor_obj_file_path)

        except Exception as e:
            raise CustomException(e, sys)

# %% [markdown]
# ##**3. Model Trainer**

# %%
@dataclass
class ModelTrainerConfig:
    train_model_file_path = os.path.join("models", "model.pkl")


class ModelTrainer:

    def __init__(self):
        self.model_trainer_config = ModelTrainerConfig()


    def initiate_model_trainer(self, train_array, test_array):
        try:
            logging.info("Splitting training and test input data")
            X_train, y_train, X_test, y_test = (
                train_array[:, :-1],
                train_array[:, -1],
                test_array[:, :-1],
                test_array[:, -1]
            )

            models = {
                "Random Forest": RandomForestRegressor(),
                "Decision Tree": DecisionTreeRegressor(),
                "Gradient Boosting": GradientBoostingRegressor(),
                "Linear Regression": LinearRegression(),
                "XGBRegressor": XGBRegressor(),
                "CatBoosting Regressor": CatBoostRegressor(verbose=True),
                "AdaBoost Regressor": AdaBoostRegressor(),
            }

            # Fine-tune Hyper Parameter
            params = {
                "Decision Tree": {
                    'criterion': ['poisson', 'absolute_error', 'friedman_mse', 'squared_error'],
                    'splitter': ['best', 'random'],
                    'max_features': ['sqrt', 'log2'],
                },
                "Random Forest": {
                    'criterion': ['squared_error', 'friedman_mse', 'poisson', 'absolute_error'],
                    'max_features': ['sqrt', 'log2', None],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                },
                "Gradient Boosting": {
                    'loss': ['squared_error', 'absolute_error', 'quantile', 'huber'],
                    'learning_rate': [0.1, 0.01, 0.05, 0.001],
                    'subsample': [0.6, 0.7, 0.75, 0.8, 0.85, 0.9],
                    'max_features': ['sqrt', 'log2'],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                },
                "Linear Regression": {},
                "XGBRegressor": {
                    'learning_rate': [0.1, 0.01, 0.05, 0.001],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                },
                "CatBoosting Regressor": {
                    'depth': [6, 8, 10],
                    'learning_rate': [0.01, 0.05, 0.1],
                    'iterations': [30, 50, 100]
                },
                "AdaBoost Regressor": {
                    'learning_rate': [0.1, 0.01, 0.5, 0.001],
                    'loss': ['linear', 'square', 'exponential'],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                }
            }

            model_report = evaluate_models(X_train, y_train, X_test, y_test, models, params)

            # Print all model results
            logging.info("Model results:")

            model_results_df = self.create_dataframe_from_results(model_report)
            print(model_results_df)

            # Find the best model based on test R2 score
            best_model_name = max(model_report, key=lambda k: model_report[k][1])  # Choose based on test R2 score
            best_model_scores = model_report[best_model_name]

            # Check if the test R2 score of the best model meets the threshold
            if best_model_scores[1] < 0.6:
                raise CustomException("No best model found")

            # Retrieve the best model
            best_model = models[best_model_name]

            # Save the best model
            save_object(file_path=self.model_trainer_config.train_model_file_path, obj=best_model)

            # Return the test R2 score, MSE, and MAE of the best model
            print("Final Best Model after Fine-tune with Hyper Paramaters")
            return best_model_scores[0], best_model_scores[1], best_model_scores[2], best_model_scores[3]

        except Exception as e:
            raise CustomException(e, sys)

    def create_dataframe_from_results(self, model_report):
      data = []
      for model_name, scores in model_report.items():
          logging.info(f"{model_name}: Train R2 Score - {scores[0]}, Test R2 Score - {scores[1]}, MSE - {scores[2]}, MAE - {scores[3]}") # Save in log file
          data.append([model_name, scores[0], scores[1], scores[2], scores[3]])
      df = pd.DataFrame(data, columns=['Model', 'Train R2 Score', 'Test R2 Score', 'MSE', 'MAE'])
      return df

# %% [markdown]
# ## **4. Results**

# %%
obj = DataIngestion()
train_data, test_data = obj.initiate_data_ingestion()

data_transformation = DataTransformation()
train_arr, test_arr, _ = data_transformation.initiate_data_transformation(train_data, test_data)

modeltrainer = ModelTrainer()
print(modeltrainer.initiate_model_trainer(train_arr, test_arr))
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# 10:	learn: 11.4946196	total: 52ms	remaining: 89.9ms
# 11:	learn: 11.4207493	total: 55.7ms	remaining: 83.6ms
# 12:	learn: 11.3461089	total: 62.2ms	remaining: 81.4ms
# 13:	learn: 11.2666259	total: 75ms	remaining: 85.7ms
# 14:	learn: 11.1885251	total: 78.6ms	remaining: 78.6ms
# 15:	learn: 11.1209663	total: 82.2ms	remaining: 72ms
# 16:	learn: 11.0508081	total: 85.1ms	remaining: 65.1ms
# 17:	learn: 10.9822952	total: 88.2ms	remaining: 58.8ms
# 18:	learn: 10.9096954	total: 93.3ms	remaining: 54ms
# 19:	learn: 10.8414087	total: 99.6ms	remaining: 49.8ms
# 20:	learn: 10.7837768	total: 105ms	remaining: 45.1ms
# 21:	learn: 10.7162213	total: 111ms	remaining: 40.4ms
# 22:	learn: 10.6542976	total: 116ms	remaining: 35.4ms
# 23:	learn: 10.5938525	total: 121ms	remaining: 30.2ms
# 24:	learn: 10.5250411	total: 129ms	remaining: 25.8ms
# 25:	learn: 10.4568657	total: 137ms	remaining: 21ms
# 26:	learn: 10.3955711	total: 147ms	remaining: 16.3ms
# 27:	learn: 10.3337178	total: 153ms	remaining: 10.9ms
# 28:	learn: 10.2678682	total: 157ms	remaining: 5.41ms
# 29:	learn: 10.2094397	total: 161ms	remaining: 0us
# 0:	learn: 11.7371678	total: 5.12ms	remaining: 148ms
# 1:	learn: 11.4249029	total: 10.7ms	remaining: 150ms
# 2:	learn: 11.1255478	total: 15.6ms	remaining: 140ms
# 3:	learn: 10.7830159	total: 19.1ms	remaining: 124ms
# 4:	learn: 10.4746286	total: 23.5ms	remaining: 117ms
# 5:	learn: 10.1815730	total: 27.5ms	remaining: 110ms
# 6:	learn: 9.9226266	total: 33.2ms	remaining: 109ms
# 7:	learn: 9.6279769	total: 42.3ms	remaining: 116ms
# 8:	learn: 9.3410207	total: 53ms	remaining: 124ms
# 9:	learn: 9.1005872	total: 62.4ms	remaining: 125ms
# 10:	learn: 8.8600093	total: 68.7ms	remaining: 119ms
# 11:	learn: 8.6417687	total: 75.3ms	remaining: 113ms
# 12:	learn: 8.4021775	total: 82.3ms	remaining: 108ms
# 13:	learn: 8.1402440	total: 87.8ms	remaining: 100ms
# 14:	learn: 7.9172339	total: 91.5ms	remaining: 91.5ms
# 15:	learn: 7.7096108	total: 96.2ms	remaining: 84.2ms
# 16:	learn: 7.5069440	total: 107ms	remaining: 82ms
# 17:	learn: 7.3323124	total: 115ms	remaining: 76.5ms
# 18:	learn: 7.1727287	total: 119ms	remaining: 69.1ms
# 19:	learn: 6.9910156	total: 125ms	remaining: 62.4ms
# 20:	learn: 6.8637840	total: 137ms	remaining: 58.9ms
# 21:	learn: 6.7041921	total: 149ms	remaining: 54.2ms
# 22:	learn: 6.5773906	total: 158ms	remaining: 48ms
# 23:	learn: 6.4539426	total: 167ms	remaining: 41.8ms
# 24:	learn: 6.3011132	total: 178ms	remaining: 35.5ms
# 25:	learn: 6.1992023	total: 185ms	remaining: 28.5ms
# 26:	learn: 6.0862278	total: 196ms	remaining: 21.8ms
# 27:	learn: 5.9580580	total: 206ms	remaining: 14.7ms
# 28:	learn: 5.8214915	total: 215ms	remaining: 7.41ms
# 29:	learn: 5.6930476	total: 222ms	remaining: 0us
# 0:	learn: 11.7887853	total: 5.02ms	remaining: 146ms
# 1:	learn: 11.4084316	total: 12ms	remaining: 169ms
# 2:	learn: 11.1177022	total: 17.7ms	remaining: 159ms
# 3:	learn: 10.8110105	total: 26.5ms	remaining: 172ms
# 4:	learn: 10.4882965	total: 35.1ms	remaining: 176ms
# 5:	learn: 10.1995189	total: 43.9ms	remaining: 176ms
# 6:	learn: 9.9339889	total: 56.3ms	remaining: 185ms
# 7:	learn: 9.6349820	total: 65.9ms	remaining: 181ms
# 8:	learn: 9.3403122	total: 72ms	remaining: 168ms
# 9:	learn: 9.0948843	total: 80.5ms	remaining: 161ms
# 10:	learn: 8.8469038	total: 89.8ms	remaining: 155ms
# 11:	learn: 8.6140906	total: 99.8ms	remaining: 150ms
# 12:	learn: 8.3787208	total: 108ms	remaining: 142ms
# 13:	learn: 8.1270282	total: 119ms	remaining: 135ms
# 14:	learn: 7.8916450	total: 127ms	remaining: 127ms
# 15:	learn: 7.6699679	total: 137ms	remaining: 120ms
# 16:	learn: 7.4587531	total: 146ms	remaining: 112ms
# 17:	learn: 7.2695922	total: 156ms	remaining: 104ms
# 18:	learn: 7.0911534	total: 170ms	remaining: 98.3ms
# 19:	learn: 6.9403145	total: 179ms	remaining: 89.4ms
# 20:	learn: 6.7978286	total: 194ms	remaining: 83.3ms
# 21:	learn: 6.6818708	total: 199ms	remaining: 72.5ms
# 22:	learn: 6.5598187	total: 207ms	remaining: 62.9ms
# 23:	learn: 6.4164870	total: 215ms	remaining: 53.8ms
# 24:	learn: 6.3093439	total: 221ms	remaining: 44.2ms
# 25:	learn: 6.1923230	total: 229ms	remaining: 35.2ms
# 26:	learn: 6.0408143	total: 236ms	remaining: 26.2ms
# 27:	learn: 5.9315947	total: 244ms	remaining: 17.4ms
# 28:	learn: 5.8108461	total: 253ms	remaining: 8.72ms
# 29:	learn: 5.6661036	total: 261ms	remaining: 0us
# 0:	learn: 11.9262218	total: 8.34ms	remaining: 242ms
# 1:	learn: 11.5410284	total: 15.1ms	remaining: 211ms
# 2:	learn: 11.2162597	total: 20.4ms	remaining: 183ms
# 3:	learn: 10.8592516	total: 24ms	remaining: 156ms
# 4:	learn: 10.5250672	total: 31.4ms	remaining: 157ms
# 5:	learn: 10.2643689	total: 37.1ms	remaining: 149ms
# 6:	learn: 9.9936870	total: 42ms	remaining: 138ms
# 7:	learn: 9.6832311	total: 46.5ms	remaining: 128ms
# 8:	learn: 9.4134625	total: 51.6ms	remaining: 120ms
# 9:	learn: 9.1591485	total: 56ms	remaining: 112ms
# 10:	learn: 8.9008568	total: 59ms	remaining: 102ms
# 11:	learn: 8.6623901	total: 63.4ms	remaining: 95.2ms
# 12:	learn: 8.4095659	total: 70.7ms	remaining: 92.5ms
# 13:	learn: 8.1444580	total: 77.8ms	remaining: 88.9ms
# 14:	learn: 7.9132616	total: 86.5ms	remaining: 86.5ms
# 15:	learn: 7.7263389	total: 93.6ms	remaining: 81.9ms
# 16:	learn: 7.5375652	total: 101ms	remaining: 76.9ms
# 17:	learn: 7.3497801	total: 109ms	remaining: 72.8ms
# 18:	learn: 7.1481795	total: 120ms	remaining: 69.3ms
# 19:	learn: 6.9731763	total: 127ms	remaining: 63.6ms
# 20:	learn: 6.8453100	total: 135ms	remaining: 57.8ms
# 21:	learn: 6.6764946	total: 144ms	remaining: 52.5ms
# 22:	learn: 6.5442900	total: 151ms	remaining: 46ms
# 23:	learn: 6.3783528	total: 159ms	remaining: 39.8ms
# 24:	learn: 6.2399800	total: 167ms	remaining: 33.5ms
# 25:	learn: 6.1100955	total: 176ms	remaining: 27.1ms
# 26:	learn: 5.9911095	total: 186ms	remaining: 20.7ms
# 27:	learn: 5.8734647	total: 193ms	remaining: 13.8ms
# 28:	learn: 5.7489487	total: 202ms	remaining: 6.95ms
# 29:	learn: 5.6197717	total: 210ms	remaining: 0us
# 0:	learn: 11.3553705	total: 8.72ms	remaining: 253ms
# 1:	learn: 10.7727863	total: 17.4ms	remaining: 244ms
# 2:	learn: 10.2425768	total: 26.3ms	remaining: 237ms
# 3:	learn: 9.6400848	total: 36.5ms	remaining: 237ms
# 4:	learn: 9.1411460	total: 45.4ms	remaining: 227ms
# 5:	learn: 8.6871315	total: 51.9ms	remaining: 207ms
# 6:	learn: 8.3131782	total: 59.3ms	remaining: 195ms
# 7:	learn: 7.8670826	total: 68.3ms	remaining: 188ms
# 8:	learn: 7.5010069	total: 73.4ms	remaining: 171ms
# 9:	learn: 7.1843051	total: 80.9ms	remaining: 162ms
# 10:	learn: 6.9251572	total: 93.4ms	remaining: 161ms
# 11:	learn: 6.6599581	total: 98.4ms	remaining: 148ms
# 12:	learn: 6.3624899	total: 104ms	remaining: 136ms
# 13:	learn: 6.0539288	total: 108ms	remaining: 124ms
# 14:	learn: 5.7690878	total: 114ms	remaining: 114ms
# 15:	learn: 5.5587055	total: 118ms	remaining: 103ms
# 16:	learn: 5.3336201	total: 122ms	remaining: 93.3ms
# 17:	learn: 5.1402284	total: 127ms	remaining: 84.8ms
# 18:	learn: 4.9690087	total: 136ms	remaining: 78.4ms
# 19:	learn: 4.8262016	total: 144ms	remaining: 72.2ms
# 20:	learn: 4.7255142	total: 154ms	remaining: 65.8ms
# 21:	learn: 4.5957024	total: 163ms	remaining: 59.4ms
# 22:	learn: 4.4880693	total: 169ms	remaining: 51.5ms
# 23:	learn: 4.3995372	total: 176ms	remaining: 43.9ms
# 24:	learn: 4.2913804	total: 182ms	remaining: 36.4ms
# 25:	learn: 4.1886451	total: 188ms	remaining: 28.9ms
# 26:	learn: 4.1193525	total: 195ms	remaining: 21.6ms
# 27:	learn: 4.0066093	total: 205ms	remaining: 14.6ms
# 28:	learn: 3.9017326	total: 211ms	remaining: 7.29ms
# 29:	learn: 3.7851406	total: 219ms	remaining: 0us
# 0:	learn: 11.4211024	total: 9.97ms	remaining: 289ms
# 1:	learn: 10.6980587	total: 22.1ms	remaining: 309ms
# 2:	learn: 10.1778914	total: 29.2ms	remaining: 263ms
# 3:	learn: 9.5669097	total: 33ms	remaining: 214ms
# 4:	learn: 9.0402591	total: 37ms	remaining: 185ms
# 5:	learn: 8.5351592	total: 41.9ms	remaining: 168ms
# 6:	learn: 8.1500808	total: 49.4ms	remaining: 162ms
# 7:	learn: 7.7125359	total: 55.8ms	remaining: 153ms
# 8:	learn: 7.3056745	total: 60.1ms	remaining: 140ms
# 9:	learn: 7.0012815	total: 66.9ms	remaining: 134ms
# 10:	learn: 6.6799951	total: 78ms	remaining: 135ms
# 11:	learn: 6.4134038	total: 85.9ms	remaining: 129ms
# 12:	learn: 6.1325495	total: 93.2ms	remaining: 122ms
# 13:	learn: 5.8293081	total: 102ms	remaining: 116ms
# 14:	learn: 5.6035109	total: 110ms	remaining: 110ms
# 15:	learn: 5.4180202	total: 123ms	remaining: 108ms
# 16:	learn: 5.2247342	total: 131ms	remaining: 99.9ms
# 17:	learn: 5.0468601	total: 140ms	remaining: 93.4ms
# 18:	learn: 4.8909254	total: 149ms	remaining: 86.4ms
# 19:	learn: 4.6817153	total: 159ms	remaining: 79.4ms
# 20:	learn: 4.5836675	total: 166ms	remaining: 71.3ms
# 21:	learn: 4.3961353	total: 175ms	remaining: 63.5ms
# 22:	learn: 4.2983973	total: 181ms	remaining: 55ms
# 23:	learn: 4.1740758	total: 188ms	remaining: 46.9ms
# 24:	learn: 4.0767632	total: 196ms	remaining: 39.1ms
# 25:	learn: 3.9686340	total: 205ms	remaining: 31.6ms
# 26:	learn: 3.8539033	total: 214ms	remaining: 23.8ms
# 27:	learn: 3.7678156	total: 223ms	remaining: 15.9ms
# 28:	learn: 3.6553975	total: 232ms	remaining: 8ms
# 29:	learn: 3.5509880	total: 242ms	remaining: 0us
# 0:	learn: 11.5346453	total: 8.01ms	remaining: 232ms
# 1:	learn: 10.8050644	total: 14.1ms	remaining: 198ms
# 2:	learn: 10.2269850	total: 29.4ms	remaining: 264ms
# 3:	learn: 9.6058770	total: 33.5ms	remaining: 218ms
# 4:	learn: 9.0683269	total: 37.7ms	remaining: 189ms
# 5:	learn: 8.5863208	total: 41.8ms	remaining: 167ms
# 6:	learn: 8.1906558	total: 45.8ms	remaining: 150ms
# 7:	learn: 7.7583650	total: 50ms	remaining: 137ms
# 8:	learn: 7.3474592	total: 54.3ms	remaining: 127ms
# 9:	learn: 7.0117595	total: 59.8ms	remaining: 120ms
# 10:	learn: 6.6841657	total: 68.1ms	remaining: 118ms
# 11:	learn: 6.3986390	total: 74.1ms	remaining: 111ms
# 12:	learn: 6.0707933	total: 79.4ms	remaining: 104ms
# 13:	learn: 5.7480267	total: 83.9ms	remaining: 95.9ms
# 14:	learn: 5.5112950	total: 88.7ms	remaining: 88.7ms
# 15:	learn: 5.2713682	total: 93.1ms	remaining: 81.5ms
# 16:	learn: 5.0695457	total: 98.1ms	remaining: 75ms
# 17:	learn: 4.8892269	total: 103ms	remaining: 68.4ms
# 18:	learn: 4.7035606	total: 107ms	remaining: 62.1ms
# 19:	learn: 4.5364614	total: 111ms	remaining: 55.4ms
# 20:	learn: 4.4089842	total: 116ms	remaining: 49.9ms
# 21:	learn: 4.2522490	total: 122ms	remaining: 44.5ms
# 22:	learn: 4.1467359	total: 126ms	remaining: 38.4ms
# 23:	learn: 4.0100055	total: 131ms	remaining: 32.7ms
# 24:	learn: 3.9082364	total: 135ms	remaining: 26.9ms
# 25:	learn: 3.7755290	total: 140ms	remaining: 21.6ms
# 26:	learn: 3.6794094	total: 149ms	remaining: 16.6ms
# 27:	learn: 3.6053269	total: 159ms	remaining: 11.4ms
# 28:	learn: 3.5119280	total: 169ms	remaining: 5.82ms
# 29:	learn: 3.4193710	total: 183ms	remaining: 0us
# 0:	learn: 12.0474412	total: 3.42ms	remaining: 168ms
# 1:	learn: 11.9717073	total: 10.7ms	remaining: 257ms
# 2:	learn: 11.9059822	total: 18.2ms	remaining: 285ms
# 3:	learn: 11.8289107	total: 26.1ms	remaining: 300ms
# 4:	learn: 11.7557857	total: 32.2ms	remaining: 290ms
# 5:	learn: 11.6845494	total: 39.4ms	remaining: 289ms
# 6:	learn: 11.6181709	total: 48.3ms	remaining: 297ms
# 7:	learn: 11.5403476	total: 56.9ms	remaining: 299ms
# 8:	learn: 11.4695802	total: 66.3ms	remaining: 302ms
# 9:	learn: 11.4015307	total: 75ms	remaining: 300ms
# 10:	learn: 11.3343708	total: 86.6ms	remaining: 307ms
# 11:	learn: 11.2648526	total: 94.8ms	remaining: 300ms
# 12:	learn: 11.1904938	total: 101ms	remaining: 287ms
# 13:	learn: 11.1149024	total: 106ms	remaining: 273ms
# 14:	learn: 11.0413905	total: 110ms	remaining: 257ms
# 15:	learn: 10.9743156	total: 115ms	remaining: 245ms
# 16:	learn: 10.9066946	total: 125ms	remaining: 243ms
# 17:	learn: 10.8406812	total: 134ms	remaining: 237ms
# 18:	learn: 10.7795569	total: 142ms	remaining: 232ms
# 19:	learn: 10.7188733	total: 153ms	remaining: 229ms
# 20:	learn: 10.6622903	total: 159ms	remaining: 220ms
# 21:	learn: 10.6064787	total: 168ms	remaining: 213ms
# 22:	learn: 10.5482488	total: 176ms	remaining: 207ms
# 23:	learn: 10.4850483	total: 185ms	remaining: 200ms
# 24:	learn: 10.4293920	total: 201ms	remaining: 201ms
# 25:	learn: 10.3637645	total: 210ms	remaining: 193ms
# 26:	learn: 10.3039968	total: 218ms	remaining: 186ms
# 27:	learn: 10.2391840	total: 227ms	remaining: 178ms
# 28:	learn: 10.1844578	total: 235ms	remaining: 170ms
# 29:	learn: 10.1269974	total: 244ms	remaining: 162ms
# 30:	learn: 10.0721983	total: 252ms	remaining: 155ms
# 31:	learn: 10.0174720	total: 261ms	remaining: 147ms
# 32:	learn: 9.9639640	total: 270ms	remaining: 139ms
# 33:	learn: 9.9109616	total: 277ms	remaining: 130ms
# 34:	learn: 9.8483429	total: 286ms	remaining: 123ms
# 35:	learn: 9.7961489	total: 295ms	remaining: 115ms
# 36:	learn: 9.7404011	total: 304ms	remaining: 107ms
# 37:	learn: 9.6847317	total: 313ms	remaining: 98.9ms
# 38:	learn: 9.6277063	total: 322ms	remaining: 90.7ms
# 39:	learn: 9.5708521	total: 331ms	remaining: 82.6ms
# 40:	learn: 9.5141396	total: 339ms	remaining: 74.5ms
# 41:	learn: 9.4626795	total: 349ms	remaining: 66.6ms
# 42:	learn: 9.4136052	total: 354ms	remaining: 57.7ms
# 43:	learn: 9.3557706	total: 363ms	remaining: 49.5ms
# 44:	learn: 9.3017360	total: 372ms	remaining: 41.3ms
# 45:	learn: 9.2464749	total: 382ms	remaining: 33.2ms
# 46:	learn: 9.1933727	total: 397ms	remaining: 25.3ms
# 47:	learn: 9.1429677	total: 404ms	remaining: 16.8ms
# 48:	learn: 9.0898165	total: 414ms	remaining: 8.45ms
# 49:	learn: 9.0317548	total: 426ms	remaining: 0us
# 0:	learn: 12.0876188	total: 3.7ms	remaining: 181ms
# 1:	learn: 12.0101542	total: 9.87ms	remaining: 237ms
# 2:	learn: 11.9462280	total: 20ms	remaining: 313ms
# 3:	learn: 11.8766055	total: 24.9ms	remaining: 286ms
# 4:	learn: 11.7993281	total: 31.4ms	remaining: 283ms
# 5:	learn: 11.7295218	total: 37.4ms	remaining: 274ms
# 6:	learn: 11.6623892	total: 47ms	remaining: 289ms
# 7:	learn: 11.5853543	total: 55.3ms	remaining: 290ms
# 8:	learn: 11.5049736	total: 62.5ms	remaining: 285ms
# 9:	learn: 11.4351770	total: 68.6ms	remaining: 274ms
# 10:	learn: 11.3609023	total: 74.4ms	remaining: 264ms
# 11:	learn: 11.2913618	total: 79.5ms	remaining: 252ms
# 12:	learn: 11.2213774	total: 84.7ms	remaining: 241ms
# 13:	learn: 11.1419547	total: 90.5ms	remaining: 233ms
# 14:	learn: 11.0666027	total: 96.7ms	remaining: 226ms
# 15:	learn: 11.0009093	total: 105ms	remaining: 224ms
# 16:	learn: 10.9378978	total: 111ms	remaining: 216ms
# 17:	learn: 10.8718306	total: 116ms	remaining: 206ms
# 18:	learn: 10.8025223	total: 123ms	remaining: 201ms
# 19:	learn: 10.7360424	total: 133ms	remaining: 200ms
# 20:	learn: 10.6792105	total: 142ms	remaining: 197ms
# 21:	learn: 10.6220447	total: 154ms	remaining: 196ms
# 22:	learn: 10.5552748	total: 165ms	remaining: 194ms
# 23:	learn: 10.4895436	total: 170ms	remaining: 184ms
# 24:	learn: 10.4331873	total: 178ms	remaining: 178ms
# 25:	learn: 10.3688947	total: 188ms	remaining: 173ms
# 26:	learn: 10.3134943	total: 197ms	remaining: 167ms
# 27:	learn: 10.2544168	total: 207ms	remaining: 163ms
# 28:	learn: 10.1934568	total: 215ms	remaining: 156ms
# 29:	learn: 10.1345617	total: 228ms	remaining: 152ms
# 30:	learn: 10.0823560	total: 238ms	remaining: 146ms
# 31:	learn: 10.0236730	total: 247ms	remaining: 139ms
# 32:	learn: 9.9669532	total: 256ms	remaining: 132ms
# 33:	learn: 9.9122968	total: 268ms	remaining: 126ms
# 34:	learn: 9.8490374	total: 278ms	remaining: 119ms
# 35:	learn: 9.7976747	total: 287ms	remaining: 111ms
# 36:	learn: 9.7365266	total: 297ms	remaining: 104ms
# 37:	learn: 9.6808952	total: 307ms	remaining: 96.9ms
# 38:	learn: 9.6215331	total: 315ms	remaining: 89ms
# 39:	learn: 9.5692442	total: 325ms	remaining: 81.2ms
# 40:	learn: 9.5095304	total: 335ms	remaining: 73.5ms
# 41:	learn: 9.4496014	total: 342ms	remaining: 65.2ms
# 42:	learn: 9.3972741	total: 346ms	remaining: 56.3ms
# 43:	learn: 9.3432035	total: 350ms	remaining: 47.8ms
# 44:	learn: 9.2920843	total: 357ms	remaining: 39.7ms
# 45:	learn: 9.2466171	total: 365ms	remaining: 31.7ms
# 46:	learn: 9.1962071	total: 374ms	remaining: 23.9ms
# 47:	learn: 9.1444185	total: 383ms	remaining: 16ms
# 48:	learn: 9.1008643	total: 391ms	remaining: 7.97ms
# 49:	learn: 9.0506506	total: 399ms	remaining: 0us
# 0:	learn: 12.2439202	total: 5.88ms	remaining: 288ms
# 1:	learn: 12.1636759	total: 10.1ms	remaining: 241ms
# 2:	learn: 12.0928441	total: 16.4ms	remaining: 257ms
# 3:	learn: 12.0126725	total: 23.7ms	remaining: 273ms
# 4:	learn: 11.9342153	total: 39.7ms	remaining: 358ms
# 5:	learn: 11.8698934	total: 47.6ms	remaining: 349ms
# 6:	learn: 11.8020036	total: 57ms	remaining: 350ms
# 7:	learn: 11.7200300	total: 69.8ms	remaining: 367ms
# 8:	learn: 11.6383024	total: 79.2ms	remaining: 361ms
# 9:	learn: 11.5660014	total: 89.5ms	remaining: 358ms
# 10:	learn: 11.4946196	total: 96.6ms	remaining: 343ms
# 11:	learn: 11.4207493	total: 104ms	remaining: 330ms
# 12:	learn: 11.3461089	total: 114ms	remaining: 326ms
# 13:	learn: 11.2666259	total: 123ms	remaining: 315ms
# 14:	learn: 11.1885251	total: 133ms	remaining: 311ms
# 15:	learn: 11.1209663	total: 141ms	remaining: 300ms
# 16:	learn: 11.0508081	total: 149ms	remaining: 289ms
# 17:	learn: 10.9822952	total: 159ms	remaining: 283ms
# 18:	learn: 10.9096954	total: 166ms	remaining: 270ms
# 19:	learn: 10.8414087	total: 173ms	remaining: 259ms
# 20:	learn: 10.7837768	total: 181ms	remaining: 250ms
# 21:	learn: 10.7162213	total: 189ms	remaining: 241ms
# 22:	learn: 10.6542976	total: 199ms	remaining: 233ms
# 23:	learn: 10.5938525	total: 206ms	remaining: 224ms
# 24:	learn: 10.5250411	total: 215ms	remaining: 215ms
# 25:	learn: 10.4568657	total: 223ms	remaining: 205ms
# 26:	learn: 10.3955711	total: 238ms	remaining: 203ms
# 27:	learn: 10.3337178	total: 247ms	remaining: 194ms
# 28:	learn: 10.2678682	total: 258ms	remaining: 186ms
# 29:	learn: 10.2094397	total: 265ms	remaining: 177ms
# 30:	learn: 10.1535152	total: 272ms	remaining: 167ms
# 31:	learn: 10.0918472	total: 279ms	remaining: 157ms
# 32:	learn: 10.0302151	total: 287ms	remaining: 148ms
# 33:	learn: 9.9751362	total: 294ms	remaining: 138ms
# 34:	learn: 9.9119890	total: 301ms	remaining: 129ms
# 35:	learn: 9.8552126	total: 308ms	remaining: 120ms
# 36:	learn: 9.7972956	total: 316ms	remaining: 111ms
# 37:	learn: 9.7345926	total: 324ms	remaining: 102ms
# 38:	learn: 9.6764191	total: 331ms	remaining: 93.5ms
# 39:	learn: 9.6186125	total: 340ms	remaining: 84.9ms
# 40:	learn: 9.5592405	total: 350ms	remaining: 76.8ms
# 41:	learn: 9.4993978	total: 357ms	remaining: 68ms
# 42:	learn: 9.4436181	total: 361ms	remaining: 58.7ms
# 43:	learn: 9.3837555	total: 364ms	remaining: 49.7ms
# 44:	learn: 9.3370566	total: 368ms	remaining: 40.9ms
# 45:	learn: 9.2886429	total: 371ms	remaining: 32.3ms
# 46:	learn: 9.2414893	total: 374ms	remaining: 23.9ms
# 47:	learn: 9.1926666	total: 378ms	remaining: 15.7ms
# 48:	learn: 9.1470896	total: 381ms	remaining: 7.78ms
# 49:	learn: 9.0945292	total: 384ms	remaining: 0us
# 0:	learn: 11.7371678	total: 4.39ms	remaining: 215ms
# 1:	learn: 11.4249029	total: 12.9ms	remaining: 310ms
# 2:	learn: 11.1255478	total: 18.5ms	remaining: 290ms
# 3:	learn: 10.7830159	total: 29ms	remaining: 333ms
# 4:	learn: 10.4746286	total: 36ms	remaining: 324ms
# 5:	learn: 10.1815730	total: 39ms	remaining: 286ms
# 6:	learn: 9.9226266	total: 42.2ms	remaining: 259ms
# 7:	learn: 9.6279769	total: 45.5ms	remaining: 239ms
# 8:	learn: 9.3410207	total: 48.7ms	remaining: 222ms
# 9:	learn: 9.1005872	total: 52.1ms	remaining: 208ms
# 10:	learn: 8.8600093	total: 57.8ms	remaining: 205ms
# 11:	learn: 8.6417687	total: 60.8ms	remaining: 192ms
# 12:	learn: 8.4021775	total: 64.1ms	remaining: 182ms
# 13:	learn: 8.1402440	total: 67.5ms	remaining: 173ms
# 14:	learn: 7.9172339	total: 70.8ms	remaining: 165ms
# 15:	learn: 7.7096108	total: 74.1ms	remaining: 158ms
# 16:	learn: 7.5069440	total: 77.7ms	remaining: 151ms
# 17:	learn: 7.3323124	total: 82.7ms	remaining: 147ms
# 18:	learn: 7.1727287	total: 87.9ms	remaining: 143ms
# 19:	learn: 6.9910156	total: 91.3ms	remaining: 137ms
# 20:	learn: 6.8637840	total: 94.4ms	remaining: 130ms
# 21:	learn: 6.7041921	total: 97.8ms	remaining: 125ms
# 22:	learn: 6.5773906	total: 101ms	remaining: 119ms
# 23:	learn: 6.4539426	total: 104ms	remaining: 113ms
# 24:	learn: 6.3011132	total: 108ms	remaining: 108ms
# 25:	learn: 6.1992023	total: 111ms	remaining: 102ms
# 26:	learn: 6.0862278	total: 114ms	remaining: 97.3ms
# 27:	learn: 5.9580580	total: 118ms	remaining: 92.5ms
# 28:	learn: 5.8214915	total: 121ms	remaining: 87.7ms
# 29:	learn: 5.6930476	total: 124ms	remaining: 82.8ms
# 30:	learn: 5.6270442	total: 127ms	remaining: 78.1ms
# 31:	learn: 5.5394550	total: 131ms	remaining: 73.4ms
# 32:	learn: 5.4596805	total: 134ms	remaining: 69ms
# 33:	learn: 5.3721826	total: 137ms	remaining: 64.6ms
# 34:	learn: 5.2605996	total: 141ms	remaining: 60.3ms
# 35:	learn: 5.1911321	total: 145ms	remaining: 56.6ms
# 36:	learn: 5.1028915	total: 149ms	remaining: 52.3ms
# 37:	learn: 4.9999632	total: 152ms	remaining: 48ms
# 38:	learn: 4.9062614	total: 155ms	remaining: 43.8ms
# 39:	learn: 4.8107795	total: 158ms	remaining: 39.6ms
# 40:	learn: 4.7168719	total: 162ms	remaining: 35.5ms
# 41:	learn: 4.6401623	total: 165ms	remaining: 31.4ms
# 42:	learn: 4.5628875	total: 168ms	remaining: 27.4ms
# 43:	learn: 4.4971022	total: 172ms	remaining: 23.4ms
# 44:	learn: 4.4466142	total: 175ms	remaining: 19.4ms
# 45:	learn: 4.3776326	total: 178ms	remaining: 15.5ms
# 46:	learn: 4.3207645	total: 182ms	remaining: 11.6ms
# 47:	learn: 4.2638266	total: 187ms	remaining: 7.78ms
# 48:	learn: 4.1997192	total: 190ms	remaining: 3.88ms
# 49:	learn: 4.1477306	total: 197ms	remaining: 0us
# 0:	learn: 11.7887853	total: 3.2ms	remaining: 157ms
# 1:	learn: 11.4084316	total: 6.58ms	remaining: 158ms
# 2:	learn: 11.1177022	total: 9.97ms	remaining: 156ms
# 3:	learn: 10.8110105	total: 13.4ms	remaining: 154ms
# 4:	learn: 10.4882965	total: 16.8ms	remaining: 151ms
# 5:	learn: 10.1995189	total: 20ms	remaining: 147ms
# 6:	learn: 9.9339889	total: 23.1ms	remaining: 142ms
# 7:	learn: 9.6349820	total: 26.8ms	remaining: 141ms
# 8:	learn: 9.3403122	total: 30.2ms	remaining: 137ms
# 9:	learn: 9.0948843	total: 33.4ms	remaining: 134ms
# 10:	learn: 8.8469038	total: 36.6ms	remaining: 130ms
# 11:	learn: 8.6140906	total: 39.9ms	remaining: 126ms
# 12:	learn: 8.3787208	total: 42.9ms	remaining: 122ms
# 13:	learn: 8.1270282	total: 46.2ms	remaining: 119ms
# 14:	learn: 7.8916450	total: 49.7ms	remaining: 116ms
# 15:	learn: 7.6699679	total: 53.2ms	remaining: 113ms
# 16:	learn: 7.4587531	total: 56.8ms	remaining: 110ms
# 17:	learn: 7.2695922	total: 60.4ms	remaining: 107ms
# 18:	learn: 7.0911534	total: 63.7ms	remaining: 104ms
# 19:	learn: 6.9403145	total: 67ms	remaining: 101ms
# 20:	learn: 6.7978286	total: 70.8ms	remaining: 97.8ms
# 21:	learn: 6.6818708	total: 74.2ms	remaining: 94.4ms
# 22:	learn: 6.5598187	total: 77.4ms	remaining: 90.9ms
# 23:	learn: 6.4164870	total: 80.7ms	remaining: 87.5ms
# 24:	learn: 6.3093439	total: 84.1ms	remaining: 84.1ms
# 25:	learn: 6.1923230	total: 87.5ms	remaining: 80.7ms
# 26:	learn: 6.0408143	total: 90.8ms	remaining: 77.4ms
# 27:	learn: 5.9315947	total: 94.2ms	remaining: 74ms
# 28:	learn: 5.8108461	total: 97.4ms	remaining: 70.5ms
# 29:	learn: 5.6661036	total: 101ms	remaining: 67.3ms
# 30:	learn: 5.5464753	total: 104ms	remaining: 63.9ms
# 31:	learn: 5.4538866	total: 107ms	remaining: 60.5ms
# 32:	learn: 5.3388129	total: 111ms	remaining: 57ms
# 33:	learn: 5.2584524	total: 114ms	remaining: 53.6ms
# 34:	learn: 5.1383206	total: 117ms	remaining: 50.2ms
# 35:	learn: 5.0628682	total: 120ms	remaining: 46.8ms
# 36:	learn: 4.9621358	total: 123ms	remaining: 43.4ms
# 37:	learn: 4.8756387	total: 127ms	remaining: 40.1ms
# 38:	learn: 4.7951350	total: 130ms	remaining: 36.8ms
# 39:	learn: 4.7199943	total: 134ms	remaining: 33.5ms
# 40:	learn: 4.6173663	total: 137ms	remaining: 30.1ms
# 41:	learn: 4.5317280	total: 141ms	remaining: 26.8ms
# 42:	learn: 4.4645344	total: 144ms	remaining: 23.4ms
# 43:	learn: 4.3755120	total: 147ms	remaining: 20.1ms
# 44:	learn: 4.3230224	total: 155ms	remaining: 17.2ms
# 45:	learn: 4.2573478	total: 158ms	remaining: 13.7ms
# 46:	learn: 4.1977767	total: 161ms	remaining: 10.3ms
# 47:	learn: 4.1344576	total: 165ms	remaining: 6.86ms
# 48:	learn: 4.0660433	total: 168ms	remaining: 3.42ms
# 49:	learn: 4.0077327	total: 171ms	remaining: 0us
# 0:	learn: 11.9262218	total: 3.22ms	remaining: 158ms
# 1:	learn: 11.5410284	total: 6.48ms	remaining: 156ms
# 2:	learn: 11.2162597	total: 10.6ms	remaining: 167ms
# 3:	learn: 10.8592516	total: 14.8ms	remaining: 171ms
# 4:	learn: 10.5250672	total: 18.4ms	remaining: 165ms
# 5:	learn: 10.2643689	total: 21.9ms	remaining: 161ms
# 6:	learn: 9.9936870	total: 25.5ms	remaining: 157ms
# 7:	learn: 9.6832311	total: 28.9ms	remaining: 152ms
# 8:	learn: 9.4134625	total: 32.3ms	remaining: 147ms
# 9:	learn: 9.1591485	total: 35.6ms	remaining: 142ms
# 10:	learn: 8.9008568	total: 39ms	remaining: 138ms
# 11:	learn: 8.6623901	total: 42.2ms	remaining: 134ms
# 12:	learn: 8.4095659	total: 45.4ms	remaining: 129ms
# 13:	learn: 8.1444580	total: 48.8ms	remaining: 125ms
# 14:	learn: 7.9132616	total: 52.6ms	remaining: 123ms
# 15:	learn: 7.7263389	total: 56.6ms	remaining: 120ms
# 16:	learn: 7.5375652	total: 59.7ms	remaining: 116ms
# 17:	learn: 7.3497801	total: 63.1ms	remaining: 112ms
# 18:	learn: 7.1481795	total: 66.4ms	remaining: 108ms
# 19:	learn: 6.9731763	total: 70ms	remaining: 105ms
# 20:	learn: 6.8453100	total: 73.2ms	remaining: 101ms
# 21:	learn: 6.6764946	total: 76.7ms	remaining: 97.6ms
# 22:	learn: 6.5442900	total: 80.1ms	remaining: 94.1ms
# 23:	learn: 6.3783528	total: 83.3ms	remaining: 90.2ms
# 24:	learn: 6.2399800	total: 86.7ms	remaining: 86.7ms
# 25:	learn: 6.1100955	total: 90ms	remaining: 83.1ms
# 26:	learn: 5.9911095	total: 93.2ms	remaining: 79.4ms
# 27:	learn: 5.8734647	total: 96.4ms	remaining: 75.8ms
# 28:	learn: 5.7489487	total: 99.5ms	remaining: 72.1ms
# 29:	learn: 5.6197717	total: 103ms	remaining: 68.4ms
# 30:	learn: 5.5339796	total: 106ms	remaining: 64.9ms
# 31:	learn: 5.4361825	total: 109ms	remaining: 61.4ms
# 32:	learn: 5.3450347	total: 112ms	remaining: 57.9ms
# 33:	learn: 5.2520132	total: 115ms	remaining: 54.4ms
# 34:	learn: 5.1506129	total: 121ms	remaining: 51.9ms
# 35:	learn: 5.0515688	total: 124ms	remaining: 48.4ms
# 36:	learn: 4.9521653	total: 128ms	remaining: 44.9ms
# 37:	learn: 4.8639359	total: 131ms	remaining: 41.3ms
# 38:	learn: 4.7701646	total: 138ms	remaining: 39ms
# 39:	learn: 4.6902501	total: 143ms	remaining: 35.8ms
# 40:	learn: 4.5962240	total: 148ms	remaining: 32.5ms
# 41:	learn: 4.5122899	total: 153ms	remaining: 29.2ms
# 42:	learn: 4.4316381	total: 156ms	remaining: 25.5ms
# 43:	learn: 4.3564322	total: 160ms	remaining: 21.8ms
# 44:	learn: 4.3007585	total: 163ms	remaining: 18.1ms
# 45:	learn: 4.2380768	total: 166ms	remaining: 14.5ms
# 46:	learn: 4.1747959	total: 170ms	remaining: 10.8ms
# 47:	learn: 4.0870185	total: 174ms	remaining: 7.23ms
# 48:	learn: 4.0099797	total: 177ms	remaining: 3.61ms
# 49:	learn: 3.9616950	total: 180ms	remaining: 0us
# 0:	learn: 11.3553705	total: 3.08ms	remaining: 151ms
# 1:	learn: 10.7727863	total: 5.92ms	remaining: 142ms
# 2:	learn: 10.2425768	total: 8.93ms	remaining: 140ms
# 3:	learn: 9.6400848	total: 11.8ms	remaining: 136ms
# 4:	learn: 9.1411460	total: 15ms	remaining: 135ms
# 5:	learn: 8.6871315	total: 18.4ms	remaining: 135ms
# 6:	learn: 8.3131782	total: 22.3ms	remaining: 137ms
# 7:	learn: 7.8670826	total: 25.9ms	remaining: 136ms
# 8:	learn: 7.5010069	total: 29.4ms	remaining: 134ms
# 9:	learn: 7.1843051	total: 32.9ms	remaining: 131ms
# 10:	learn: 6.9251572	total: 36.1ms	remaining: 128ms
# 11:	learn: 6.6599581	total: 39.2ms	remaining: 124ms
# 12:	learn: 6.3624899	total: 42.2ms	remaining: 120ms
# 13:	learn: 6.0539288	total: 45.7ms	remaining: 117ms
# 14:	learn: 5.7690878	total: 48.9ms	remaining: 114ms
# 15:	learn: 5.5587055	total: 52.2ms	remaining: 111ms
# 16:	learn: 5.3336201	total: 55.8ms	remaining: 108ms
# 17:	learn: 5.1402284	total: 59.4ms	remaining: 106ms
# 18:	learn: 4.9690087	total: 62.8ms	remaining: 102ms
# 19:	learn: 4.8262016	total: 66.4ms	remaining: 99.6ms
# 20:	learn: 4.7255142	total: 70ms	remaining: 96.7ms
# 21:	learn: 4.5957024	total: 73.6ms	remaining: 93.7ms
# 22:	learn: 4.4880693	total: 76.9ms	remaining: 90.3ms
# 23:	learn: 4.3995372	total: 80.8ms	remaining: 87.6ms
# 24:	learn: 4.2913804	total: 84.4ms	remaining: 84.4ms
# 25:	learn: 4.1886451	total: 89ms	remaining: 82.2ms
# 26:	learn: 4.1193525	total: 93.9ms	remaining: 80ms
# 27:	learn: 4.0066093	total: 96.9ms	remaining: 76.2ms
# 28:	learn: 3.9017326	total: 100ms	remaining: 72.7ms
# 29:	learn: 3.7851406	total: 104ms	remaining: 69.3ms
# 30:	learn: 3.7237544	total: 113ms	remaining: 69.4ms
# 31:	learn: 3.6452386	total: 116ms	remaining: 65.5ms
# 32:	learn: 3.5648873	total: 120ms	remaining: 61.6ms
# 33:	learn: 3.4690909	total: 123ms	remaining: 57.9ms
# 34:	learn: 3.3949388	total: 126ms	remaining: 54ms
# 35:	learn: 3.3310581	total: 129ms	remaining: 50.1ms
# 36:	learn: 3.2756706	total: 132ms	remaining: 46.3ms
# 37:	learn: 3.2175321	total: 135ms	remaining: 42.5ms
# 38:	learn: 3.1595239	total: 138ms	remaining: 38.8ms
# 39:	learn: 3.0903686	total: 141ms	remaining: 35.2ms
# 40:	learn: 3.0506348	total: 144ms	remaining: 31.6ms
# 41:	learn: 3.0267387	total: 148ms	remaining: 28.1ms
# 42:	learn: 2.9886788	total: 151ms	remaining: 24.6ms
# 43:	learn: 2.9387998	total: 154ms	remaining: 21ms
# 44:	learn: 2.9052882	total: 157ms	remaining: 17.5ms
# 45:	learn: 2.8887360	total: 161ms	remaining: 14ms
# 46:	learn: 2.8465968	total: 164ms	remaining: 10.5ms
# 47:	learn: 2.8311120	total: 167ms	remaining: 6.97ms
# 48:	learn: 2.7655350	total: 170ms	remaining: 3.48ms
# 49:	learn: 2.7402361	total: 174ms	remaining: 0us
# 0:	learn: 11.4211024	total: 3.07ms	remaining: 150ms
# 1:	learn: 10.6980587	total: 6.58ms	remaining: 158ms
# 2:	learn: 10.1778914	total: 9.84ms	remaining: 154ms
# 3:	learn: 9.5669097	total: 13ms	remaining: 149ms
# 4:	learn: 9.0402591	total: 16.3ms	remaining: 147ms
# 5:	learn: 8.5351592	total: 19.6ms	remaining: 144ms
# 6:	learn: 8.1500808	total: 23ms	remaining: 141ms
# 7:	learn: 7.7125359	total: 26.2ms	remaining: 137ms
# 8:	learn: 7.3056745	total: 29.4ms	remaining: 134ms
# 9:	learn: 7.0012815	total: 32.7ms	remaining: 131ms
# 10:	learn: 6.6799951	total: 36ms	remaining: 127ms
# 11:	learn: 6.4134038	total: 39.4ms	remaining: 125ms
# 12:	learn: 6.1325495	total: 42.8ms	remaining: 122ms
# 13:	learn: 5.8293081	total: 46.5ms	remaining: 120ms
# 14:	learn: 5.6035109	total: 49.9ms	remaining: 117ms
# 15:	learn: 5.4180202	total: 53.2ms	remaining: 113ms
# 16:	learn: 5.2247342	total: 56.4ms	remaining: 109ms
# 17:	learn: 5.0468601	total: 60.2ms	remaining: 107ms
# 18:	learn: 4.8909254	total: 63.6ms	remaining: 104ms
# 19:	learn: 4.6817153	total: 67.6ms	remaining: 101ms
# 20:	learn: 4.5836675	total: 71ms	remaining: 98ms
# 21:	learn: 4.3961353	total: 74.1ms	remaining: 94.4ms
# 22:	learn: 4.2983973	total: 79.5ms	remaining: 93.3ms
# 23:	learn: 4.1740758	total: 83.2ms	remaining: 90.1ms
# 24:	learn: 4.0767632	total: 89.1ms	remaining: 89.1ms
# 25:	learn: 3.9686340	total: 101ms	remaining: 93.5ms
# 26:	learn: 3.8539033	total: 110ms	remaining: 93.3ms
# 27:	learn: 3.7678156	total: 119ms	remaining: 93.8ms
# 28:	learn: 3.6553975	total: 125ms	remaining: 90.7ms
# 29:	learn: 3.5509880	total: 129ms	remaining: 85.7ms
# 30:	learn: 3.4649298	total: 132ms	remaining: 80.8ms
# 31:	learn: 3.3908900	total: 135ms	remaining: 76ms
# 32:	learn: 3.3234935	total: 138ms	remaining: 71.3ms
# 33:	learn: 3.2615791	total: 142ms	remaining: 66.7ms
# 34:	learn: 3.1794113	total: 145ms	remaining: 62.1ms
# 35:	learn: 3.1186992	total: 148ms	remaining: 57.7ms
# 36:	learn: 3.0483558	total: 152ms	remaining: 53.4ms
# 37:	learn: 2.9753750	total: 155ms	remaining: 49ms
# 38:	learn: 2.9124251	total: 161ms	remaining: 45.5ms
# 39:	learn: 2.8543182	total: 168ms	remaining: 42.1ms
# 40:	learn: 2.8075398	total: 171ms	remaining: 37.6ms
# 41:	learn: 2.7485446	total: 175ms	remaining: 33.3ms
# 42:	learn: 2.7091782	total: 178ms	remaining: 29ms
# 43:	learn: 2.6544052	total: 182ms	remaining: 24.8ms
# 44:	learn: 2.6159642	total: 185ms	remaining: 20.6ms
# 45:	learn: 2.5776953	total: 188ms	remaining: 16.4ms
# 46:	learn: 2.5432378	total: 192ms	remaining: 12.3ms
# 47:	learn: 2.5194452	total: 195ms	remaining: 8.14ms
# 48:	learn: 2.4770033	total: 199ms	remaining: 4.05ms
# 49:	learn: 2.4303221	total: 202ms	remaining: 0us
# 0:	learn: 11.5346453	total: 3.14ms	remaining: 154ms
# 1:	learn: 10.8050644	total: 6.17ms	remaining: 148ms
# 2:	learn: 10.2269850	total: 9.03ms	remaining: 141ms
# 3:	learn: 9.6058770	total: 12.2ms	remaining: 141ms
# 4:	learn: 9.0683269	total: 15.2ms	remaining: 137ms
# 5:	learn: 8.5863208	total: 18.7ms	remaining: 137ms
# 6:	learn: 8.1906558	total: 22.3ms	remaining: 137ms
# 7:	learn: 7.7583650	total: 25.8ms	remaining: 136ms
# 8:	learn: 7.3474592	total: 29.3ms	remaining: 133ms
# 9:	learn: 7.0117595	total: 33ms	remaining: 132ms
# 10:	learn: 6.6841657	total: 36.7ms	remaining: 130ms
# 11:	learn: 6.3986390	total: 39.8ms	remaining: 126ms
# 12:	learn: 6.0707933	total: 42.9ms	remaining: 122ms
# 13:	learn: 5.7480267	total: 46.2ms	remaining: 119ms
# 14:	learn: 5.5112950	total: 50.8ms	remaining: 118ms
# 15:	learn: 5.2713682	total: 55.7ms	remaining: 118ms
# 16:	learn: 5.0695457	total: 59.3ms	remaining: 115ms
# 17:	learn: 4.8892269	total: 62.5ms	remaining: 111ms
# 18:	learn: 4.7035606	total: 66ms	remaining: 108ms
# 19:	learn: 4.5364614	total: 69.3ms	remaining: 104ms
# 20:	learn: 4.4089842	total: 72.6ms	remaining: 100ms
# 21:	learn: 4.2522490	total: 75.8ms	remaining: 96.5ms
# 22:	learn: 4.1467359	total: 79.1ms	remaining: 92.8ms
# 23:	learn: 4.0100055	total: 82.4ms	remaining: 89.2ms
# 24:	learn: 3.9082364	total: 85.8ms	remaining: 85.8ms
# 25:	learn: 3.7755290	total: 89.2ms	remaining: 82.3ms
# 26:	learn: 3.6794094	total: 92.6ms	remaining: 78.9ms
# 27:	learn: 3.6053269	total: 95.9ms	remaining: 75.3ms
# 28:	learn: 3.5119280	total: 99.6ms	remaining: 72.1ms
# 29:	learn: 3.4193710	total: 103ms	remaining: 69ms
# 30:	learn: 3.3720133	total: 107ms	remaining: 65.4ms
# 31:	learn: 3.2949335	total: 110ms	remaining: 62.1ms
# 32:	learn: 3.2304757	total: 114ms	remaining: 58.8ms
# 33:	learn: 3.1771797	total: 118ms	remaining: 55.5ms
# 34:	learn: 3.1194191	total: 122ms	remaining: 52.1ms
# 35:	learn: 3.0310134	total: 125ms	remaining: 48.6ms
# 36:	learn: 2.9486816	total: 128ms	remaining: 45.1ms
# 37:	learn: 2.8702217	total: 132ms	remaining: 41.6ms
# 38:	learn: 2.8146967	total: 135ms	remaining: 38ms
# 39:	learn: 2.7553270	total: 138ms	remaining: 34.5ms
# 40:	learn: 2.6895926	total: 143ms	remaining: 31.4ms
# 41:	learn: 2.6228943	total: 146ms	remaining: 27.9ms
# 42:	learn: 2.5886193	total: 149ms	remaining: 24.3ms
# 43:	learn: 2.5468549	total: 153ms	remaining: 20.8ms
# 44:	learn: 2.5255339	total: 156ms	remaining: 17.3ms
# 45:	learn: 2.4848133	total: 159ms	remaining: 13.9ms
# 46:	learn: 2.4523220	total: 163ms	remaining: 10.4ms
# 47:	learn: 2.3989532	total: 166ms	remaining: 6.91ms
# 48:	learn: 2.3643734	total: 172ms	remaining: 3.51ms
# 49:	learn: 2.3161348	total: 177ms	remaining: 0us
# 0:	learn: 12.0474412	total: 3.12ms	remaining: 309ms
# 1:	learn: 11.9717073	total: 6.13ms	remaining: 300ms
# 2:	learn: 11.9059822	total: 8.91ms	remaining: 288ms
# 3:	learn: 11.8289107	total: 12.2ms	remaining: 293ms
# 4:	learn: 11.7557857	total: 15.5ms	remaining: 294ms
# 5:	learn: 11.6845494	total: 18.6ms	remaining: 292ms
# 6:	learn: 11.6181709	total: 24.3ms	remaining: 323ms
# 7:	learn: 11.5403476	total: 29.6ms	remaining: 340ms
# 8:	learn: 11.4695802	total: 32.8ms	remaining: 332ms
# 9:	learn: 11.4015307	total: 36.2ms	remaining: 326ms
# 10:	learn: 11.3343708	total: 40.2ms	remaining: 326ms
# 11:	learn: 11.2648526	total: 43.5ms	remaining: 319ms
# 12:	learn: 11.1904938	total: 46.7ms	remaining: 312ms
# 13:	learn: 11.1149024	total: 50.2ms	remaining: 308ms
# 14:	learn: 11.0413905	total: 53.7ms	remaining: 304ms
# 15:	learn: 10.9743156	total: 56.9ms	remaining: 299ms
# 16:	learn: 10.9066946	total: 60.2ms	remaining: 294ms
# 17:	learn: 10.8406812	total: 63.3ms	remaining: 288ms
# 18:	learn: 10.7795569	total: 66.7ms	remaining: 284ms
# 19:	learn: 10.7188733	total: 70.1ms	remaining: 280ms
# 20:	learn: 10.6622903	total: 73.6ms	remaining: 277ms
# 21:	learn: 10.6064787	total: 77.3ms	remaining: 274ms
# 22:	learn: 10.5482488	total: 80.5ms	remaining: 269ms
# 23:	learn: 10.4850483	total: 83.8ms	remaining: 266ms
# 24:	learn: 10.4293920	total: 87.2ms	remaining: 261ms
# 25:	learn: 10.3637645	total: 90.4ms	remaining: 257ms
# 26:	learn: 10.3039968	total: 94.3ms	remaining: 255ms
# 27:	learn: 10.2391840	total: 99.1ms	remaining: 255ms
# 28:	learn: 10.1844578	total: 102ms	remaining: 250ms
# 29:	learn: 10.1269974	total: 106ms	remaining: 247ms
# 30:	learn: 10.0721983	total: 109ms	remaining: 242ms
# 31:	learn: 10.0174720	total: 112ms	remaining: 238ms
# 32:	learn: 9.9639640	total: 115ms	remaining: 234ms
# 33:	learn: 9.9109616	total: 119ms	remaining: 230ms
# 34:	learn: 9.8483429	total: 122ms	remaining: 226ms
# 35:	learn: 9.7961489	total: 125ms	remaining: 222ms
# 36:	learn: 9.7404011	total: 128ms	remaining: 219ms
# 37:	learn: 9.6847317	total: 132ms	remaining: 215ms
# 38:	learn: 9.6277063	total: 135ms	remaining: 212ms
# 39:	learn: 9.5708521	total: 139ms	remaining: 208ms
# 40:	learn: 9.5141396	total: 142ms	remaining: 204ms
# 41:	learn: 9.4626795	total: 145ms	remaining: 201ms
# 42:	learn: 9.4136052	total: 148ms	remaining: 196ms
# 43:	learn: 9.3557706	total: 151ms	remaining: 192ms
# 44:	learn: 9.3017360	total: 154ms	remaining: 188ms
# 45:	learn: 9.2464749	total: 160ms	remaining: 188ms
# 46:	learn: 9.1933727	total: 164ms	remaining: 185ms
# 47:	learn: 9.1429677	total: 167ms	remaining: 181ms
# 48:	learn: 9.0898165	total: 170ms	remaining: 177ms
# 49:	learn: 9.0317548	total: 174ms	remaining: 174ms
# 50:	learn: 8.9872033	total: 177ms	remaining: 170ms
# 51:	learn: 8.9370077	total: 181ms	remaining: 167ms
# 52:	learn: 8.8904013	total: 184ms	remaining: 163ms
# 53:	learn: 8.8422730	total: 188ms	remaining: 160ms
# 54:	learn: 8.7953010	total: 191ms	remaining: 156ms
# 55:	learn: 8.7495214	total: 194ms	remaining: 153ms
# 56:	learn: 8.7019609	total: 198ms	remaining: 149ms
# 57:	learn: 8.6535154	total: 201ms	remaining: 146ms
# 58:	learn: 8.6050293	total: 205ms	remaining: 142ms
# 59:	learn: 8.5672636	total: 208ms	remaining: 138ms
# 60:	learn: 8.5234701	total: 211ms	remaining: 135ms
# 61:	learn: 8.4778356	total: 214ms	remaining: 131ms
# 62:	learn: 8.4339580	total: 224ms	remaining: 131ms
# 63:	learn: 8.3912984	total: 227ms	remaining: 128ms
# 64:	learn: 8.3494392	total: 231ms	remaining: 124ms
# 65:	learn: 8.3050773	total: 234ms	remaining: 121ms
# 66:	learn: 8.2630564	total: 237ms	remaining: 117ms
# 67:	learn: 8.2206665	total: 241ms	remaining: 113ms
# 68:	learn: 8.1808246	total: 244ms	remaining: 110ms
# 69:	learn: 8.1418424	total: 247ms	remaining: 106ms
# 70:	learn: 8.0971085	total: 250ms	remaining: 102ms
# 71:	learn: 8.0560321	total: 254ms	remaining: 98.7ms
# 72:	learn: 8.0123230	total: 257ms	remaining: 95.1ms
# 73:	learn: 7.9709821	total: 260ms	remaining: 91.4ms
# 74:	learn: 7.9299314	total: 263ms	remaining: 87.8ms
# 75:	learn: 7.8949401	total: 266ms	remaining: 84.2ms
# 76:	learn: 7.8560428	total: 270ms	remaining: 80.6ms
# 77:	learn: 7.8197009	total: 273ms	remaining: 77ms
# 78:	learn: 7.7840103	total: 276ms	remaining: 73.4ms
# 79:	learn: 7.7396009	total: 279ms	remaining: 69.8ms
# 80:	learn: 7.7016655	total: 283ms	remaining: 66.3ms
# 81:	learn: 7.6654442	total: 286ms	remaining: 62.8ms
# 82:	learn: 7.6263150	total: 289ms	remaining: 59.2ms
# 83:	learn: 7.5856223	total: 293ms	remaining: 55.8ms
# 84:	learn: 7.5460810	total: 296ms	remaining: 52.3ms
# 85:	learn: 7.5083906	total: 300ms	remaining: 48.8ms
# 86:	learn: 7.4727447	total: 303ms	remaining: 45.3ms
# 87:	learn: 7.4371514	total: 307ms	remaining: 41.8ms
# 88:	learn: 7.4020872	total: 310ms	remaining: 38.3ms
# 89:	learn: 7.3662962	total: 313ms	remaining: 34.8ms
# 90:	learn: 7.3340240	total: 316ms	remaining: 31.3ms
# 91:	learn: 7.3008579	total: 320ms	remaining: 27.8ms
# 92:	learn: 7.2637968	total: 323ms	remaining: 24.3ms
# 93:	learn: 7.2327908	total: 327ms	remaining: 20.9ms
# 94:	learn: 7.1930668	total: 330ms	remaining: 17.4ms
# 95:	learn: 7.1595502	total: 333ms	remaining: 13.9ms
# 96:	learn: 7.1298398	total: 336ms	remaining: 10.4ms
# 97:	learn: 7.0997555	total: 340ms	remaining: 6.93ms
# 98:	learn: 7.0679092	total: 343ms	remaining: 3.47ms
# 99:	learn: 7.0318533	total: 347ms	remaining: 0us
# 0:	learn: 12.0876188	total: 3.26ms	remaining: 322ms
# 1:	learn: 12.0101542	total: 6.41ms	remaining: 314ms
# 2:	learn: 11.9462280	total: 9.81ms	remaining: 317ms
# 3:	learn: 11.8766055	total: 13.1ms	remaining: 313ms
# 4:	learn: 11.7993281	total: 16.3ms	remaining: 310ms
# 5:	learn: 11.7295218	total: 19.7ms	remaining: 308ms
# 6:	learn: 11.6623892	total: 23.2ms	remaining: 308ms
# 7:	learn: 11.5853543	total: 27.7ms	remaining: 319ms
# 8:	learn: 11.5049736	total: 33.8ms	remaining: 342ms
# 9:	learn: 11.4351770	total: 36.9ms	remaining: 332ms
# 10:	learn: 11.3609023	total: 39.9ms	remaining: 323ms
# 11:	learn: 11.2913618	total: 43.1ms	remaining: 316ms
# 12:	learn: 11.2213774	total: 47.7ms	remaining: 319ms
# 13:	learn: 11.1419547	total: 55.2ms	remaining: 339ms
# 14:	learn: 11.0666027	total: 58.7ms	remaining: 333ms
# 15:	learn: 11.0009093	total: 62.2ms	remaining: 326ms
# 16:	learn: 10.9378978	total: 65.6ms	remaining: 320ms
# 17:	learn: 10.8718306	total: 70.2ms	remaining: 320ms
# 18:	learn: 10.8025223	total: 73.6ms	remaining: 314ms
# 19:	learn: 10.7360424	total: 77ms	remaining: 308ms
# 20:	learn: 10.6792105	total: 80.1ms	remaining: 301ms
# 21:	learn: 10.6220447	total: 83.4ms	remaining: 296ms
# 22:	learn: 10.5552748	total: 86.6ms	remaining: 290ms
# 23:	learn: 10.4895436	total: 90.2ms	remaining: 286ms
# 24:	learn: 10.4331873	total: 93.6ms	remaining: 281ms
# 25:	learn: 10.3688947	total: 96.9ms	remaining: 276ms
# 26:	learn: 10.3134943	total: 100ms	remaining: 272ms
# 27:	learn: 10.2544168	total: 104ms	remaining: 267ms
# 28:	learn: 10.1934568	total: 107ms	remaining: 262ms
# 29:	learn: 10.1345617	total: 111ms	remaining: 258ms
# 30:	learn: 10.0823560	total: 114ms	remaining: 253ms
# 31:	learn: 10.0236730	total: 117ms	remaining: 249ms
# 32:	learn: 9.9669532	total: 120ms	remaining: 245ms
# 33:	learn: 9.9122968	total: 124ms	remaining: 241ms
# 34:	learn: 9.8490374	total: 128ms	remaining: 237ms
# 35:	learn: 9.7976747	total: 131ms	remaining: 233ms
# 36:	learn: 9.7365266	total: 135ms	remaining: 229ms
# 37:	learn: 9.6808952	total: 138ms	remaining: 225ms
# 38:	learn: 9.6215331	total: 142ms	remaining: 222ms
# 39:	learn: 9.5692442	total: 145ms	remaining: 218ms
# 40:	learn: 9.5095304	total: 149ms	remaining: 214ms
# 41:	learn: 9.4496014	total: 152ms	remaining: 210ms
# 42:	learn: 9.3972741	total: 156ms	remaining: 206ms
# 43:	learn: 9.3432035	total: 159ms	remaining: 203ms
# 44:	learn: 9.2920843	total: 162ms	remaining: 199ms
# 45:	learn: 9.2466171	total: 166ms	remaining: 195ms
# 46:	learn: 9.1962071	total: 169ms	remaining: 191ms
# 47:	learn: 9.1444185	total: 175ms	remaining: 190ms
# 48:	learn: 9.1008643	total: 179ms	remaining: 186ms
# 49:	learn: 9.0506506	total: 182ms	remaining: 182ms
# 50:	learn: 8.9982072	total: 185ms	remaining: 178ms
# 51:	learn: 8.9437360	total: 189ms	remaining: 174ms
# 52:	learn: 8.8869790	total: 192ms	remaining: 170ms
# 53:	learn: 8.8368566	total: 197ms	remaining: 168ms
# 54:	learn: 8.7943287	total: 202ms	remaining: 165ms
# 55:	learn: 8.7427454	total: 206ms	remaining: 162ms
# 56:	learn: 8.7041782	total: 210ms	remaining: 158ms
# 57:	learn: 8.6548271	total: 214ms	remaining: 155ms
# 58:	learn: 8.6120471	total: 221ms	remaining: 154ms
# 59:	learn: 8.5662324	total: 230ms	remaining: 153ms
# 60:	learn: 8.5196662	total: 240ms	remaining: 153ms
# 61:	learn: 8.4738482	total: 246ms	remaining: 150ms
# 62:	learn: 8.4230444	total: 248ms	remaining: 146ms
# 63:	learn: 8.3813942	total: 252ms	remaining: 142ms
# 64:	learn: 8.3386906	total: 255ms	remaining: 137ms
# 65:	learn: 8.3033660	total: 258ms	remaining: 133ms
# 66:	learn: 8.2561473	total: 262ms	remaining: 129ms
# 67:	learn: 8.2206745	total: 265ms	remaining: 125ms
# 68:	learn: 8.1749769	total: 268ms	remaining: 120ms
# 69:	learn: 8.1338333	total: 271ms	remaining: 116ms
# 70:	learn: 8.0963785	total: 275ms	remaining: 112ms
# 71:	learn: 8.0559336	total: 278ms	remaining: 108ms
# 72:	learn: 8.0166444	total: 281ms	remaining: 104ms
# 73:	learn: 7.9814769	total: 284ms	remaining: 99.9ms
# 74:	learn: 7.9448235	total: 288ms	remaining: 95.9ms
# 75:	learn: 7.9040884	total: 291ms	remaining: 91.9ms
# 76:	learn: 7.8609468	total: 295ms	remaining: 88ms
# 77:	learn: 7.8219955	total: 298ms	remaining: 84ms
# 78:	learn: 7.7841426	total: 301ms	remaining: 80.1ms
# 79:	learn: 7.7424153	total: 305ms	remaining: 76.2ms
# 80:	learn: 7.7043633	total: 308ms	remaining: 72.3ms
# 81:	learn: 7.6664015	total: 311ms	remaining: 68.4ms
# 82:	learn: 7.6255633	total: 315ms	remaining: 64.5ms
# 83:	learn: 7.5904360	total: 318ms	remaining: 60.6ms
# 84:	learn: 7.5518600	total: 322ms	remaining: 56.8ms
# 85:	learn: 7.5112463	total: 325ms	remaining: 52.9ms
# 86:	learn: 7.4786914	total: 328ms	remaining: 49ms
# 87:	learn: 7.4462592	total: 332ms	remaining: 45.2ms
# 88:	learn: 7.4107402	total: 335ms	remaining: 41.4ms
# 89:	learn: 7.3718115	total: 338ms	remaining: 37.6ms
# 90:	learn: 7.3432501	total: 341ms	remaining: 33.7ms
# 91:	learn: 7.3107479	total: 344ms	remaining: 29.9ms
# 92:	learn: 7.2727285	total: 348ms	remaining: 26.2ms
# 93:	learn: 7.2417437	total: 351ms	remaining: 22.4ms
# 94:	learn: 7.2007577	total: 354ms	remaining: 18.6ms
# 95:	learn: 7.1668874	total: 357ms	remaining: 14.9ms
# 96:	learn: 7.1322405	total: 360ms	remaining: 11.1ms
# 97:	learn: 7.1051507	total: 363ms	remaining: 7.42ms
# 98:	learn: 7.0710384	total: 367ms	remaining: 3.7ms
# 99:	learn: 7.0390563	total: 370ms	remaining: 0us
# 0:	learn: 12.2439202	total: 5.89ms	remaining: 583ms
# 1:	learn: 12.1636759	total: 9.85ms	remaining: 483ms
# 2:	learn: 12.0928441	total: 13.4ms	remaining: 432ms
# 3:	learn: 12.0126725	total: 16.7ms	remaining: 402ms
# 4:	learn: 11.9342153	total: 20ms	remaining: 380ms
# 5:	learn: 11.8698934	total: 23.3ms	remaining: 365ms
# 6:	learn: 11.8020036	total: 26.5ms	remaining: 352ms
# 7:	learn: 11.7200300	total: 29.8ms	remaining: 343ms
# 8:	learn: 11.6383024	total: 33.4ms	remaining: 338ms
# 9:	learn: 11.5660014	total: 36.6ms	remaining: 330ms
# 10:	learn: 11.4946196	total: 40ms	remaining: 324ms
# 11:	learn: 11.4207493	total: 43.5ms	remaining: 319ms
# 12:	learn: 11.3461089	total: 46.7ms	remaining: 312ms
# 13:	learn: 11.2666259	total: 49.9ms	remaining: 306ms
# 14:	learn: 11.1885251	total: 53.5ms	remaining: 303ms
# 15:	learn: 11.1209663	total: 56.9ms	remaining: 299ms
# 16:	learn: 11.0508081	total: 60.5ms	remaining: 295ms
# 17:	learn: 10.9822952	total: 64.5ms	remaining: 294ms
# 18:	learn: 10.9096954	total: 67.9ms	remaining: 289ms
# 19:	learn: 10.8414087	total: 71.1ms	remaining: 284ms
# 20:	learn: 10.7837768	total: 74.4ms	remaining: 280ms
# 21:	learn: 10.7162213	total: 77.8ms	remaining: 276ms
# 22:	learn: 10.6542976	total: 81.1ms	remaining: 272ms
# 23:	learn: 10.5938525	total: 84.3ms	remaining: 267ms
# 24:	learn: 10.5250411	total: 87.6ms	remaining: 263ms
# 25:	learn: 10.4568657	total: 90.8ms	remaining: 258ms
# 26:	learn: 10.3955711	total: 94.1ms	remaining: 254ms
# 27:	learn: 10.3337178	total: 97.2ms	remaining: 250ms
# 28:	learn: 10.2678682	total: 101ms	remaining: 246ms
# 29:	learn: 10.2094397	total: 104ms	remaining: 243ms
# 30:	learn: 10.1535152	total: 108ms	remaining: 239ms
# 31:	learn: 10.0918472	total: 111ms	remaining: 236ms
# 32:	learn: 10.0302151	total: 117ms	remaining: 238ms
# 33:	learn: 9.9751362	total: 122ms	remaining: 236ms
# 34:	learn: 9.9119890	total: 125ms	remaining: 233ms
# 35:	learn: 9.8552126	total: 129ms	remaining: 229ms
# 36:	learn: 9.7972956	total: 132ms	remaining: 225ms
# 37:	learn: 9.7345926	total: 135ms	remaining: 221ms
# 38:	learn: 9.6764191	total: 139ms	remaining: 217ms
# 39:	learn: 9.6186125	total: 142ms	remaining: 212ms
# 40:	learn: 9.5592405	total: 145ms	remaining: 208ms
# 41:	learn: 9.4993978	total: 148ms	remaining: 204ms
# 42:	learn: 9.4436181	total: 151ms	remaining: 200ms
# 43:	learn: 9.3837555	total: 155ms	remaining: 197ms
# 44:	learn: 9.3370566	total: 161ms	remaining: 197ms
# 45:	learn: 9.2886429	total: 170ms	remaining: 200ms
# 46:	learn: 9.2414893	total: 178ms	remaining: 200ms
# 47:	learn: 9.1926666	total: 186ms	remaining: 201ms
# 48:	learn: 9.1470896	total: 190ms	remaining: 198ms
# 49:	learn: 9.0945292	total: 197ms	remaining: 197ms
# 50:	learn: 9.0458759	total: 203ms	remaining: 195ms
# 51:	learn: 8.9892548	total: 207ms	remaining: 191ms
# 52:	learn: 8.9309735	total: 211ms	remaining: 187ms
# 53:	learn: 8.8795076	total: 216ms	remaining: 184ms
# 54:	learn: 8.8339856	total: 228ms	remaining: 186ms
# 55:	learn: 8.7826595	total: 233ms	remaining: 183ms
# 56:	learn: 8.7425114	total: 241ms	remaining: 182ms
# 57:	learn: 8.6986479	total: 248ms	remaining: 179ms
# 58:	learn: 8.6533031	total: 257ms	remaining: 179ms
# 59:	learn: 8.6061498	total: 265ms	remaining: 177ms
# 60:	learn: 8.5602661	total: 269ms	remaining: 172ms
# 61:	learn: 8.5095102	total: 273ms	remaining: 167ms
# 62:	learn: 8.4633475	total: 277ms	remaining: 163ms
# 63:	learn: 8.4203965	total: 285ms	remaining: 160ms
# 64:	learn: 8.3710498	total: 291ms	remaining: 156ms
# 65:	learn: 8.3317712	total: 299ms	remaining: 154ms
# 66:	learn: 8.2885197	total: 307ms	remaining: 151ms
# 67:	learn: 8.2440568	total: 313ms	remaining: 147ms
# 68:	learn: 8.2002061	total: 321ms	remaining: 144ms
# 69:	learn: 8.1616487	total: 327ms	remaining: 140ms
# 70:	learn: 8.1151318	total: 331ms	remaining: 135ms
# 71:	learn: 8.0772312	total: 335ms	remaining: 130ms
# 72:	learn: 8.0336281	total: 339ms	remaining: 126ms
# 73:	learn: 7.9924745	total: 344ms	remaining: 121ms
# 74:	learn: 7.9522389	total: 348ms	remaining: 116ms
# 75:	learn: 7.9094676	total: 353ms	remaining: 111ms
# 76:	learn: 7.8646508	total: 357ms	remaining: 107ms
# ...
# 2:	learn: 10.1558738	total: 101ms	remaining: 3.27s
# 3:	learn: 9.5550499	total: 104ms	remaining: 2.5s
# 4:	learn: 8.9810558	total: 135ms	remaining: 2.56s
# 5:	learn: 8.5257962	total: 166ms	remaining: 2.6s
# 6:	learn: 8.0967863	total: 196ms	remaining: 2.61s
# 7:	learn: 7.6212230	total: 228ms	remaining: 2.62s
# 8:	learn: 7.2783280	total: 268ms	remaining: 2.71s
# 9:	learn: 6.9031498	total: 298ms	remaining: 2.69s
# 10:	learn: 6.5455396	total: 330ms	remaining: 2.67s
# 11:	learn: 6.1893064	total: 365ms	remaining: 2.67s
# 12:	learn: 5.9132409	total: 397ms	remaining: 2.66s
# 13:	learn: 5.6236777	total: 432ms	remaining: 2.65s
# 14:	learn: 5.3938268	total: 463ms	remaining: 2.63s
# 15:	learn: 5.1860924	total: 509ms	remaining: 2.67s
# 16:	learn: 5.0030920	total: 541ms	remaining: 2.64s
# 17:	learn: 4.7677124	total: 576ms	remaining: 2.62s
# 18:	learn: 4.6056271	total: 607ms	remaining: 2.58s
# 19:	learn: 4.4657600	total: 637ms	remaining: 2.55s
# 20:	learn: 4.2789090	total: 668ms	remaining: 2.51s
# 21:	learn: 4.1124347	total: 698ms	remaining: 2.48s
# 22:	learn: 3.9810788	total: 748ms	remaining: 2.5s
# 23:	learn: 3.8606206	total: 757ms	remaining: 2.4s
# 24:	learn: 3.7205668	total: 795ms	remaining: 2.39s
# 25:	learn: 3.6033275	total: 826ms	remaining: 2.35s
# 26:	learn: 3.5052845	total: 857ms	remaining: 2.32s
# 27:	learn: 3.3870458	total: 888ms	remaining: 2.28s
# 28:	learn: 3.2690632	total: 919ms	remaining: 2.25s
# 29:	learn: 3.1759652	total: 958ms	remaining: 2.23s
# 30:	learn: 3.0698266	total: 989ms	remaining: 2.2s
# 31:	learn: 2.9580507	total: 1.02s	remaining: 2.17s
# 32:	learn: 2.8708405	total: 1.05s	remaining: 2.14s
# 33:	learn: 2.7830694	total: 1.09s	remaining: 2.11s
# 34:	learn: 2.7130077	total: 1.12s	remaining: 2.08s
# 35:	learn: 2.6341657	total: 1.15s	remaining: 2.05s
# 36:	learn: 2.5697967	total: 1.19s	remaining: 2.03s
# 37:	learn: 2.4889349	total: 1.22s	remaining: 2s
# 38:	learn: 2.4334652	total: 1.25s	remaining: 1.96s
# 39:	learn: 2.3863431	total: 1.29s	remaining: 1.93s
# 40:	learn: 2.3361114	total: 1.32s	remaining: 1.9s
# 41:	learn: 2.2946689	total: 1.35s	remaining: 1.86s
# 42:	learn: 2.2396892	total: 1.38s	remaining: 1.83s
# 43:	learn: 2.1926043	total: 1.42s	remaining: 1.8s
# 44:	learn: 2.1286316	total: 1.45s	remaining: 1.77s
# 45:	learn: 2.0837485	total: 1.48s	remaining: 1.74s
# 46:	learn: 2.0454533	total: 1.51s	remaining: 1.7s
# 47:	learn: 2.0086537	total: 1.54s	remaining: 1.67s
# 48:	learn: 1.9776209	total: 1.57s	remaining: 1.64s
# 49:	learn: 1.9449145	total: 1.6s	remaining: 1.6s
# 50:	learn: 1.8996451	total: 1.64s	remaining: 1.58s
# 51:	learn: 1.8622928	total: 1.68s	remaining: 1.55s
# 52:	learn: 1.8300854	total: 1.71s	remaining: 1.51s
# 53:	learn: 1.8009621	total: 1.74s	remaining: 1.48s
# 54:	learn: 1.7672412	total: 1.78s	remaining: 1.46s
# 55:	learn: 1.7271363	total: 1.81s	remaining: 1.43s
# 56:	learn: 1.6961682	total: 1.85s	remaining: 1.4s
# 57:	learn: 1.6742505	total: 1.88s	remaining: 1.36s
# 58:	learn: 1.6431323	total: 1.91s	remaining: 1.33s
# 59:	learn: 1.6191174	total: 1.95s	remaining: 1.3s
# 60:	learn: 1.5947406	total: 1.98s	remaining: 1.26s
# 61:	learn: 1.5740273	total: 2.01s	remaining: 1.23s
# 62:	learn: 1.5546550	total: 2.04s	remaining: 1.2s
# 63:	learn: 1.5362200	total: 2.08s	remaining: 1.17s
# 64:	learn: 1.5168441	total: 2.12s	remaining: 1.14s
# 65:	learn: 1.4950385	total: 2.15s	remaining: 1.11s
# 66:	learn: 1.4747275	total: 2.18s	remaining: 1.07s
# 67:	learn: 1.4539153	total: 2.21s	remaining: 1.04s
# 68:	learn: 1.4374644	total: 2.24s	remaining: 1.01s
# 69:	learn: 1.4279496	total: 2.27s	remaining: 975ms
# 70:	learn: 1.4068044	total: 2.31s	remaining: 944ms
# 71:	learn: 1.3841148	total: 2.34s	remaining: 911ms
# 72:	learn: 1.3580157	total: 2.37s	remaining: 878ms
# 73:	learn: 1.3403719	total: 2.4s	remaining: 845ms
# 74:	learn: 1.3154981	total: 2.43s	remaining: 812ms
# 75:	learn: 1.2986111	total: 2.46s	remaining: 778ms
# 76:	learn: 1.2795308	total: 2.5s	remaining: 746ms
# 77:	learn: 1.2622996	total: 2.54s	remaining: 717ms
# 78:	learn: 1.2411400	total: 2.57s	remaining: 684ms
# 79:	learn: 1.2299348	total: 2.6s	remaining: 650ms
# 80:	learn: 1.2101081	total: 2.64s	remaining: 619ms
# 81:	learn: 1.1966916	total: 2.69s	remaining: 591ms
# 82:	learn: 1.1791023	total: 2.74s	remaining: 562ms
# 83:	learn: 1.1666846	total: 2.81s	remaining: 536ms
# 84:	learn: 1.1538891	total: 2.87s	remaining: 507ms
# 85:	learn: 1.1371932	total: 2.92s	remaining: 476ms
# 86:	learn: 1.1198596	total: 2.99s	remaining: 447ms
# 87:	learn: 1.1014065	total: 3.06s	remaining: 418ms
# 88:	learn: 1.0891277	total: 3.12s	remaining: 386ms
# 89:	learn: 1.0826883	total: 3.18s	remaining: 353ms
# 90:	learn: 1.0605111	total: 3.23s	remaining: 320ms
# 91:	learn: 1.0467046	total: 3.29s	remaining: 287ms
# 92:	learn: 1.0355114	total: 3.35s	remaining: 252ms
# 93:	learn: 1.0286418	total: 3.42s	remaining: 218ms
# 94:	learn: 1.0105553	total: 3.47s	remaining: 183ms
# 95:	learn: 0.9943135	total: 3.54s	remaining: 147ms
# 96:	learn: 0.9780521	total: 3.59s	remaining: 111ms
# 97:	learn: 0.9670315	total: 3.65s	remaining: 74.5ms
# 98:	learn: 0.9533914	total: 3.71s	remaining: 37.4ms
# 99:	learn: 0.9433600	total: 3.77s	remaining: 0us
# 0:	learn: 11.4181506	total: 5.1ms	remaining: 505ms
# 1:	learn: 10.7066774	total: 11.1ms	remaining: 546ms
# 2:	learn: 10.1345493	total: 18.1ms	remaining: 586ms
# 3:	learn: 9.5174119	total: 25.5ms	remaining: 613ms
# 4:	learn: 8.9894474	total: 32.7ms	remaining: 621ms
# 5:	learn: 8.5369318	total: 40.9ms	remaining: 641ms
# 6:	learn: 8.1410287	total: 48.8ms	remaining: 648ms
# 7:	learn: 7.7032202	total: 59.3ms	remaining: 682ms
# 8:	learn: 7.2940469	total: 69ms	remaining: 698ms
# 9:	learn: 6.9708316	total: 74.9ms	remaining: 675ms
# 10:	learn: 6.6447825	total: 82.9ms	remaining: 671ms
# 11:	learn: 6.3701360	total: 93.2ms	remaining: 684ms
# 12:	learn: 6.0846037	total: 99.8ms	remaining: 668ms
# 13:	learn: 5.7859816	total: 108ms	remaining: 661ms
# 14:	learn: 5.5225770	total: 116ms	remaining: 657ms
# 15:	learn: 5.3112145	total: 125ms	remaining: 657ms
# 16:	learn: 5.0911303	total: 145ms	remaining: 708ms
# 17:	learn: 4.8555598	total: 156ms	remaining: 711ms
# 18:	learn: 4.7015779	total: 162ms	remaining: 690ms
# 19:	learn: 4.5353605	total: 168ms	remaining: 673ms
# 20:	learn: 4.4213148	total: 179ms	remaining: 673ms
# 21:	learn: 4.2830971	total: 186ms	remaining: 659ms
# 22:	learn: 4.1405617	total: 196ms	remaining: 656ms
# 23:	learn: 4.0340816	total: 205ms	remaining: 649ms
# 24:	learn: 3.9231504	total: 214ms	remaining: 642ms
# 25:	learn: 3.8091908	total: 223ms	remaining: 634ms
# 26:	learn: 3.7093867	total: 226ms	remaining: 612ms
# 27:	learn: 3.5846056	total: 233ms	remaining: 598ms
# 28:	learn: 3.4448638	total: 242ms	remaining: 592ms
# 29:	learn: 3.3436639	total: 252ms	remaining: 587ms
# 30:	learn: 3.2826352	total: 259ms	remaining: 576ms
# 31:	learn: 3.1795774	total: 266ms	remaining: 566ms
# 32:	learn: 3.1064841	total: 276ms	remaining: 561ms
# 33:	learn: 3.0106739	total: 284ms	remaining: 551ms
# 34:	learn: 2.9366715	total: 293ms	remaining: 544ms
# 35:	learn: 2.8669443	total: 302ms	remaining: 537ms
# 36:	learn: 2.8192232	total: 313ms	remaining: 532ms
# 37:	learn: 2.7534041	total: 323ms	remaining: 527ms
# 38:	learn: 2.6827673	total: 333ms	remaining: 521ms
# 39:	learn: 2.6390516	total: 342ms	remaining: 512ms
# 40:	learn: 2.5908817	total: 352ms	remaining: 506ms
# 41:	learn: 2.5354902	total: 361ms	remaining: 499ms
# 42:	learn: 2.5027907	total: 372ms	remaining: 493ms
# 43:	learn: 2.4278013	total: 376ms	remaining: 478ms
# 44:	learn: 2.4041135	total: 381ms	remaining: 466ms
# 45:	learn: 2.3607512	total: 390ms	remaining: 458ms
# 46:	learn: 2.3237059	total: 398ms	remaining: 449ms
# 47:	learn: 2.2828358	total: 408ms	remaining: 442ms
# 48:	learn: 2.2417588	total: 418ms	remaining: 435ms
# 49:	learn: 2.2089302	total: 428ms	remaining: 428ms
# 50:	learn: 2.1722087	total: 437ms	remaining: 420ms
# 51:	learn: 2.1247079	total: 446ms	remaining: 412ms
# 52:	learn: 2.1143350	total: 457ms	remaining: 405ms
# 53:	learn: 2.0783445	total: 467ms	remaining: 398ms
# 54:	learn: 2.0453730	total: 476ms	remaining: 390ms
# 55:	learn: 2.0243811	total: 487ms	remaining: 382ms
# 56:	learn: 2.0011748	total: 496ms	remaining: 374ms
# 57:	learn: 1.9710909	total: 507ms	remaining: 367ms
# 58:	learn: 1.9409631	total: 517ms	remaining: 359ms
# 59:	learn: 1.9237479	total: 529ms	remaining: 352ms
# 60:	learn: 1.9037850	total: 537ms	remaining: 343ms
# 61:	learn: 1.8864462	total: 546ms	remaining: 335ms
# 62:	learn: 1.8713099	total: 555ms	remaining: 326ms
# 63:	learn: 1.8374660	total: 565ms	remaining: 318ms
# 64:	learn: 1.8219547	total: 574ms	remaining: 309ms
# 65:	learn: 1.8072265	total: 585ms	remaining: 301ms
# 66:	learn: 1.7820926	total: 594ms	remaining: 292ms
# 67:	learn: 1.7562645	total: 605ms	remaining: 285ms
# 68:	learn: 1.7257604	total: 613ms	remaining: 275ms
# 69:	learn: 1.7008765	total: 623ms	remaining: 267ms
# 70:	learn: 1.6808291	total: 632ms	remaining: 258ms
# 71:	learn: 1.6540034	total: 642ms	remaining: 250ms
# 72:	learn: 1.6271916	total: 652ms	remaining: 241ms
# 73:	learn: 1.6085341	total: 661ms	remaining: 232ms
# 74:	learn: 1.5965425	total: 671ms	remaining: 224ms
# 75:	learn: 1.5665020	total: 681ms	remaining: 215ms
# 76:	learn: 1.5440714	total: 691ms	remaining: 206ms
# 77:	learn: 1.5251415	total: 700ms	remaining: 197ms
# 78:	learn: 1.5163922	total: 710ms	remaining: 189ms
# 79:	learn: 1.5090727	total: 722ms	remaining: 181ms
# 80:	learn: 1.4994800	total: 732ms	remaining: 172ms
# 81:	learn: 1.4872233	total: 741ms	remaining: 163ms
# 82:	learn: 1.4653922	total: 751ms	remaining: 154ms
# 83:	learn: 1.4443852	total: 761ms	remaining: 145ms
# 84:	learn: 1.4380498	total: 775ms	remaining: 137ms
# 85:	learn: 1.4312507	total: 784ms	remaining: 128ms
# 86:	learn: 1.4155750	total: 794ms	remaining: 119ms
# 87:	learn: 1.4117828	total: 804ms	remaining: 110ms
# 88:	learn: 1.3968724	total: 814ms	remaining: 101ms
# 89:	learn: 1.3776106	total: 824ms	remaining: 91.5ms
# 90:	learn: 1.3724604	total: 833ms	remaining: 82.4ms
# 91:	learn: 1.3594689	total: 844ms	remaining: 73.4ms
# 92:	learn: 1.3422717	total: 853ms	remaining: 64.2ms
# 93:	learn: 1.3221721	total: 863ms	remaining: 55.1ms
# 94:	learn: 1.3087952	total: 871ms	remaining: 45.8ms
# 95:	learn: 1.2879923	total: 875ms	remaining: 36.5ms
# 96:	learn: 1.2729858	total: 881ms	remaining: 27.3ms
# 97:	learn: 1.2617511	total: 890ms	remaining: 18.2ms
# 98:	learn: 1.2435063	total: 901ms	remaining: 9.11ms
# 99:	learn: 1.2342354	total: 913ms	remaining: 0us
# 0:	learn: 11.4181506	total: 6.84ms	remaining: 678ms
# 1:	learn: 10.7066774	total: 16.7ms	remaining: 821ms
# 2:	learn: 10.1345493	total: 24.1ms	remaining: 781ms
# 3:	learn: 9.5174119	total: 30.5ms	remaining: 731ms
# 4:	learn: 8.9894474	total: 38.2ms	remaining: 726ms
# 5:	learn: 8.5369318	total: 48.7ms	remaining: 763ms
# 6:	learn: 8.1410287	total: 57.9ms	remaining: 770ms
# 7:	learn: 7.7032202	total: 61.9ms	remaining: 712ms
# 8:	learn: 7.2940469	total: 69.7ms	remaining: 705ms
# 9:	learn: 6.9708316	total: 74.3ms	remaining: 669ms
# 10:	learn: 6.6447825	total: 78.7ms	remaining: 637ms
# 11:	learn: 6.3701360	total: 82.8ms	remaining: 607ms
# 12:	learn: 6.0846037	total: 87ms	remaining: 582ms
# 13:	learn: 5.7859816	total: 91.3ms	remaining: 561ms
# 14:	learn: 5.5225770	total: 95.3ms	remaining: 540ms
# 15:	learn: 5.3112145	total: 99ms	remaining: 520ms
# 16:	learn: 5.0911303	total: 103ms	remaining: 503ms
# 17:	learn: 4.8555598	total: 111ms	remaining: 504ms
# 18:	learn: 4.7015779	total: 114ms	remaining: 486ms
# 19:	learn: 4.5353605	total: 119ms	remaining: 475ms
# 20:	learn: 4.4213148	total: 124ms	remaining: 465ms
# 21:	learn: 4.2830971	total: 128ms	remaining: 453ms
# 22:	learn: 4.1405617	total: 132ms	remaining: 443ms
# 23:	learn: 4.0340816	total: 137ms	remaining: 433ms
# 24:	learn: 3.9231504	total: 142ms	remaining: 425ms
# 25:	learn: 3.8091908	total: 149ms	remaining: 423ms
# 26:	learn: 3.7093867	total: 153ms	remaining: 413ms
# 27:	learn: 3.5846056	total: 157ms	remaining: 404ms
# 28:	learn: 3.4448638	total: 163ms	remaining: 399ms
# 29:	learn: 3.3436639	total: 170ms	remaining: 398ms
# 30:	learn: 3.2826352	total: 176ms	remaining: 392ms
# 31:	learn: 3.1795774	total: 184ms	remaining: 392ms
# 32:	learn: 3.1064841	total: 194ms	remaining: 393ms
# 33:	learn: 3.0106739	total: 203ms	remaining: 395ms
# 34:	learn: 2.9366715	total: 211ms	remaining: 393ms
# 35:	learn: 2.8669443	total: 222ms	remaining: 394ms
# 36:	learn: 2.8192232	total: 230ms	remaining: 392ms
# 37:	learn: 2.7534041	total: 239ms	remaining: 390ms
# 38:	learn: 2.6827673	total: 248ms	remaining: 387ms
# 39:	learn: 2.6390516	total: 256ms	remaining: 385ms
# 40:	learn: 2.5908817	total: 265ms	remaining: 381ms
# 41:	learn: 2.5354902	total: 274ms	remaining: 379ms
# 42:	learn: 2.5027907	total: 285ms	remaining: 377ms
# 43:	learn: 2.4278013	total: 293ms	remaining: 372ms
# 44:	learn: 2.4041135	total: 301ms	remaining: 367ms
# 45:	learn: 2.3607512	total: 310ms	remaining: 363ms
# 46:	learn: 2.3237059	total: 319ms	remaining: 360ms
# 47:	learn: 2.2828358	total: 328ms	remaining: 356ms
# 48:	learn: 2.2417588	total: 339ms	remaining: 353ms
# 49:	learn: 2.2089302	total: 347ms	remaining: 347ms
# 50:	learn: 2.1722087	total: 355ms	remaining: 341ms
# 51:	learn: 2.1247079	total: 365ms	remaining: 337ms
# 52:	learn: 2.1143350	total: 376ms	remaining: 333ms
# 53:	learn: 2.0783445	total: 386ms	remaining: 328ms
# 54:	learn: 2.0453730	total: 394ms	remaining: 323ms
# 55:	learn: 2.0243811	total: 405ms	remaining: 318ms
# 56:	learn: 2.0011748	total: 414ms	remaining: 312ms
# 57:	learn: 1.9710909	total: 421ms	remaining: 305ms
# 58:	learn: 1.9409631	total: 425ms	remaining: 295ms
# 59:	learn: 1.9237479	total: 431ms	remaining: 288ms
# 60:	learn: 1.9037850	total: 442ms	remaining: 283ms
# 61:	learn: 1.8864462	total: 451ms	remaining: 276ms
# 62:	learn: 1.8713099	total: 457ms	remaining: 269ms
# 63:	learn: 1.8374660	total: 466ms	remaining: 262ms
# 64:	learn: 1.8219547	total: 474ms	remaining: 255ms
# 65:	learn: 1.8072265	total: 484ms	remaining: 249ms
# 66:	learn: 1.7820926	total: 493ms	remaining: 243ms
# 67:	learn: 1.7562645	total: 502ms	remaining: 236ms
# 68:	learn: 1.7257604	total: 512ms	remaining: 230ms
# 69:	learn: 1.7008765	total: 522ms	remaining: 224ms
# 70:	learn: 1.6808291	total: 530ms	remaining: 217ms
# 71:	learn: 1.6540034	total: 540ms	remaining: 210ms
# 72:	learn: 1.6271916	total: 550ms	remaining: 203ms
# 73:	learn: 1.6085341	total: 559ms	remaining: 196ms
# 74:	learn: 1.5965425	total: 569ms	remaining: 190ms
# 75:	learn: 1.5665020	total: 579ms	remaining: 183ms
# 76:	learn: 1.5440714	total: 588ms	remaining: 176ms
# 77:	learn: 1.5251415	total: 600ms	remaining: 169ms
# 78:	learn: 1.5163922	total: 607ms	remaining: 161ms
# 79:	learn: 1.5090727	total: 612ms	remaining: 153ms
# 80:	learn: 1.4994800	total: 621ms	remaining: 146ms
# 81:	learn: 1.4872233	total: 630ms	remaining: 138ms
# 82:	learn: 1.4653922	total: 643ms	remaining: 132ms
# 83:	learn: 1.4443852	total: 651ms	remaining: 124ms
# 84:	learn: 1.4380498	total: 660ms	remaining: 116ms
# 85:	learn: 1.4312507	total: 670ms	remaining: 109ms
# 86:	learn: 1.4155750	total: 680ms	remaining: 102ms
# 87:	learn: 1.4117828	total: 688ms	remaining: 93.8ms
# 88:	learn: 1.3968724	total: 697ms	remaining: 86.2ms
# 89:	learn: 1.3776106	total: 705ms	remaining: 78.3ms
# 90:	learn: 1.3724604	total: 716ms	remaining: 70.8ms
# 91:	learn: 1.3594689	total: 726ms	remaining: 63.1ms
# 92:	learn: 1.3422717	total: 735ms	remaining: 55.3ms
# 93:	learn: 1.3221721	total: 739ms	remaining: 47.2ms
# 94:	learn: 1.3087952	total: 747ms	remaining: 39.3ms
# 95:	learn: 1.2879923	total: 757ms	remaining: 31.5ms
# 96:	learn: 1.2729858	total: 765ms	remaining: 23.7ms
# 97:	learn: 1.2617511	total: 772ms	remaining: 15.8ms
# 98:	learn: 1.2435063	total: 781ms	remaining: 7.89ms
# 99:	learn: 1.2342354	total: 788ms	remaining: 0us
#                    Model  Train R2 Score  Test R2 Score         MSE        MAE
# 0          Random Forest        0.996672       0.975889    3.245464   0.938181
# 1          Decision Tree        1.000000      -0.659070  223.317708  10.333333
# 2      Gradient Boosting        0.989949       0.934133    8.865975   1.923018
# 3      Linear Regression        0.591967       0.616776   51.583482   5.628918
# 4           XGBRegressor        0.999692       0.992075    1.066758   0.657959
# 5  CatBoosting Regressor        0.989774       0.971099    3.890196   1.355197
# 6     AdaBoost Regressor        0.919371       0.896853   13.884042   2.685375
# Final Best Model after Fine-tune with Hyper Paramaters
# (0.9996916989305938, 0.9920748532187741, 1.0667575632145592, 0.6579587509495468)

# %% [markdown]
# ## **Push to github**

# %%
# !git config --global user.email "ehthanhtruc@gmail.com"
# !git config --global user.name "truc-nmt"

# %% [markdown]
# <a href="https://colab.research.google.com/github/truc-nmt/tiki_discount_rate/blob/main/notebooks/4.%20Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 4: Modeling - TrucNMT**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install dill catboost xgboost

# %%
import os
import sys
import pandas as pd
import numpy as np
from dataclasses import dataclass

# Packages for logger
import logging
from datetime import datetime

# Packages for model evaluation
import dill
import pickle
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GridSearchCV, train_test_split


# Packages for data transformation
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder

# Packages for data transformation
from catboost import CatBoostRegressor
from sklearn.ensemble import (
    AdaBoostRegressor,
    GradientBoostingRegressor,
    RandomForestRegressor
)

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score, f1_score, recall_score, precision_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %% [markdown]
# ## **Logger**

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
logs_path = os.path.join(os.getcwd(), "logs", LOG_FILE)
os.makedirs(logs_path, exist_ok=True)

LOG_FILE_PATH = os.path.join(logs_path, LOG_FILE)

logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(lineno)d %(name)s - %(levelname)s - %(message)s",
    level=logging.INFO,
)

# %% [markdown]
# ## **Exception**

# %%
def error_message_detail(error, error_detail:sys):

    _, _, exc_tb = error_detail.exc_info()          # Get info about traceback(Info about error position)
    file_name = exc_tb.tb_frame.f_code.co_filename  # Get name of file script Python from "exc_tb"
    error_message="Error occured in python script name [{0}] line number [{1}] error message[{2}]".format(
    file_name,exc_tb.tb_lineno,str(error))

    return error_message


class CustomException(Exception):

    def __init__(self, error_message, error_detail:sys):
        super().__init__(error_message)
        self.error_message = error_message_detail(error_message, error_detail=error_detail)

    def __str__(self):
        return self.error_message

# %% [markdown]
# ## **Utils**

# %%
def save_object(file_path, obj):
    try:
        dir_path = os.path.dirname(file_path) #  is used to get the directory path of the file_path.
        os.makedirs(dir_path, exist_ok=True)

        with open(file_path, "wb") as file_obj:
            pickle.dump(obj, file_obj)

    except Exception as e:
        raise CustomException(e, sys)


def load_object(file_path):
    try:
        with open(file_path, "rb") as file_obj:
            return pickle.load(file_obj)

    except Exception as e:
        raise CustomException(e, sys)

def evaluate_models(X_train, y_train, X_test, y_test, models, param):
    try:
        report = {}

        for model_name, model in models.items():
            para = param[model_name]

            gs = GridSearchCV(model, para, cv=3)
            gs.fit(X_train, y_train)

            model.set_params(**gs.best_params_)
            model.fit(X_train, y_train)

            y_train_pred = model.predict(X_train)
            y_test_pred = model.predict(X_test)

            train_r2_score = r2_score(y_train, y_train_pred)
            test_r2_score = r2_score(y_test, y_test_pred)
            mse = mean_squared_error(y_test, y_test_pred)
            mae = mean_absolute_error(y_test, y_test_pred)

            report[model_name] = (train_r2_score, test_r2_score, mse, mae)

        return report

    except Exception as e:
        raise CustomException(e, sys)

# %% [markdown]
# ##**1. Data Ingestion**

# %%
@dataclass
class DataIngestionConfig:
    train_path: str = os.path.join('/content/data', 'train.csv')
    test_path: str = os.path.join('/content/data', 'test.csv')
    raw_path: str = os.path.join('/content/data', 'raw.csv')

class DataIngestion:

    def __init__(self):
        self.ingestion_config = DataIngestionConfig()

    def initiate_data_ingestion(self):
        logging.info("Entered the data ingestion method or component")

        try:
            df = pd.read_csv('/content/Data_Tiki_Cleaned.csv')
            logging.info("Read the dataset as dataframe")

            os.makedirs(os.path.dirname(self.ingestion_config.train_path), exist_ok= True)

            df.to_csv(self.ingestion_config.raw_path, index = False, header = True)

            logging.info("Train test split initiated")

            # Make dataset
            train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
            train_set.to_csv(self.ingestion_config.train_path, index = False, header = True)
            test_set.to_csv(self.ingestion_config.test_path, index = False, header = True)


            logging.info("Data Ingestion Completed!")

            return(
                self.ingestion_config.train_path,
                self.ingestion_config.test_path,
            )

        except Exception as e:
            raise CustomException(e, sys)

# %% [markdown]
# ##**2. Data Transformation**

# %%
class MultiColumnLabelEncoder:

    def __init__(self, columns=None):
        self.columns = columns if columns else []

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_ = X.copy()
        for col in self.columns:
            le = LabelEncoder()
            X_[col] = le.fit_transform(X_[col])
        return X_

    def fit_transform(self, X, y=None):
        return self.fit(X).transform(X)

@dataclass
class DataTransformationConfig:
    preprocessor_obj_file_path = os.path.join("data", "preprocessor.pkl")

class DataTransformation:

    def __init__(self):
        self.data_transformation_config = DataTransformationConfig()

    def get_data_transformation_object(self):
        '''

        This function is responsible for data transformation

        '''

        '''
            Information of columns data types after cleaned and filled null values!
            RangeIndex: 1916 entries, 0 to 1915
            Data columns (total 24 columns):
            #   Column             Non-Null Count  Dtype
            ---  ------             --------------  -----
            0   Name               1916 non-null   object
            1   Link Product       1916 non-null   object
            2   Store              1916 non-null   object
            3   Type               1916 non-null   object
            4   Author Name        1916 non-null   object
            5   Short Description  1916 non-null   object
            6   Publisher          1916 non-null   object
            7   Translators        1916 non-null   object
            8   Categories         1916 non-null   object
            9   Width              1916 non-null   float64
            10  Length             1916 non-null   float64
            11  Height             1916 non-null   float64
            12  Product ID         1916 non-null   int64
            13  Price              1916 non-null   int64
            14  Original Price     1916 non-null   int64
            15  Discount           1916 non-null   int64
            16  Discount Rate      1916 non-null   int64
            17  Rating             1916 non-null   float64
            18  Review Count       1916 non-null   int64
            19  Quantity Sold      1916 non-null   float64
            20  Number of page     1916 non-null   float64
            21  Range Price        1916 non-null   object
            22  Publication Date   1916 non-null   object
            23  Publication Year   1916 non-null   float64
            dtypes: float64(7), int64(6), object(11)
        '''
        try:

            # numerical_columns = df.select_dtypes(include=['number']).columns.tolist()

            numerical_columns = [
                                'Width',
                                'Length',
                                'Height',
                                'Product_ID',
                                'Price',
                                'Original_Price',
                                'Discount',
                                # 'Discount_Rate', # target
                                'Rating',
                                'Review_Count',
                                'Quantity_Sold',
                                'Number_of_page',
                                'Publication_Year'
                                ]
            # categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
            categorical_columns = [
                                'Store',
                                'Type',
                                'Author_Name',
                                'Publisher',
                                'Translators',
                                'Categories',
                                'Range_Price',
                            ]

            # Pipeline

            num_pipeline = Pipeline(
                steps = [
                    # ("imputer", SimpleImputer(strategy="median")),
                    ("scaler", StandardScaler())
                ]
            )

            cate_pipeline = Pipeline(
                steps=[
                    ("label_encoder", MultiColumnLabelEncoder(columns=categorical_columns)),
                    ("scaler", StandardScaler(with_mean=False))
                ]
            )

            # Log info

            logging.info(f"Categorical columns: {categorical_columns}")
            logging.info(f"Numerical columns: {numerical_columns}")

            # Preprocessor

            preprocessor = ColumnTransformer(
                [
                    ("num_pipeline", num_pipeline, numerical_columns),
                    ("cate_pipeline", cate_pipeline, categorical_columns),
                ]
            )

            return preprocessor

        except Exception as e:
            raise CustomException(e, sys)

    def initiate_data_transformation(self, train_path, test_path):

        try:
            train_df = pd.read_csv(train_path)
            test_df = pd.read_csv(test_path)

            # print(train_df.columns)
            # print(test_df.columns)

            logging.info("read train and test data completed!")
            logging.info("Obtaining preprocessing object")

            preprocessing_obj = self.get_data_transformation_object()

            target_column_name = "Discount_Rate"
            numerical_columns = train_df.select_dtypes(include=['number']).columns.tolist()
            # print(numerical_columns)


            input_feature_train_df = train_df.drop(columns=[target_column_name], axis = 1)
            # print(input_feature_train_df.info)
            target_feature_train_df = train_df[target_column_name]

            input_feature_test_df = test_df.drop(columns=[target_column_name], axis = 1)
            target_feature_test_df = test_df[target_column_name]

            logging.info(f"Applying preprocessing object on training dataframe and testing dataframe")

            input_feature_train_arr = preprocessing_obj.fit_transform(input_feature_train_df)
            input_feature_test_arr = preprocessing_obj.transform(input_feature_test_df)

            train_arr = np.c_[input_feature_train_arr, np.array(target_feature_train_df)]
            test_arr = np.c_[input_feature_test_arr, np.array(target_feature_test_df)]

            logging.info(f"Saved preprocessing object.")

            save_object(
                file_path= self.data_transformation_config.preprocessor_obj_file_path,
                obj=preprocessing_obj
            )

            return(train_arr, test_arr, self.data_transformation_config.preprocessor_obj_file_path)

        except Exception as e:
            raise CustomException(e, sys)

# %% [markdown]
# ##**3. Model Trainer**

# %%
@dataclass
class ModelTrainerConfig:
    train_model_file_path = os.path.join("models", "model.pkl")


class ModelTrainer:

    def __init__(self):
        self.model_trainer_config = ModelTrainerConfig()


    def initiate_model_trainer(self, train_array, test_array):
        try:
            logging.info("Splitting training and test input data")
            X_train, y_train, X_test, y_test = (
                train_array[:, :-1],
                train_array[:, -1],
                test_array[:, :-1],
                test_array[:, -1]
            )

            models = {
                "Random Forest": RandomForestRegressor(),
                "Decision Tree": DecisionTreeRegressor(),
                "Gradient Boosting": GradientBoostingRegressor(),
                "Linear Regression": LinearRegression(),
                "XGBRegressor": XGBRegressor(),
                "CatBoosting Regressor": CatBoostRegressor(verbose=True),
                "AdaBoost Regressor": AdaBoostRegressor(),
            }

            # Fine-tune Hyper Parameter
            params = {
                "Decision Tree": {
                    'criterion': ['poisson', 'absolute_error', 'friedman_mse', 'squared_error'],
                    'splitter': ['best', 'random'],
                    'max_features': ['sqrt', 'log2'],
                },
                "Random Forest": {
                    'criterion': ['squared_error', 'friedman_mse', 'poisson', 'absolute_error'],
                    'max_features': ['sqrt', 'log2', None],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                },
                "Gradient Boosting": {
                    'loss': ['squared_error', 'absolute_error', 'quantile', 'huber'],
                    'learning_rate': [0.1, 0.01, 0.05, 0.001],
                    'subsample': [0.6, 0.7, 0.75, 0.8, 0.85, 0.9],
                    'max_features': ['sqrt', 'log2'],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                },
                "Linear Regression": {},
                "XGBRegressor": {
                    'learning_rate': [0.1, 0.01, 0.05, 0.001],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                },
                "CatBoosting Regressor": {
                    'depth': [6, 8, 10],
                    'learning_rate': [0.01, 0.05, 0.1],
                    'iterations': [30, 50, 100]
                },
                "AdaBoost Regressor": {
                    'learning_rate': [0.1, 0.01, 0.5, 0.001],
                    'loss': ['linear', 'square', 'exponential'],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                }
            }

            model_report = evaluate_models(X_train, y_train, X_test, y_test, models, params)

            # Print all model results
            logging.info("Model results:")
            for model_name, scores in model_report.items():
                logging.info(f"{model_name}: Train R2 Score - {scores[0]}, Test R2 Score - {scores[1]}, MSE - {scores[2]}, MAE - {scores[3]}") # Save in log file
                print((f"{model_name}: Train R2 Score - {scores[0]}, Test R2 Score - {scores[1]}, MSE - {scores[2]}, MAE - {scores[3]}"))



            # Find the best model based on test R2 score
            best_model_name = max(model_report, key=lambda k: model_report[k][1])  # Choose based on test R2 score
            best_model_scores = model_report[best_model_name]

            # Check if the test R2 score of the best model meets the threshold
            if best_model_scores[1] < 0.6:
                raise CustomException("No best model found")

            # Retrieve the best model
            best_model = models[best_model_name]

            # Save the best model
            save_object(file_path=self.model_trainer_config.train_model_file_path, obj=best_model)

            # Return the test R2 score, MSE, and MAE of the best model
            print("Final Best Model after Fine-tune with Hyper Paramaters")
            return best_model_scores[1], best_model_scores[2], best_model_scores[3]

        except Exception as e:
            raise CustomException(e, sys)

# %% [markdown]
# ## **4. Results**

# %%
obj = DataIngestion()
train_data, test_data = obj.initiate_data_ingestion()

data_transformation = DataTransformation()
train_arr, test_arr, _ = data_transformation.initiate_data_transformation(train_data, test_data)

modeltrainer = ModelTrainer()
print(modeltrainer.initiate_model_trainer(train_arr, test_arr))
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# 9:	learn: 11.5660014	total: 34ms	remaining: 68ms
# 10:	learn: 11.4946196	total: 37.7ms	remaining: 65ms
# 11:	learn: 11.4207493	total: 41.4ms	remaining: 62.1ms
# 12:	learn: 11.3461089	total: 44.7ms	remaining: 58.4ms
# 13:	learn: 11.2666259	total: 48.1ms	remaining: 55ms
# 14:	learn: 11.1885251	total: 51.7ms	remaining: 51.7ms
# 15:	learn: 11.1209663	total: 55.2ms	remaining: 48.3ms
# 16:	learn: 11.0508081	total: 58.5ms	remaining: 44.8ms
# 17:	learn: 10.9822952	total: 62.1ms	remaining: 41.4ms
# 18:	learn: 10.9096954	total: 65.6ms	remaining: 38ms
# 19:	learn: 10.8414087	total: 69ms	remaining: 34.5ms
# 20:	learn: 10.7837768	total: 72.3ms	remaining: 31ms
# 21:	learn: 10.7162213	total: 75.7ms	remaining: 27.5ms
# 22:	learn: 10.6542976	total: 82.8ms	remaining: 25.2ms
# 23:	learn: 10.5938525	total: 87.6ms	remaining: 21.9ms
# 24:	learn: 10.5250411	total: 91.1ms	remaining: 18.2ms
# 25:	learn: 10.4568657	total: 94.4ms	remaining: 14.5ms
# 26:	learn: 10.3955711	total: 97.6ms	remaining: 10.8ms
# 27:	learn: 10.3337178	total: 101ms	remaining: 7.19ms
# 28:	learn: 10.2678682	total: 104ms	remaining: 3.59ms
# 29:	learn: 10.2094397	total: 107ms	remaining: 0us
# 0:	learn: 11.7371678	total: 3.31ms	remaining: 96.2ms
# 1:	learn: 11.4249029	total: 6.3ms	remaining: 88.2ms
# 2:	learn: 11.1255478	total: 9.55ms	remaining: 86ms
# 3:	learn: 10.7830159	total: 12.5ms	remaining: 81.5ms
# 4:	learn: 10.4746286	total: 15.7ms	remaining: 78.7ms
# 5:	learn: 10.1815730	total: 19.4ms	remaining: 77.5ms
# 6:	learn: 9.9226266	total: 22.9ms	remaining: 75.2ms
# 7:	learn: 9.6279769	total: 26.5ms	remaining: 72.8ms
# 8:	learn: 9.3410207	total: 29.9ms	remaining: 69.9ms
# 9:	learn: 9.1005872	total: 33.4ms	remaining: 66.8ms
# 10:	learn: 8.8600093	total: 36.8ms	remaining: 63.5ms
# 11:	learn: 8.6417687	total: 40.2ms	remaining: 60.3ms
# 12:	learn: 8.4021775	total: 43.6ms	remaining: 57ms
# 13:	learn: 8.1402440	total: 46.9ms	remaining: 53.6ms
# 14:	learn: 7.9172339	total: 50.3ms	remaining: 50.3ms
# 15:	learn: 7.7096108	total: 53.6ms	remaining: 46.9ms
# 16:	learn: 7.5069440	total: 56.9ms	remaining: 43.5ms
# 17:	learn: 7.3323124	total: 60ms	remaining: 40ms
# 18:	learn: 7.1727287	total: 63.3ms	remaining: 36.6ms
# 19:	learn: 6.9910156	total: 66.6ms	remaining: 33.3ms
# 20:	learn: 6.8637840	total: 69.8ms	remaining: 29.9ms
# 21:	learn: 6.7041921	total: 73ms	remaining: 26.5ms
# 22:	learn: 6.5773906	total: 76.3ms	remaining: 23.2ms
# 23:	learn: 6.4539426	total: 79.5ms	remaining: 19.9ms
# 24:	learn: 6.3011132	total: 82.8ms	remaining: 16.6ms
# 25:	learn: 6.1992023	total: 86.1ms	remaining: 13.2ms
# 26:	learn: 6.0862278	total: 91ms	remaining: 10.1ms
# 27:	learn: 5.9580580	total: 96.8ms	remaining: 6.91ms
# 28:	learn: 5.8214915	total: 100ms	remaining: 3.45ms
# 29:	learn: 5.6930476	total: 103ms	remaining: 0us
# 0:	learn: 11.7887853	total: 3.33ms	remaining: 96.7ms
# 1:	learn: 11.4084316	total: 7.52ms	remaining: 105ms
# 2:	learn: 11.1177022	total: 11.8ms	remaining: 106ms
# 3:	learn: 10.8110105	total: 15.4ms	remaining: 100ms
# 4:	learn: 10.4882965	total: 18.9ms	remaining: 94.6ms
# 5:	learn: 10.1995189	total: 24.1ms	remaining: 96.6ms
# 6:	learn: 9.9339889	total: 27.5ms	remaining: 90.4ms
# 7:	learn: 9.6349820	total: 30.9ms	remaining: 84.9ms
# 8:	learn: 9.3403122	total: 34.2ms	remaining: 79.7ms
# 9:	learn: 9.0948843	total: 37.5ms	remaining: 75ms
# 10:	learn: 8.8469038	total: 40.8ms	remaining: 70.5ms
# 11:	learn: 8.6140906	total: 45ms	remaining: 67.5ms
# 12:	learn: 8.3787208	total: 48.2ms	remaining: 63ms
# 13:	learn: 8.1270282	total: 51.7ms	remaining: 59.1ms
# 14:	learn: 7.8916450	total: 55.3ms	remaining: 55.3ms
# 15:	learn: 7.6699679	total: 58.8ms	remaining: 51.4ms
# 16:	learn: 7.4587531	total: 62.3ms	remaining: 47.6ms
# 17:	learn: 7.2695922	total: 65.8ms	remaining: 43.9ms
# 18:	learn: 7.0911534	total: 69.4ms	remaining: 40.2ms
# 19:	learn: 6.9403145	total: 72.9ms	remaining: 36.4ms
# 20:	learn: 6.7978286	total: 76.4ms	remaining: 32.7ms
# 21:	learn: 6.6818708	total: 79.8ms	remaining: 29ms
# 22:	learn: 6.5598187	total: 83.2ms	remaining: 25.3ms
# 23:	learn: 6.4164870	total: 86.6ms	remaining: 21.6ms
# 24:	learn: 6.3093439	total: 89.9ms	remaining: 18ms
# 25:	learn: 6.1923230	total: 93.3ms	remaining: 14.4ms
# 26:	learn: 6.0408143	total: 96.8ms	remaining: 10.8ms
# 27:	learn: 5.9315947	total: 100ms	remaining: 7.15ms
# 28:	learn: 5.8108461	total: 103ms	remaining: 3.57ms
# 29:	learn: 5.6661036	total: 107ms	remaining: 0us
# 0:	learn: 11.9262218	total: 3.31ms	remaining: 95.9ms
# 1:	learn: 11.5410284	total: 6.62ms	remaining: 92.7ms
# 2:	learn: 11.2162597	total: 10.8ms	remaining: 97ms
# 3:	learn: 10.8592516	total: 14.2ms	remaining: 92.2ms
# 4:	learn: 10.5250672	total: 17.5ms	remaining: 87.7ms
# 5:	learn: 10.2643689	total: 21ms	remaining: 84ms
# 6:	learn: 9.9936870	total: 24.4ms	remaining: 80ms
# 7:	learn: 9.6832311	total: 30.4ms	remaining: 83.7ms
# 8:	learn: 9.4134625	total: 33.4ms	remaining: 78ms
# 9:	learn: 9.1591485	total: 36.6ms	remaining: 73.1ms
# 10:	learn: 8.9008568	total: 39.8ms	remaining: 68.7ms
# 11:	learn: 8.6623901	total: 43.1ms	remaining: 64.6ms
# 12:	learn: 8.4095659	total: 51.5ms	remaining: 67.3ms
# 13:	learn: 8.1444580	total: 54.9ms	remaining: 62.7ms
# 14:	learn: 7.9132616	total: 58.4ms	remaining: 58.4ms
# 15:	learn: 7.7263389	total: 61.8ms	remaining: 54.1ms
# 16:	learn: 7.5375652	total: 65.3ms	remaining: 49.9ms
# 17:	learn: 7.3497801	total: 68.6ms	remaining: 45.7ms
# 18:	learn: 7.1481795	total: 72.1ms	remaining: 41.8ms
# 19:	learn: 6.9731763	total: 75.8ms	remaining: 37.9ms
# 20:	learn: 6.8453100	total: 79.1ms	remaining: 33.9ms
# 21:	learn: 6.6764946	total: 82.2ms	remaining: 29.9ms
# 22:	learn: 6.5442900	total: 85.5ms	remaining: 26ms
# 23:	learn: 6.3783528	total: 88.8ms	remaining: 22.2ms
# 24:	learn: 6.2399800	total: 92.1ms	remaining: 18.4ms
# 25:	learn: 6.1100955	total: 95.4ms	remaining: 14.7ms
# 26:	learn: 5.9911095	total: 98.8ms	remaining: 11ms
# 27:	learn: 5.8734647	total: 102ms	remaining: 7.29ms
# 28:	learn: 5.7489487	total: 106ms	remaining: 3.64ms
# 29:	learn: 5.6197717	total: 109ms	remaining: 0us
# 0:	learn: 11.3553705	total: 5.76ms	remaining: 167ms
# 1:	learn: 10.7727863	total: 9.18ms	remaining: 128ms
# 2:	learn: 10.2425768	total: 13.2ms	remaining: 119ms
# 3:	learn: 9.6400848	total: 16.9ms	remaining: 110ms
# 4:	learn: 9.1411460	total: 20.4ms	remaining: 102ms
# 5:	learn: 8.6871315	total: 23.8ms	remaining: 95.1ms
# 6:	learn: 8.3131782	total: 27.2ms	remaining: 89.4ms
# 7:	learn: 7.8670826	total: 30.6ms	remaining: 84ms
# 8:	learn: 7.5010069	total: 34ms	remaining: 79.3ms
# 9:	learn: 7.1843051	total: 37.3ms	remaining: 74.5ms
# 10:	learn: 6.9251572	total: 40.7ms	remaining: 70.3ms
# 11:	learn: 6.6599581	total: 45.8ms	remaining: 68.7ms
# 12:	learn: 6.3624899	total: 49.2ms	remaining: 64.4ms
# 13:	learn: 6.0539288	total: 52.7ms	remaining: 60.3ms
# 14:	learn: 5.7690878	total: 56.4ms	remaining: 56.4ms
# 15:	learn: 5.5587055	total: 59.3ms	remaining: 51.9ms
# 16:	learn: 5.3336201	total: 62.7ms	remaining: 47.9ms
# 17:	learn: 5.1402284	total: 66.5ms	remaining: 44.3ms
# 18:	learn: 4.9690087	total: 70ms	remaining: 40.6ms
# 19:	learn: 4.8262016	total: 73.6ms	remaining: 36.8ms
# 20:	learn: 4.7255142	total: 77.1ms	remaining: 33ms
# 21:	learn: 4.5957024	total: 80.4ms	remaining: 29.3ms
# 22:	learn: 4.4880693	total: 83.7ms	remaining: 25.5ms
# 23:	learn: 4.3995372	total: 87ms	remaining: 21.8ms
# 24:	learn: 4.2913804	total: 90.5ms	remaining: 18.1ms
# 25:	learn: 4.1886451	total: 95.2ms	remaining: 14.6ms
# 26:	learn: 4.1193525	total: 101ms	remaining: 11.2ms
# 27:	learn: 4.0066093	total: 104ms	remaining: 7.44ms
# 28:	learn: 3.9017326	total: 108ms	remaining: 3.71ms
# 29:	learn: 3.7851406	total: 111ms	remaining: 0us
# 0:	learn: 11.4211024	total: 3.2ms	remaining: 92.9ms
# 1:	learn: 10.6980587	total: 6.37ms	remaining: 89.2ms
# 2:	learn: 10.1778914	total: 9.52ms	remaining: 85.7ms
# 3:	learn: 9.5669097	total: 13ms	remaining: 84.3ms
# 4:	learn: 9.0402591	total: 16.5ms	remaining: 82.4ms
# 5:	learn: 8.5351592	total: 19.9ms	remaining: 79.5ms
# 6:	learn: 8.1500808	total: 23.4ms	remaining: 76.9ms
# 7:	learn: 7.7125359	total: 26.9ms	remaining: 74ms
# 8:	learn: 7.3056745	total: 30.4ms	remaining: 71ms
# 9:	learn: 7.0012815	total: 33.8ms	remaining: 67.6ms
# 10:	learn: 6.6799951	total: 37.1ms	remaining: 64.1ms
# 11:	learn: 6.4134038	total: 40.4ms	remaining: 60.5ms
# 12:	learn: 6.1325495	total: 43.7ms	remaining: 57.1ms
# 13:	learn: 5.8293081	total: 47.2ms	remaining: 53.9ms
# 14:	learn: 5.6035109	total: 50.4ms	remaining: 50.4ms
# 15:	learn: 5.4180202	total: 53.8ms	remaining: 47.1ms
# 16:	learn: 5.2247342	total: 57ms	remaining: 43.6ms
# 17:	learn: 5.0468601	total: 60.1ms	remaining: 40.1ms
# 18:	learn: 4.8909254	total: 63.3ms	remaining: 36.7ms
# 19:	learn: 4.6817153	total: 66.7ms	remaining: 33.3ms
# 20:	learn: 4.5836675	total: 70ms	remaining: 30ms
# 21:	learn: 4.3961353	total: 74.5ms	remaining: 27.1ms
# 22:	learn: 4.2983973	total: 78.2ms	remaining: 23.8ms
# 23:	learn: 4.1740758	total: 81.7ms	remaining: 20.4ms
# 24:	learn: 4.0767632	total: 85.4ms	remaining: 17.1ms
# 25:	learn: 3.9686340	total: 88.8ms	remaining: 13.7ms
# 26:	learn: 3.8539033	total: 92.2ms	remaining: 10.2ms
# 27:	learn: 3.7678156	total: 95.6ms	remaining: 6.83ms
# 28:	learn: 3.6553975	total: 99.1ms	remaining: 3.42ms
# 29:	learn: 3.5509880	total: 103ms	remaining: 0us
# 0:	learn: 11.5346453	total: 3.51ms	remaining: 102ms
# 1:	learn: 10.8050644	total: 7.15ms	remaining: 100ms
# 2:	learn: 10.2269850	total: 10.6ms	remaining: 95.3ms
# 3:	learn: 9.6058770	total: 14.4ms	remaining: 93.7ms
# 4:	learn: 9.0683269	total: 17.9ms	remaining: 89.6ms
# 5:	learn: 8.5863208	total: 21.6ms	remaining: 86.4ms
# 6:	learn: 8.1906558	total: 25.6ms	remaining: 84.2ms
# 7:	learn: 7.7583650	total: 29.4ms	remaining: 80.7ms
# 8:	learn: 7.3474592	total: 32.9ms	remaining: 76.9ms
# 9:	learn: 7.0117595	total: 36.5ms	remaining: 73ms
# 10:	learn: 6.6841657	total: 40ms	remaining: 69.1ms
# 11:	learn: 6.3986390	total: 43.6ms	remaining: 65.4ms
# 12:	learn: 6.0707933	total: 47.3ms	remaining: 61.8ms
# 13:	learn: 5.7480267	total: 50.7ms	remaining: 58ms
# 14:	learn: 5.5112950	total: 54.1ms	remaining: 54.1ms
# 15:	learn: 5.2713682	total: 57.5ms	remaining: 50.3ms
# 16:	learn: 5.0695457	total: 61.6ms	remaining: 47.1ms
# 17:	learn: 4.8892269	total: 65.1ms	remaining: 43.4ms
# 18:	learn: 4.7035606	total: 68.6ms	remaining: 39.7ms
# 19:	learn: 4.5364614	total: 72.5ms	remaining: 36.3ms
# 20:	learn: 4.4089842	total: 76.1ms	remaining: 32.6ms
# 21:	learn: 4.2522490	total: 79.7ms	remaining: 29ms
# 22:	learn: 4.1467359	total: 83.2ms	remaining: 25.3ms
# 23:	learn: 4.0100055	total: 86.2ms	remaining: 21.6ms
# 24:	learn: 3.9082364	total: 89.7ms	remaining: 17.9ms
# 25:	learn: 3.7755290	total: 93.1ms	remaining: 14.3ms
# 26:	learn: 3.6794094	total: 96.5ms	remaining: 10.7ms
# 27:	learn: 3.6053269	total: 99.9ms	remaining: 7.13ms
# 28:	learn: 3.5119280	total: 103ms	remaining: 3.56ms
# 29:	learn: 3.4193710	total: 106ms	remaining: 0us
# 0:	learn: 12.0474412	total: 3.28ms	remaining: 161ms
# 1:	learn: 11.9717073	total: 7.1ms	remaining: 170ms
# 2:	learn: 11.9059822	total: 10.2ms	remaining: 159ms
# 3:	learn: 11.8289107	total: 13.2ms	remaining: 152ms
# 4:	learn: 11.7557857	total: 16.4ms	remaining: 147ms
# 5:	learn: 11.6845494	total: 20.1ms	remaining: 147ms
# 6:	learn: 11.6181709	total: 23.8ms	remaining: 146ms
# 7:	learn: 11.5403476	total: 27ms	remaining: 142ms
# 8:	learn: 11.4695802	total: 30.6ms	remaining: 139ms
# 9:	learn: 11.4015307	total: 34.4ms	remaining: 137ms
# 10:	learn: 11.3343708	total: 37.9ms	remaining: 134ms
# 11:	learn: 11.2648526	total: 41.5ms	remaining: 131ms
# 12:	learn: 11.1904938	total: 46ms	remaining: 131ms
# 13:	learn: 11.1149024	total: 52.7ms	remaining: 135ms
# 14:	learn: 11.0413905	total: 56.4ms	remaining: 132ms
# 15:	learn: 10.9743156	total: 59.9ms	remaining: 127ms
# 16:	learn: 10.9066946	total: 63.4ms	remaining: 123ms
# 17:	learn: 10.8406812	total: 66.9ms	remaining: 119ms
# 18:	learn: 10.7795569	total: 70.2ms	remaining: 115ms
# 19:	learn: 10.7188733	total: 73.6ms	remaining: 110ms
# 20:	learn: 10.6622903	total: 77ms	remaining: 106ms
# 21:	learn: 10.6064787	total: 80.5ms	remaining: 102ms
# 22:	learn: 10.5482488	total: 83.9ms	remaining: 98.5ms
# 23:	learn: 10.4850483	total: 87.4ms	remaining: 94.6ms
# 24:	learn: 10.4293920	total: 90.8ms	remaining: 90.8ms
# 25:	learn: 10.3637645	total: 94.3ms	remaining: 87ms
# 26:	learn: 10.3039968	total: 97.7ms	remaining: 83.3ms
# 27:	learn: 10.2391840	total: 101ms	remaining: 79.4ms
# 28:	learn: 10.1844578	total: 105ms	remaining: 75.9ms
# 29:	learn: 10.1269974	total: 108ms	remaining: 72.2ms
# 30:	learn: 10.0721983	total: 112ms	remaining: 68.5ms
# 31:	learn: 10.0174720	total: 115ms	remaining: 64.6ms
# 32:	learn: 9.9639640	total: 118ms	remaining: 61ms
# 33:	learn: 9.9109616	total: 122ms	remaining: 57.2ms
# 34:	learn: 9.8483429	total: 125ms	remaining: 53.6ms
# 35:	learn: 9.7961489	total: 130ms	remaining: 50.7ms
# 36:	learn: 9.7404011	total: 134ms	remaining: 46.9ms
# 37:	learn: 9.6847317	total: 137ms	remaining: 43.1ms
# 38:	learn: 9.6277063	total: 140ms	remaining: 39.4ms
# 39:	learn: 9.5708521	total: 143ms	remaining: 35.7ms
# 40:	learn: 9.5141396	total: 146ms	remaining: 32ms
# 41:	learn: 9.4626795	total: 149ms	remaining: 28.4ms
# 42:	learn: 9.4136052	total: 152ms	remaining: 24.7ms
# 43:	learn: 9.3557706	total: 155ms	remaining: 21.2ms
# 44:	learn: 9.3017360	total: 159ms	remaining: 17.7ms
# 45:	learn: 9.2464749	total: 163ms	remaining: 14.1ms
# 46:	learn: 9.1933727	total: 166ms	remaining: 10.6ms
# 47:	learn: 9.1429677	total: 170ms	remaining: 7.07ms
# 48:	learn: 9.0898165	total: 176ms	remaining: 3.58ms
# 49:	learn: 9.0317548	total: 191ms	remaining: 0us
# 0:	learn: 12.0876188	total: 3.32ms	remaining: 163ms
# 1:	learn: 12.0101542	total: 7.4ms	remaining: 178ms
# 2:	learn: 11.9462280	total: 10.9ms	remaining: 170ms
# 3:	learn: 11.8766055	total: 14.3ms	remaining: 164ms
# 4:	learn: 11.7993281	total: 17.7ms	remaining: 160ms
# 5:	learn: 11.7295218	total: 21.1ms	remaining: 155ms
# 6:	learn: 11.6623892	total: 24.6ms	remaining: 151ms
# 7:	learn: 11.5853543	total: 28ms	remaining: 147ms
# 8:	learn: 11.5049736	total: 31.4ms	remaining: 143ms
# 9:	learn: 11.4351770	total: 34.8ms	remaining: 139ms
# 10:	learn: 11.3609023	total: 38.4ms	remaining: 136ms
# 11:	learn: 11.2913618	total: 41.8ms	remaining: 132ms
# 12:	learn: 11.2213774	total: 45.2ms	remaining: 129ms
# 13:	learn: 11.1419547	total: 48.9ms	remaining: 126ms
# 14:	learn: 11.0666027	total: 52.5ms	remaining: 122ms
# 15:	learn: 11.0009093	total: 55.9ms	remaining: 119ms
# 16:	learn: 10.9378978	total: 59.2ms	remaining: 115ms
# 17:	learn: 10.8718306	total: 62.5ms	remaining: 111ms
# 18:	learn: 10.8025223	total: 66.1ms	remaining: 108ms
# 19:	learn: 10.7360424	total: 69.7ms	remaining: 105ms
# 20:	learn: 10.6792105	total: 73ms	remaining: 101ms
# 21:	learn: 10.6220447	total: 76.6ms	remaining: 97.5ms
# 22:	learn: 10.5552748	total: 79.9ms	remaining: 93.8ms
# 23:	learn: 10.4895436	total: 83.3ms	remaining: 90.2ms
# 24:	learn: 10.4331873	total: 86.7ms	remaining: 86.7ms
# 25:	learn: 10.3688947	total: 90.1ms	remaining: 83.2ms
# 26:	learn: 10.3134943	total: 93.5ms	remaining: 79.7ms
# 27:	learn: 10.2544168	total: 97.1ms	remaining: 76.3ms
# 28:	learn: 10.1934568	total: 101ms	remaining: 72.8ms
# 29:	learn: 10.1345617	total: 104ms	remaining: 69.6ms
# 30:	learn: 10.0823560	total: 108ms	remaining: 66.1ms
# 31:	learn: 10.0236730	total: 111ms	remaining: 62.6ms
# 32:	learn: 9.9669532	total: 115ms	remaining: 59.1ms
# 33:	learn: 9.9122968	total: 118ms	remaining: 55.7ms
# 34:	learn: 9.8490374	total: 122ms	remaining: 52.2ms
# 35:	learn: 9.7976747	total: 127ms	remaining: 49.5ms
# 36:	learn: 9.7365266	total: 131ms	remaining: 46ms
# 37:	learn: 9.6808952	total: 134ms	remaining: 42.5ms
# 38:	learn: 9.6215331	total: 138ms	remaining: 38.9ms
# 39:	learn: 9.5692442	total: 141ms	remaining: 35.3ms
# 40:	learn: 9.5095304	total: 145ms	remaining: 31.8ms
# 41:	learn: 9.4496014	total: 148ms	remaining: 28.3ms
# 42:	learn: 9.3972741	total: 152ms	remaining: 24.7ms
# 43:	learn: 9.3432035	total: 156ms	remaining: 21.3ms
# 44:	learn: 9.2920843	total: 161ms	remaining: 17.9ms
# 45:	learn: 9.2466171	total: 164ms	remaining: 14.3ms
# 46:	learn: 9.1962071	total: 168ms	remaining: 10.7ms
# 47:	learn: 9.1444185	total: 171ms	remaining: 7.14ms
# 48:	learn: 9.1008643	total: 175ms	remaining: 3.57ms
# 49:	learn: 9.0506506	total: 179ms	remaining: 0us
# 0:	learn: 12.2439202	total: 3.49ms	remaining: 171ms
# 1:	learn: 12.1636759	total: 7.37ms	remaining: 177ms
# 2:	learn: 12.0928441	total: 10.7ms	remaining: 168ms
# 3:	learn: 12.0126725	total: 14.2ms	remaining: 163ms
# 4:	learn: 11.9342153	total: 17.6ms	remaining: 158ms
# 5:	learn: 11.8698934	total: 20.9ms	remaining: 153ms
# 6:	learn: 11.8020036	total: 24.2ms	remaining: 149ms
# 7:	learn: 11.7200300	total: 27.6ms	remaining: 145ms
# 8:	learn: 11.6383024	total: 30.9ms	remaining: 141ms
# 9:	learn: 11.5660014	total: 34.5ms	remaining: 138ms
# 10:	learn: 11.4946196	total: 37.9ms	remaining: 134ms
# 11:	learn: 11.4207493	total: 41.3ms	remaining: 131ms
# 12:	learn: 11.3461089	total: 44.7ms	remaining: 127ms
# 13:	learn: 11.2666259	total: 48.3ms	remaining: 124ms
# 14:	learn: 11.1885251	total: 51.8ms	remaining: 121ms
# 15:	learn: 11.1209663	total: 55.7ms	remaining: 118ms
# 16:	learn: 11.0508081	total: 59.4ms	remaining: 115ms
# 17:	learn: 10.9822952	total: 62.9ms	remaining: 112ms
# 18:	learn: 10.9096954	total: 66.6ms	remaining: 109ms
# 19:	learn: 10.8414087	total: 70.1ms	remaining: 105ms
# 20:	learn: 10.7837768	total: 73.6ms	remaining: 102ms
# 21:	learn: 10.7162213	total: 77.5ms	remaining: 98.6ms
# 22:	learn: 10.6542976	total: 81.1ms	remaining: 95.2ms
# 23:	learn: 10.5938525	total: 84.9ms	remaining: 92ms
# 24:	learn: 10.5250411	total: 88.6ms	remaining: 88.6ms
# 25:	learn: 10.4568657	total: 92.1ms	remaining: 85.1ms
# 26:	learn: 10.3955711	total: 95.6ms	remaining: 81.4ms
# 27:	learn: 10.3337178	total: 99ms	remaining: 77.7ms
# 28:	learn: 10.2678682	total: 102ms	remaining: 74.2ms
# 29:	learn: 10.2094397	total: 106ms	remaining: 70.6ms
# 30:	learn: 10.1535152	total: 109ms	remaining: 66.9ms
# 31:	learn: 10.0918472	total: 113ms	remaining: 63.4ms
# 32:	learn: 10.0302151	total: 116ms	remaining: 59.9ms
# 33:	learn: 9.9751362	total: 120ms	remaining: 56.3ms
# 34:	learn: 9.9119890	total: 123ms	remaining: 52.8ms
# 35:	learn: 9.8552126	total: 127ms	remaining: 49.2ms
# 36:	learn: 9.7972956	total: 131ms	remaining: 45.9ms
# 37:	learn: 9.7345926	total: 134ms	remaining: 42.4ms
# 38:	learn: 9.6764191	total: 138ms	remaining: 38.8ms
# 39:	learn: 9.6186125	total: 141ms	remaining: 35.3ms
# 40:	learn: 9.5592405	total: 145ms	remaining: 31.7ms
# 41:	learn: 9.4993978	total: 148ms	remaining: 28.2ms
# 42:	learn: 9.4436181	total: 151ms	remaining: 24.6ms
# 43:	learn: 9.3837555	total: 155ms	remaining: 21.1ms
# 44:	learn: 9.3370566	total: 158ms	remaining: 17.5ms
# 45:	learn: 9.2886429	total: 161ms	remaining: 14ms
# 46:	learn: 9.2414893	total: 165ms	remaining: 10.5ms
# 47:	learn: 9.1926666	total: 168ms	remaining: 7ms
# 48:	learn: 9.1470896	total: 171ms	remaining: 3.49ms
# 49:	learn: 9.0945292	total: 175ms	remaining: 0us
# 0:	learn: 11.7371678	total: 3.33ms	remaining: 163ms
# 1:	learn: 11.4249029	total: 8.74ms	remaining: 210ms
# 2:	learn: 11.1255478	total: 14.8ms	remaining: 232ms
# 3:	learn: 10.7830159	total: 18ms	remaining: 207ms
# 4:	learn: 10.4746286	total: 21.3ms	remaining: 192ms
# 5:	learn: 10.1815730	total: 25.3ms	remaining: 186ms
# 6:	learn: 9.9226266	total: 28.6ms	remaining: 176ms
# 7:	learn: 9.6279769	total: 31.7ms	remaining: 166ms
# 8:	learn: 9.3410207	total: 35.1ms	remaining: 160ms
# 9:	learn: 9.1005872	total: 38.3ms	remaining: 153ms
# 10:	learn: 8.8600093	total: 42ms	remaining: 149ms
# 11:	learn: 8.6417687	total: 45.7ms	remaining: 145ms
# 12:	learn: 8.4021775	total: 49.4ms	remaining: 141ms
# 13:	learn: 8.1402440	total: 53ms	remaining: 136ms
# 14:	learn: 7.9172339	total: 56.7ms	remaining: 132ms
# 15:	learn: 7.7096108	total: 60.1ms	remaining: 128ms
# 16:	learn: 7.5069440	total: 63.5ms	remaining: 123ms
# 17:	learn: 7.3323124	total: 66.8ms	remaining: 119ms
# 18:	learn: 7.1727287	total: 70.6ms	remaining: 115ms
# 19:	learn: 6.9910156	total: 74.1ms	remaining: 111ms
# 20:	learn: 6.8637840	total: 77.5ms	remaining: 107ms
# 21:	learn: 6.7041921	total: 81.1ms	remaining: 103ms
# 22:	learn: 6.5773906	total: 87ms	remaining: 102ms
# 23:	learn: 6.4539426	total: 90.4ms	remaining: 98ms
# 24:	learn: 6.3011132	total: 94.1ms	remaining: 94.1ms
# 25:	learn: 6.1992023	total: 97.5ms	remaining: 90ms
# 26:	learn: 6.0862278	total: 101ms	remaining: 86.2ms
# 27:	learn: 5.9580580	total: 105ms	remaining: 82.4ms
# 28:	learn: 5.8214915	total: 109ms	remaining: 78.6ms
# 29:	learn: 5.6930476	total: 112ms	remaining: 74.8ms
# 30:	learn: 5.6270442	total: 116ms	remaining: 70.9ms
# 31:	learn: 5.5394550	total: 119ms	remaining: 67.1ms
# 32:	learn: 5.4596805	total: 123ms	remaining: 63.3ms
# 33:	learn: 5.3721826	total: 126ms	remaining: 59.5ms
# 34:	learn: 5.2605996	total: 130ms	remaining: 55.7ms
# 35:	learn: 5.1911321	total: 133ms	remaining: 51.9ms
# 36:	learn: 5.1028915	total: 137ms	remaining: 48.1ms
# 37:	learn: 4.9999632	total: 141ms	remaining: 44.4ms
# 38:	learn: 4.9062614	total: 144ms	remaining: 40.6ms
# 39:	learn: 4.8107795	total: 147ms	remaining: 36.9ms
# 40:	learn: 4.7168719	total: 151ms	remaining: 33.1ms
# 41:	learn: 4.6401623	total: 154ms	remaining: 29.4ms
# 42:	learn: 4.5628875	total: 158ms	remaining: 25.7ms
# 43:	learn: 4.4971022	total: 161ms	remaining: 22ms
# 44:	learn: 4.4466142	total: 165ms	remaining: 18.3ms
# 45:	learn: 4.3776326	total: 169ms	remaining: 14.7ms
# 46:	learn: 4.3207645	total: 172ms	remaining: 11ms
# 47:	learn: 4.2638266	total: 176ms	remaining: 7.31ms
# 48:	learn: 4.1997192	total: 179ms	remaining: 3.65ms
# 49:	learn: 4.1477306	total: 182ms	remaining: 0us
# 0:	learn: 11.7887853	total: 3.28ms	remaining: 161ms
# 1:	learn: 11.4084316	total: 7.31ms	remaining: 175ms
# 2:	learn: 11.1177022	total: 10.9ms	remaining: 171ms
# 3:	learn: 10.8110105	total: 14.4ms	remaining: 166ms
# 4:	learn: 10.4882965	total: 18ms	remaining: 162ms
# 5:	learn: 10.1995189	total: 21.4ms	remaining: 157ms
# 6:	learn: 9.9339889	total: 24.9ms	remaining: 153ms
# 7:	learn: 9.6349820	total: 28.5ms	remaining: 149ms
# 8:	learn: 9.3403122	total: 31.9ms	remaining: 145ms
# 9:	learn: 9.0948843	total: 35.3ms	remaining: 141ms
# 10:	learn: 8.8469038	total: 38.7ms	remaining: 137ms
# 11:	learn: 8.6140906	total: 42.3ms	remaining: 134ms
# 12:	learn: 8.3787208	total: 45.9ms	remaining: 131ms
# 13:	learn: 8.1270282	total: 49ms	remaining: 126ms
# 14:	learn: 7.8916450	total: 52.1ms	remaining: 122ms
# 15:	learn: 7.6699679	total: 55.3ms	remaining: 118ms
# 16:	learn: 7.4587531	total: 59.1ms	remaining: 115ms
# 17:	learn: 7.2695922	total: 62.8ms	remaining: 112ms
# 18:	learn: 7.0911534	total: 66.4ms	remaining: 108ms
# 19:	learn: 6.9403145	total: 69.9ms	remaining: 105ms
# 20:	learn: 6.7978286	total: 73.4ms	remaining: 101ms
# 21:	learn: 6.6818708	total: 76.9ms	remaining: 97.8ms
# 22:	learn: 6.5598187	total: 80.3ms	remaining: 94.2ms
# 23:	learn: 6.4164870	total: 83.9ms	remaining: 90.9ms
# 24:	learn: 6.3093439	total: 87.4ms	remaining: 87.4ms
# 25:	learn: 6.1923230	total: 91ms	remaining: 84ms
# 26:	learn: 6.0408143	total: 94.4ms	remaining: 80.4ms
# 27:	learn: 5.9315947	total: 97.8ms	remaining: 76.8ms
# 28:	learn: 5.8108461	total: 101ms	remaining: 73.3ms
# 29:	learn: 5.6661036	total: 105ms	remaining: 69.8ms
# 30:	learn: 5.5464753	total: 108ms	remaining: 66.3ms
# 31:	learn: 5.4538866	total: 111ms	remaining: 62.7ms
# 32:	learn: 5.3388129	total: 115ms	remaining: 59.3ms
# 33:	learn: 5.2584524	total: 119ms	remaining: 55.9ms
# 34:	learn: 5.1383206	total: 122ms	remaining: 52.3ms
# 35:	learn: 5.0628682	total: 126ms	remaining: 48.8ms
# 36:	learn: 4.9621358	total: 129ms	remaining: 45.3ms
# 37:	learn: 4.8756387	total: 132ms	remaining: 41.8ms
# 38:	learn: 4.7951350	total: 137ms	remaining: 38.6ms
# 39:	learn: 4.7199943	total: 140ms	remaining: 35ms
# 40:	learn: 4.6173663	total: 144ms	remaining: 31.6ms
# 41:	learn: 4.5317280	total: 150ms	remaining: 28.5ms
# 42:	learn: 4.4645344	total: 153ms	remaining: 24.8ms
# 43:	learn: 4.3755120	total: 156ms	remaining: 21.2ms
# 44:	learn: 4.3230224	total: 159ms	remaining: 17.7ms
# 45:	learn: 4.2573478	total: 163ms	remaining: 14.2ms
# 46:	learn: 4.1977767	total: 166ms	remaining: 10.6ms
# 47:	learn: 4.1344576	total: 170ms	remaining: 7.08ms
# 48:	learn: 4.0660433	total: 174ms	remaining: 3.54ms
# 49:	learn: 4.0077327	total: 177ms	remaining: 0us
# 0:	learn: 11.9262218	total: 3.39ms	remaining: 166ms
# 1:	learn: 11.5410284	total: 10.6ms	remaining: 255ms
# 2:	learn: 11.2162597	total: 17.2ms	remaining: 270ms
# 3:	learn: 10.8592516	total: 21.3ms	remaining: 245ms
# 4:	learn: 10.5250672	total: 25.9ms	remaining: 233ms
# 5:	learn: 10.2643689	total: 29.4ms	remaining: 216ms
# 6:	learn: 9.9936870	total: 37.3ms	remaining: 229ms
# 7:	learn: 9.6832311	total: 44.9ms	remaining: 236ms
# 8:	learn: 9.4134625	total: 49.5ms	remaining: 225ms
# 9:	learn: 9.1591485	total: 52.9ms	remaining: 212ms
# 10:	learn: 8.9008568	total: 56.4ms	remaining: 200ms
# 11:	learn: 8.6623901	total: 59.6ms	remaining: 189ms
# 12:	learn: 8.4095659	total: 63ms	remaining: 179ms
# 13:	learn: 8.1444580	total: 66.6ms	remaining: 171ms
# 14:	learn: 7.9132616	total: 69.9ms	remaining: 163ms
# 15:	learn: 7.7263389	total: 73.3ms	remaining: 156ms
# 16:	learn: 7.5375652	total: 76.8ms	remaining: 149ms
# 17:	learn: 7.3497801	total: 80.2ms	remaining: 143ms
# 18:	learn: 7.1481795	total: 83.6ms	remaining: 136ms
# 19:	learn: 6.9731763	total: 87.1ms	remaining: 131ms
# 20:	learn: 6.8453100	total: 90.5ms	remaining: 125ms
# 21:	learn: 6.6764946	total: 93.9ms	remaining: 119ms
# 22:	learn: 6.5442900	total: 97.3ms	remaining: 114ms
# 23:	learn: 6.3783528	total: 101ms	remaining: 109ms
# 24:	learn: 6.2399800	total: 107ms	remaining: 107ms
# 25:	learn: 6.1100955	total: 110ms	remaining: 102ms
# 26:	learn: 5.9911095	total: 114ms	remaining: 97.2ms
# 27:	learn: 5.8734647	total: 118ms	remaining: 92.5ms
# 28:	learn: 5.7489487	total: 121ms	remaining: 87.8ms
# 29:	learn: 5.6197717	total: 124ms	remaining: 83ms
# 30:	learn: 5.5339796	total: 128ms	remaining: 78.5ms
# 31:	learn: 5.4361825	total: 132ms	remaining: 74ms
# 32:	learn: 5.3450347	total: 135ms	remaining: 69.6ms
# 33:	learn: 5.2520132	total: 138ms	remaining: 65.1ms
# 34:	learn: 5.1506129	total: 143ms	remaining: 61.5ms
# 35:	learn: 5.0515688	total: 147ms	remaining: 57.2ms
# 36:	learn: 4.9521653	total: 151ms	remaining: 52.9ms
# 37:	learn: 4.8639359	total: 154ms	remaining: 48.7ms
# 38:	learn: 4.7701646	total: 158ms	remaining: 44.5ms
# 39:	learn: 4.6902501	total: 162ms	remaining: 40.4ms
# 40:	learn: 4.5962240	total: 167ms	remaining: 36.7ms
# 41:	learn: 4.5122899	total: 171ms	remaining: 32.6ms
# 42:	learn: 4.4316381	total: 175ms	remaining: 28.4ms
# 43:	learn: 4.3564322	total: 178ms	remaining: 24.3ms
# 44:	learn: 4.3007585	total: 182ms	remaining: 20.2ms
# 45:	learn: 4.2380768	total: 186ms	remaining: 16.1ms
# 46:	learn: 4.1747959	total: 193ms	remaining: 12.3ms
# 47:	learn: 4.0870185	total: 198ms	remaining: 8.24ms
# 48:	learn: 4.0099797	total: 201ms	remaining: 4.1ms
# 49:	learn: 3.9616950	total: 204ms	remaining: 0us
# 0:	learn: 11.3553705	total: 3.17ms	remaining: 155ms
# 1:	learn: 10.7727863	total: 7.09ms	remaining: 170ms
# 2:	learn: 10.2425768	total: 10.6ms	remaining: 166ms
# 3:	learn: 9.6400848	total: 14.1ms	remaining: 162ms
# 4:	learn: 9.1411460	total: 17.5ms	remaining: 158ms
# 5:	learn: 8.6871315	total: 20.8ms	remaining: 152ms
# 6:	learn: 8.3131782	total: 24.3ms	remaining: 149ms
# 7:	learn: 7.8670826	total: 28ms	remaining: 147ms
# 8:	learn: 7.5010069	total: 31.6ms	remaining: 144ms
# 9:	learn: 7.1843051	total: 35.1ms	remaining: 140ms
# 10:	learn: 6.9251572	total: 38.6ms	remaining: 137ms
# 11:	learn: 6.6599581	total: 42.1ms	remaining: 133ms
# 12:	learn: 6.3624899	total: 45.3ms	remaining: 129ms
# 13:	learn: 6.0539288	total: 49.1ms	remaining: 126ms
# 14:	learn: 5.7690878	total: 52.7ms	remaining: 123ms
# 15:	learn: 5.5587055	total: 56ms	remaining: 119ms
# 16:	learn: 5.3336201	total: 59.7ms	remaining: 116ms
# 17:	learn: 5.1402284	total: 63.2ms	remaining: 112ms
# 18:	learn: 4.9690087	total: 66.7ms	remaining: 109ms
# 19:	learn: 4.8262016	total: 70.3ms	remaining: 105ms
# 20:	learn: 4.7255142	total: 73.8ms	remaining: 102ms
# 21:	learn: 4.5957024	total: 77.2ms	remaining: 98.3ms
# 22:	learn: 4.4880693	total: 80.6ms	remaining: 94.6ms
# 23:	learn: 4.3995372	total: 84.1ms	remaining: 91.1ms
# 24:	learn: 4.2913804	total: 87.8ms	remaining: 87.8ms
# 25:	learn: 4.1886451	total: 91.6ms	remaining: 84.5ms
# 26:	learn: 4.1193525	total: 95.2ms	remaining: 81.1ms
# 27:	learn: 4.0066093	total: 98.8ms	remaining: 77.6ms
# 28:	learn: 3.9017326	total: 102ms	remaining: 74.1ms
# 29:	learn: 3.7851406	total: 106ms	remaining: 70.6ms
# 30:	learn: 3.7237544	total: 110ms	remaining: 67.1ms
# 31:	learn: 3.6452386	total: 113ms	remaining: 63.5ms
# 32:	learn: 3.5648873	total: 116ms	remaining: 59.9ms
# 33:	learn: 3.4690909	total: 120ms	remaining: 56.4ms
# 34:	learn: 3.3949388	total: 123ms	remaining: 52.8ms
# 35:	learn: 3.3310581	total: 127ms	remaining: 49.3ms
# 36:	learn: 3.2756706	total: 130ms	remaining: 45.7ms
# 37:	learn: 3.2175321	total: 134ms	remaining: 42.2ms
# 38:	learn: 3.1595239	total: 139ms	remaining: 39.3ms
# 39:	learn: 3.0903686	total: 147ms	remaining: 36.7ms
# 40:	learn: 3.0506348	total: 151ms	remaining: 33.2ms
# 41:	learn: 3.0267387	total: 155ms	remaining: 29.5ms
# 42:	learn: 2.9886788	total: 158ms	remaining: 25.8ms
# 43:	learn: 2.9387998	total: 162ms	remaining: 22.1ms
# 44:	learn: 2.9052882	total: 165ms	remaining: 18.3ms
# 45:	learn: 2.8887360	total: 169ms	remaining: 14.7ms
# 46:	learn: 2.8465968	total: 172ms	remaining: 11ms
# 47:	learn: 2.8311120	total: 175ms	remaining: 7.3ms
# 48:	learn: 2.7655350	total: 179ms	remaining: 3.65ms
# 49:	learn: 2.7402361	total: 182ms	remaining: 0us
# 0:	learn: 11.4211024	total: 3.28ms	remaining: 161ms
# 1:	learn: 10.6980587	total: 6.62ms	remaining: 159ms
# 2:	learn: 10.1778914	total: 10.2ms	remaining: 160ms
# 3:	learn: 9.5669097	total: 13.7ms	remaining: 157ms
# 4:	learn: 9.0402591	total: 17ms	remaining: 153ms
# 5:	learn: 8.5351592	total: 20.5ms	remaining: 150ms
# 6:	learn: 8.1500808	total: 23.9ms	remaining: 147ms
# 7:	learn: 7.7125359	total: 27.4ms	remaining: 144ms
# 8:	learn: 7.3056745	total: 30.9ms	remaining: 141ms
# 9:	learn: 7.0012815	total: 35.3ms	remaining: 141ms
# 10:	learn: 6.6799951	total: 38.9ms	remaining: 138ms
# 11:	learn: 6.4134038	total: 42.5ms	remaining: 134ms
# 12:	learn: 6.1325495	total: 51.1ms	remaining: 145ms
# 13:	learn: 5.8293081	total: 54.5ms	remaining: 140ms
# 14:	learn: 5.6035109	total: 58ms	remaining: 135ms
# 15:	learn: 5.4180202	total: 61.3ms	remaining: 130ms
# 16:	learn: 5.2247342	total: 64.6ms	remaining: 125ms
# 17:	learn: 5.0468601	total: 68ms	remaining: 121ms
# 18:	learn: 4.8909254	total: 71.3ms	remaining: 116ms
# 19:	learn: 4.6817153	total: 74.8ms	remaining: 112ms
# 20:	learn: 4.5836675	total: 78.1ms	remaining: 108ms
# 21:	learn: 4.3961353	total: 81.4ms	remaining: 104ms
# 22:	learn: 4.2983973	total: 84.7ms	remaining: 99.4ms
# 23:	learn: 4.1740758	total: 88.1ms	remaining: 95.5ms
# 24:	learn: 4.0767632	total: 91.5ms	remaining: 91.5ms
# 25:	learn: 3.9686340	total: 97.3ms	remaining: 89.8ms
# 26:	learn: 3.8539033	total: 101ms	remaining: 85.8ms
# 27:	learn: 3.7678156	total: 106ms	remaining: 83.1ms
# 28:	learn: 3.6553975	total: 112ms	remaining: 81ms
# 29:	learn: 3.5509880	total: 115ms	remaining: 76.9ms
# 30:	learn: 3.4649298	total: 119ms	remaining: 72.8ms
# 31:	learn: 3.3908900	total: 122ms	remaining: 68.7ms
# 32:	learn: 3.3234935	total: 126ms	remaining: 64.7ms
# 33:	learn: 3.2615791	total: 129ms	remaining: 60.7ms
# 34:	learn: 3.1794113	total: 132ms	remaining: 56.7ms
# 35:	learn: 3.1186992	total: 136ms	remaining: 52.9ms
# 36:	learn: 3.0483558	total: 139ms	remaining: 49ms
# 37:	learn: 2.9753750	total: 143ms	remaining: 45.1ms
# 38:	learn: 2.9124251	total: 146ms	remaining: 41.2ms
# 39:	learn: 2.8543182	total: 150ms	remaining: 37.4ms
# 40:	learn: 2.8075398	total: 153ms	remaining: 33.6ms
# 41:	learn: 2.7485446	total: 156ms	remaining: 29.8ms
# 42:	learn: 2.7091782	total: 160ms	remaining: 26ms
# 43:	learn: 2.6544052	total: 163ms	remaining: 22.2ms
# 44:	learn: 2.6159642	total: 166ms	remaining: 18.4ms
# 45:	learn: 2.5776953	total: 169ms	remaining: 14.7ms
# 46:	learn: 2.5432378	total: 173ms	remaining: 11ms
# 47:	learn: 2.5194452	total: 176ms	remaining: 7.33ms
# 48:	learn: 2.4770033	total: 179ms	remaining: 3.65ms
# 49:	learn: 2.4303221	total: 183ms	remaining: 0us
# 0:	learn: 11.5346453	total: 3.23ms	remaining: 158ms
# 1:	learn: 10.8050644	total: 6.36ms	remaining: 153ms
# 2:	learn: 10.2269850	total: 9.45ms	remaining: 148ms
# 3:	learn: 9.6058770	total: 13.1ms	remaining: 151ms
# 4:	learn: 9.0683269	total: 16.8ms	remaining: 151ms
# 5:	learn: 8.5863208	total: 20.4ms	remaining: 150ms
# 6:	learn: 8.1906558	total: 23.8ms	remaining: 146ms
# 7:	learn: 7.7583650	total: 27.4ms	remaining: 144ms
# 8:	learn: 7.3474592	total: 31ms	remaining: 141ms
# 9:	learn: 7.0117595	total: 34.3ms	remaining: 137ms
# 10:	learn: 6.6841657	total: 37.7ms	remaining: 134ms
# 11:	learn: 6.3986390	total: 41ms	remaining: 130ms
# 12:	learn: 6.0707933	total: 44.5ms	remaining: 127ms
# 13:	learn: 5.7480267	total: 47.9ms	remaining: 123ms
# 14:	learn: 5.5112950	total: 51.1ms	remaining: 119ms
# 15:	learn: 5.2713682	total: 54.3ms	remaining: 115ms
# 16:	learn: 5.0695457	total: 57.7ms	remaining: 112ms
# 17:	learn: 4.8892269	total: 61ms	remaining: 109ms
# 18:	learn: 4.7035606	total: 64.4ms	remaining: 105ms
# 19:	learn: 4.5364614	total: 68.1ms	remaining: 102ms
# 20:	learn: 4.4089842	total: 78ms	remaining: 108ms
# 21:	learn: 4.2522490	total: 81.7ms	remaining: 104ms
# 22:	learn: 4.1467359	total: 85.2ms	remaining: 100ms
# 23:	learn: 4.0100055	total: 88.6ms	remaining: 96ms
# 24:	learn: 3.9082364	total: 92ms	remaining: 92ms
# 25:	learn: 3.7755290	total: 95.4ms	remaining: 88.1ms
# 26:	learn: 3.6794094	total: 98.9ms	remaining: 84.3ms
# 27:	learn: 3.6053269	total: 102ms	remaining: 80.4ms
# 28:	learn: 3.5119280	total: 106ms	remaining: 76.6ms
# 29:	learn: 3.4193710	total: 109ms	remaining: 72.8ms
# 30:	learn: 3.3720133	total: 113ms	remaining: 69ms
# 31:	learn: 3.2949335	total: 116ms	remaining: 65.2ms
# 32:	learn: 3.2304757	total: 119ms	remaining: 61.4ms
# 33:	learn: 3.1771797	total: 123ms	remaining: 57.7ms
# 34:	learn: 3.1194191	total: 126ms	remaining: 54ms
# 35:	learn: 3.0310134	total: 129ms	remaining: 50.4ms
# 36:	learn: 2.9486816	total: 133ms	remaining: 46.7ms
# 37:	learn: 2.8702217	total: 136ms	remaining: 43ms
# 38:	learn: 2.8146967	total: 139ms	remaining: 39.3ms
# 39:	learn: 2.7553270	total: 143ms	remaining: 35.7ms
# 40:	learn: 2.6895926	total: 146ms	remaining: 32ms
# 41:	learn: 2.6228943	total: 149ms	remaining: 28.5ms
# 42:	learn: 2.5886193	total: 153ms	remaining: 24.9ms
# 43:	learn: 2.5468549	total: 157ms	remaining: 21.4ms
# 44:	learn: 2.5255339	total: 160ms	remaining: 17.8ms
# 45:	learn: 2.4848133	total: 163ms	remaining: 14.2ms
# 46:	learn: 2.4523220	total: 168ms	remaining: 10.7ms
# 47:	learn: 2.3989532	total: 172ms	remaining: 7.15ms
# 48:	learn: 2.3643734	total: 175ms	remaining: 3.57ms
# 49:	learn: 2.3161348	total: 179ms	remaining: 0us
# 0:	learn: 12.0474412	total: 3.38ms	remaining: 335ms
# 1:	learn: 11.9717073	total: 6.57ms	remaining: 322ms
# 2:	learn: 11.9059822	total: 10ms	remaining: 324ms
# 3:	learn: 11.8289107	total: 14.4ms	remaining: 344ms
# 4:	learn: 11.7557857	total: 18.1ms	remaining: 345ms
# 5:	learn: 11.6845494	total: 21.7ms	remaining: 340ms
# 6:	learn: 11.6181709	total: 25.2ms	remaining: 334ms
# 7:	learn: 11.5403476	total: 28.6ms	remaining: 329ms
# 8:	learn: 11.4695802	total: 32ms	remaining: 324ms
# 9:	learn: 11.4015307	total: 35.6ms	remaining: 320ms
# 10:	learn: 11.3343708	total: 39.4ms	remaining: 319ms
# 11:	learn: 11.2648526	total: 43ms	remaining: 315ms
# 12:	learn: 11.1904938	total: 46.2ms	remaining: 309ms
# 13:	learn: 11.1149024	total: 54.9ms	remaining: 337ms
# 14:	learn: 11.0413905	total: 58.8ms	remaining: 333ms
# 15:	learn: 10.9743156	total: 62.1ms	remaining: 326ms
# 16:	learn: 10.9066946	total: 65.6ms	remaining: 320ms
# 17:	learn: 10.8406812	total: 74.6ms	remaining: 340ms
# 18:	learn: 10.7795569	total: 81.2ms	remaining: 346ms
# 19:	learn: 10.7188733	total: 89.3ms	remaining: 357ms
# 20:	learn: 10.6622903	total: 95.2ms	remaining: 358ms
# 21:	learn: 10.6064787	total: 98.8ms	remaining: 350ms
# 22:	learn: 10.5482488	total: 102ms	remaining: 342ms
# 23:	learn: 10.4850483	total: 108ms	remaining: 342ms
# 24:	learn: 10.4293920	total: 113ms	remaining: 340ms
# 25:	learn: 10.3637645	total: 117ms	remaining: 333ms
# 26:	learn: 10.3039968	total: 120ms	remaining: 325ms
# 27:	learn: 10.2391840	total: 123ms	remaining: 318ms
# 28:	learn: 10.1844578	total: 127ms	remaining: 310ms
# 29:	learn: 10.1269974	total: 130ms	remaining: 303ms
# 30:	learn: 10.0721983	total: 133ms	remaining: 297ms
# 31:	learn: 10.0174720	total: 137ms	remaining: 290ms
# 32:	learn: 9.9639640	total: 140ms	remaining: 284ms
# 33:	learn: 9.9109616	total: 143ms	remaining: 278ms
# 34:	learn: 9.8483429	total: 146ms	remaining: 272ms
# 35:	learn: 9.7961489	total: 150ms	remaining: 266ms
# 36:	learn: 9.7404011	total: 153ms	remaining: 261ms
# 37:	learn: 9.6847317	total: 156ms	remaining: 255ms
# 38:	learn: 9.6277063	total: 159ms	remaining: 249ms
# 39:	learn: 9.5708521	total: 163ms	remaining: 244ms
# 40:	learn: 9.5141396	total: 166ms	remaining: 239ms
# 41:	learn: 9.4626795	total: 169ms	remaining: 234ms
# 42:	learn: 9.4136052	total: 171ms	remaining: 227ms
# 43:	learn: 9.3557706	total: 175ms	remaining: 222ms
# 44:	learn: 9.3017360	total: 178ms	remaining: 217ms
# 45:	learn: 9.2464749	total: 181ms	remaining: 213ms
# 46:	learn: 9.1933727	total: 185ms	remaining: 208ms
# 47:	learn: 9.1429677	total: 188ms	remaining: 203ms
# 48:	learn: 9.0898165	total: 192ms	remaining: 200ms
# 49:	learn: 9.0317548	total: 197ms	remaining: 197ms
# 50:	learn: 8.9872033	total: 200ms	remaining: 192ms
# 51:	learn: 8.9370077	total: 203ms	remaining: 187ms
# 52:	learn: 8.8904013	total: 206ms	remaining: 183ms
# 53:	learn: 8.8422730	total: 210ms	remaining: 179ms
# 54:	learn: 8.7953010	total: 214ms	remaining: 175ms
# 55:	learn: 8.7495214	total: 217ms	remaining: 170ms
# 56:	learn: 8.7019609	total: 220ms	remaining: 166ms
# 57:	learn: 8.6535154	total: 223ms	remaining: 161ms
# 58:	learn: 8.6050293	total: 226ms	remaining: 157ms
# 59:	learn: 8.5672636	total: 230ms	remaining: 153ms
# 60:	learn: 8.5234701	total: 233ms	remaining: 149ms
# 61:	learn: 8.4778356	total: 236ms	remaining: 145ms
# 62:	learn: 8.4339580	total: 240ms	remaining: 141ms
# 63:	learn: 8.3912984	total: 247ms	remaining: 139ms
# 64:	learn: 8.3494392	total: 251ms	remaining: 135ms
# 65:	learn: 8.3050773	total: 254ms	remaining: 131ms
# 66:	learn: 8.2630564	total: 258ms	remaining: 127ms
# 67:	learn: 8.2206665	total: 261ms	remaining: 123ms
# 68:	learn: 8.1808246	total: 265ms	remaining: 119ms
# 69:	learn: 8.1418424	total: 268ms	remaining: 115ms
# 70:	learn: 8.0971085	total: 271ms	remaining: 111ms
# 71:	learn: 8.0560321	total: 275ms	remaining: 107ms
# 72:	learn: 8.0123230	total: 279ms	remaining: 103ms
# 73:	learn: 7.9709821	total: 282ms	remaining: 99.2ms
# 74:	learn: 7.9299314	total: 286ms	remaining: 95.2ms
# 75:	learn: 7.8949401	total: 289ms	remaining: 91.2ms
# 76:	learn: 7.8560428	total: 292ms	remaining: 87.3ms
# 77:	learn: 7.8197009	total: 296ms	remaining: 83.6ms
# 78:	learn: 7.7840103	total: 300ms	remaining: 79.7ms
# 79:	learn: 7.7396009	total: 303ms	remaining: 75.9ms
# 80:	learn: 7.7016655	total: 307ms	remaining: 72ms
# 81:	learn: 7.6654442	total: 311ms	remaining: 68.2ms
# 82:	learn: 7.6263150	total: 316ms	remaining: 64.7ms
# 83:	learn: 7.5856223	total: 319ms	remaining: 60.8ms
# 84:	learn: 7.5460810	total: 322ms	remaining: 56.8ms
# 85:	learn: 7.5083906	total: 325ms	remaining: 52.9ms
# 86:	learn: 7.4727447	total: 328ms	remaining: 49.1ms
# 87:	learn: 7.4371514	total: 333ms	remaining: 45.4ms
# 88:	learn: 7.4020872	total: 340ms	remaining: 42ms
# 89:	learn: 7.3662962	total: 348ms	remaining: 38.6ms
# 90:	learn: 7.3340240	total: 356ms	remaining: 35.2ms
# 91:	learn: 7.3008579	total: 365ms	remaining: 31.7ms
# 92:	learn: 7.2637968	total: 369ms	remaining: 27.8ms
# 93:	learn: 7.2327908	total: 374ms	remaining: 23.9ms
# 94:	learn: 7.1930668	total: 379ms	remaining: 20ms
# 95:	learn: 7.1595502	total: 387ms	remaining: 16.1ms
# 96:	learn: 7.1298398	total: 396ms	remaining: 12.3ms
# 97:	learn: 7.0997555	total: 407ms	remaining: 8.3ms
# 98:	learn: 7.0679092	total: 411ms	remaining: 4.15ms
# 99:	learn: 7.0318533	total: 416ms	remaining: 0us
# 0:	learn: 12.0876188	total: 7ms	remaining: 693ms
# 1:	learn: 12.0101542	total: 14.3ms	remaining: 701ms
# 2:	learn: 11.9462280	total: 21.4ms	remaining: 693ms
# 3:	learn: 11.8766055	total: 29.1ms	remaining: 698ms
# 4:	learn: 11.7993281	total: 36.1ms	remaining: 686ms
# 5:	learn: 11.7295218	total: 43.1ms	remaining: 675ms
# 6:	learn: 11.6623892	total: 52.7ms	remaining: 700ms
# 7:	learn: 11.5853543	total: 59.7ms	remaining: 687ms
# 8:	learn: 11.5049736	total: 70.2ms	remaining: 710ms
# 9:	learn: 11.4351770	total: 77.5ms	remaining: 697ms
# 10:	learn: 11.3609023	total: 82.3ms	remaining: 666ms
# 11:	learn: 11.2913618	total: 86.7ms	remaining: 636ms
# 12:	learn: 11.2213774	total: 92.1ms	remaining: 617ms
# 13:	learn: 11.1419547	total: 97.2ms	remaining: 597ms
# 14:	learn: 11.0666027	total: 101ms	remaining: 570ms
# 15:	learn: 11.0009093	total: 108ms	remaining: 569ms
# 16:	learn: 10.9378978	total: 112ms	remaining: 546ms
# 17:	learn: 10.8718306	total: 117ms	remaining: 535ms
# 18:	learn: 10.8025223	total: 122ms	remaining: 518ms
# 19:	learn: 10.7360424	total: 127ms	remaining: 510ms
# 20:	learn: 10.6792105	total: 132ms	remaining: 497ms
# 21:	learn: 10.6220447	total: 136ms	remaining: 483ms
# 22:	learn: 10.5552748	total: 141ms	remaining: 470ms
# 23:	learn: 10.4895436	total: 146ms	remaining: 462ms
# 24:	learn: 10.4331873	total: 154ms	remaining: 461ms
# 25:	learn: 10.3688947	total: 163ms	remaining: 463ms
# 26:	learn: 10.3134943	total: 168ms	remaining: 454ms
# 27:	learn: 10.2544168	total: 178ms	remaining: 457ms
# 28:	learn: 10.1934568	total: 186ms	remaining: 456ms
# 29:	learn: 10.1345617	total: 196ms	remaining: 456ms
# 30:	learn: 10.0823560	total: 204ms	remaining: 454ms
# 31:	learn: 10.0236730	total: 215ms	remaining: 456ms
# 32:	learn: 9.9669532	total: 226ms	remaining: 459ms
# 33:	learn: 9.9122968	total: 234ms	remaining: 453ms
# 34:	learn: 9.8490374	total: 241ms	remaining: 447ms
# 35:	learn: 9.7976747	total: 249ms	remaining: 443ms
# 36:	learn: 9.7365266	total: 259ms	remaining: 440ms
# 37:	learn: 9.6808952	total: 268ms	remaining: 437ms
# 38:	learn: 9.6215331	total: 277ms	remaining: 433ms
# 39:	learn: 9.5692442	total: 286ms	remaining: 429ms
# 40:	learn: 9.5095304	total: 295ms	remaining: 424ms
# 41:	learn: 9.4496014	total: 305ms	remaining: 421ms
# 42:	learn: 9.3972741	total: 314ms	remaining: 416ms
# 43:	learn: 9.3432035	total: 323ms	remaining: 411ms
# 44:	learn: 9.2920843	total: 333ms	remaining: 407ms
# 45:	learn: 9.2466171	total: 342ms	remaining: 401ms
# 46:	learn: 9.1962071	total: 352ms	remaining: 397ms
# 47:	learn: 9.1444185	total: 361ms	remaining: 391ms
# 48:	learn: 9.1008643	total: 371ms	remaining: 386ms
# 49:	learn: 9.0506506	total: 381ms	remaining: 381ms
# 50:	learn: 8.9982072	total: 390ms	remaining: 375ms
# 51:	learn: 8.9437360	total: 399ms	remaining: 368ms
# 52:	learn: 8.8869790	total: 408ms	remaining: 362ms
# 53:	learn: 8.8368566	total: 417ms	remaining: 355ms
# 54:	learn: 8.7943287	total: 426ms	remaining: 349ms
# 55:	learn: 8.7427454	total: 435ms	remaining: 342ms
# 56:	learn: 8.7041782	total: 444ms	remaining: 335ms
# 57:	learn: 8.6548271	total: 454ms	remaining: 329ms
# 58:	learn: 8.6120471	total: 464ms	remaining: 323ms
# 59:	learn: 8.5662324	total: 473ms	remaining: 315ms
# 60:	learn: 8.5196662	total: 483ms	remaining: 309ms
# 61:	learn: 8.4738482	total: 492ms	remaining: 301ms
# 62:	learn: 8.4230444	total: 501ms	remaining: 294ms
# 63:	learn: 8.3813942	total: 510ms	remaining: 287ms
# 64:	learn: 8.3386906	total: 519ms	remaining: 279ms
# 65:	learn: 8.3033660	total: 528ms	remaining: 272ms
# 66:	learn: 8.2561473	total: 542ms	remaining: 267ms
# 67:	learn: 8.2206745	total: 550ms	remaining: 259ms
# 68:	learn: 8.1749769	total: 562ms	remaining: 252ms
# 69:	learn: 8.1338333	total: 574ms	remaining: 246ms
# 70:	learn: 8.0963785	total: 585ms	remaining: 239ms
# 71:	learn: 8.0559336	total: 592ms	remaining: 230ms
# 72:	learn: 8.0166444	total: 599ms	remaining: 221ms
# 73:	learn: 7.9814769	total: 608ms	remaining: 214ms
# 74:	learn: 7.9448235	total: 619ms	remaining: 206ms
# 75:	learn: 7.9040884	total: 627ms	remaining: 198ms
# 76:	learn: 7.8609468	total: 639ms	remaining: 191ms
# 77:	learn: 7.8219955	total: 646ms	remaining: 182ms
# 78:	learn: 7.7841426	total: 654ms	remaining: 174ms
# 79:	learn: 7.7424153	total: 663ms	remaining: 166ms
# 80:	learn: 7.7043633	total: 672ms	remaining: 158ms
# 81:	learn: 7.6664015	total: 680ms	remaining: 149ms
# 82:	learn: 7.6255633	total: 689ms	remaining: 141ms
# 83:	learn: 7.5904360	total: 697ms	remaining: 133ms
# 84:	learn: 7.5518600	total: 709ms	remaining: 125ms
# 85:	learn: 7.5112463	total: 718ms	remaining: 117ms
# 86:	learn: 7.4786914	total: 727ms	remaining: 109ms
# 87:	learn: 7.4462592	total: 735ms	remaining: 100ms
# 88:	learn: 7.4107402	total: 744ms	remaining: 91.9ms
# 89:	learn: 7.3718115	total: 753ms	remaining: 83.6ms
# 90:	learn: 7.3432501	total: 762ms	remaining: 75.4ms
# 91:	learn: 7.3107479	total: 772ms	remaining: 67.2ms
# 92:	learn: 7.2727285	total: 781ms	remaining: 58.8ms
# 93:	learn: 7.2417437	total: 789ms	remaining: 50.4ms
# 94:	learn: 7.2007577	total: 798ms	remaining: 42ms
# 95:	learn: 7.1668874	total: 807ms	remaining: 33.6ms
# 96:	learn: 7.1322405	total: 815ms	remaining: 25.2ms
# 97:	learn: 7.1051507	total: 824ms	remaining: 16.8ms
# 98:	learn: 7.0710384	total: 834ms	remaining: 8.43ms
# 99:	learn: 7.0390563	total: 841ms	remaining: 0us
# 0:	learn: 12.2439202	total: 7.99ms	remaining: 791ms
# 1:	learn: 12.1636759	total: 13.9ms	remaining: 683ms
# 2:	learn: 12.0928441	total: 18.7ms	remaining: 603ms
# 3:	learn: 12.0126725	total: 23.2ms	remaining: 556ms
# 4:	learn: 11.9342153	total: 27.1ms	remaining: 515ms
# 5:	learn: 11.8698934	total: 30.9ms	remaining: 484ms
# 6:	learn: 11.8020036	total: 36.7ms	remaining: 488ms
# 7:	learn: 11.7200300	total: 56.4ms	remaining: 648ms
# 8:	learn: 11.6383024	total: 65.4ms	remaining: 661ms
# 9:	learn: 11.5660014	total: 74.7ms	remaining: 672ms
# 10:	learn: 11.4946196	total: 77.9ms	remaining: 630ms
# 11:	learn: 11.4207493	total: 83.4ms	remaining: 612ms
# 12:	learn: 11.3461089	total: 88.2ms	remaining: 590ms
# 13:	learn: 11.2666259	total: 92.3ms	remaining: 567ms
# 14:	learn: 11.1885251	total: 96.7ms	remaining: 548ms
# 15:	learn: 11.1209663	total: 100ms	remaining: 527ms
# 16:	learn: 11.0508081	total: 107ms	remaining: 524ms
# 17:	learn: 10.9822952	total: 117ms	remaining: 535ms
# 18:	learn: 10.9096954	total: 126ms	remaining: 537ms
# 19:	learn: 10.8414087	total: 134ms	remaining: 536ms
# 20:	learn: 10.7837768	total: 141ms	remaining: 532ms
# 21:	learn: 10.7162213	total: 149ms	remaining: 528ms
# 22:	learn: 10.6542976	total: 156ms	remaining: 522ms
# 23:	learn: 10.5938525	total: 159ms	remaining: 505ms
# 24:	learn: 10.5250411	total: 166ms	remaining: 498ms
# 25:	learn: 10.4568657	total: 174ms	remaining: 496ms
# 26:	learn: 10.3955711	total: 180ms	remaining: 488ms
# 27:	learn: 10.3337178	total: 188ms	remaining: 484ms
# 28:	learn: 10.2678682	total: 194ms	remaining: 474ms
# 29:	learn: 10.2094397	total: 198ms	remaining: 462ms
# 30:	learn: 10.1535152	total: 202ms	remaining: 449ms
# 31:	learn: 10.0918472	total: 209ms	remaining: 443ms
# 32:	learn: 10.0302151	total: 212ms	remaining: 431ms
# 33:	learn: 9.9751362	total: 218ms	remaining: 424ms
# 34:	learn: 9.9119890	total: 224ms	remaining: 416ms
# 35:	learn: 9.8552126	total: 229ms	remaining: 407ms
# 36:	learn: 9.7972956	total: 236ms	remaining: 402ms
# 37:	learn: 9.7345926	total: 250ms	remaining: 408ms
# 38:	learn: 9.6764191	total: 257ms	remaining: 402ms
# 39:	learn: 9.6186125	total: 265ms	remaining: 398ms
# 40:	learn: 9.5592405	total: 271ms	remaining: 390ms
# 41:	learn: 9.4993978	total: 278ms	remaining: 384ms
# 42:	learn: 9.4436181	total: 285ms	remaining: 378ms
# 43:	learn: 9.3837555	total: 294ms	remaining: 375ms
# 44:	learn: 9.3370566	total: 305ms	remaining: 373ms
# 45:	learn: 9.2886429	total: 308ms	remaining: 362ms
# 46:	learn: 9.2414893	total: 315ms	remaining: 355ms
# 47:	learn: 9.1926666	total: 323ms	remaining: 350ms
# 48:	learn: 9.1470896	total: 328ms	remaining: 341ms
# 49:	learn: 9.0945292	total: 335ms	remaining: 335ms
# 50:	learn: 9.0458759	total: 344ms	remaining: 331ms
# 51:	learn: 8.9892548	total: 355ms	remaining: 328ms
# 52:	learn: 8.9309735	total: 364ms	remaining: 323ms
# 53:	learn: 8.8795076	total: 374ms	remaining: 319ms
# 54:	learn: 8.8339856	total: 383ms	remaining: 314ms
# 55:	learn: 8.7826595	total: 392ms	remaining: 308ms
# 56:	learn: 8.7425114	total: 399ms	remaining: 301ms
# 57:	learn: 8.6986479	total: 408ms	remaining: 295ms
# 58:	learn: 8.6533031	total: 417ms	remaining: 290ms
# 59:	learn: 8.6061498	total: 428ms	remaining: 285ms
# 60:	learn: 8.5602661	total: 446ms	remaining: 285ms
# 61:	learn: 8.5095102	total: 455ms	remaining: 279ms
# 62:	learn: 8.4633475	total: 459ms	remaining: 270ms
# 63:	learn: 8.4203965	total: 465ms	remaining: 262ms
# 64:	learn: 8.3710498	total: 474ms	remaining: 255ms
# 65:	learn: 8.3317712	total: 483ms	remaining: 249ms
# 66:	learn: 8.2885197	total: 491ms	remaining: 242ms
# 67:	learn: 8.2440568	total: 499ms	remaining: 235ms
# 68:	learn: 8.2002061	total: 508ms	remaining: 228ms
# 69:	learn: 8.1616487	total: 517ms	remaining: 221ms
# 70:	learn: 8.1151318	total: 526ms	remaining: 215ms
# 71:	learn: 8.0772312	total: 536ms	remaining: 208ms
# 72:	learn: 8.0336281	total: 546ms	remaining: 202ms
# ...
# 9:	learn: 6.9031498	total: 444ms	remaining: 3.99s
# 10:	learn: 6.5455396	total: 487ms	remaining: 3.94s
# 11:	learn: 6.1893064	total: 523ms	remaining: 3.83s
# 12:	learn: 5.9132409	total: 555ms	remaining: 3.71s
# 13:	learn: 5.6236777	total: 588ms	remaining: 3.61s
# 14:	learn: 5.3938268	total: 621ms	remaining: 3.52s
# 15:	learn: 5.1860924	total: 654ms	remaining: 3.43s
# 16:	learn: 5.0030920	total: 687ms	remaining: 3.35s
# 17:	learn: 4.7677124	total: 743ms	remaining: 3.38s
# 18:	learn: 4.6056271	total: 786ms	remaining: 3.35s
# 19:	learn: 4.4657600	total: 817ms	remaining: 3.27s
# 20:	learn: 4.2789090	total: 850ms	remaining: 3.2s
# 21:	learn: 4.1124347	total: 891ms	remaining: 3.16s
# 22:	learn: 3.9810788	total: 924ms	remaining: 3.09s
# 23:	learn: 3.8606206	total: 929ms	remaining: 2.94s
# 24:	learn: 3.7205668	total: 970ms	remaining: 2.91s
# 25:	learn: 3.6033275	total: 1s	remaining: 2.85s
# 26:	learn: 3.5052845	total: 1.03s	remaining: 2.79s
# 27:	learn: 3.3870458	total: 1.06s	remaining: 2.74s
# 28:	learn: 3.2690632	total: 1.1s	remaining: 2.69s
# 29:	learn: 3.1759652	total: 1.13s	remaining: 2.64s
# 30:	learn: 3.0698266	total: 1.17s	remaining: 2.59s
# 31:	learn: 2.9580507	total: 1.21s	remaining: 2.57s
# 32:	learn: 2.8708405	total: 1.24s	remaining: 2.52s
# 33:	learn: 2.7830694	total: 1.27s	remaining: 2.47s
# 34:	learn: 2.7130077	total: 1.3s	remaining: 2.42s
# 35:	learn: 2.6341657	total: 1.33s	remaining: 2.37s
# 36:	learn: 2.5697967	total: 1.37s	remaining: 2.33s
# 37:	learn: 2.4889349	total: 1.4s	remaining: 2.29s
# 38:	learn: 2.4334652	total: 1.45s	remaining: 2.27s
# 39:	learn: 2.3863431	total: 1.48s	remaining: 2.23s
# 40:	learn: 2.3361114	total: 1.52s	remaining: 2.18s
# 41:	learn: 2.2946689	total: 1.55s	remaining: 2.14s
# 42:	learn: 2.2396892	total: 1.58s	remaining: 2.1s
# 43:	learn: 2.1926043	total: 1.61s	remaining: 2.05s
# 44:	learn: 2.1286316	total: 1.64s	remaining: 2.01s
# 45:	learn: 2.0837485	total: 1.69s	remaining: 1.98s
# 46:	learn: 2.0454533	total: 1.72s	remaining: 1.94s
# 47:	learn: 2.0086537	total: 1.75s	remaining: 1.9s
# 48:	learn: 1.9776209	total: 1.8s	remaining: 1.88s
# 49:	learn: 1.9449145	total: 1.83s	remaining: 1.83s
# 50:	learn: 1.8996451	total: 1.86s	remaining: 1.79s
# 51:	learn: 1.8622928	total: 1.91s	remaining: 1.76s
# 52:	learn: 1.8300854	total: 1.95s	remaining: 1.73s
# 53:	learn: 1.8009621	total: 1.98s	remaining: 1.68s
# 54:	learn: 1.7672412	total: 2.01s	remaining: 1.64s
# 55:	learn: 1.7271363	total: 2.04s	remaining: 1.6s
# 56:	learn: 1.6961682	total: 2.07s	remaining: 1.56s
# 57:	learn: 1.6742505	total: 2.1s	remaining: 1.52s
# 58:	learn: 1.6431323	total: 2.15s	remaining: 1.49s
# 59:	learn: 1.6191174	total: 2.18s	remaining: 1.45s
# 60:	learn: 1.5947406	total: 2.21s	remaining: 1.42s
# 61:	learn: 1.5740273	total: 2.25s	remaining: 1.38s
# 62:	learn: 1.5546550	total: 2.28s	remaining: 1.34s
# 63:	learn: 1.5362200	total: 2.31s	remaining: 1.3s
# 64:	learn: 1.5168441	total: 2.34s	remaining: 1.26s
# 65:	learn: 1.4950385	total: 2.38s	remaining: 1.23s
# 66:	learn: 1.4747275	total: 2.42s	remaining: 1.19s
# 67:	learn: 1.4539153	total: 2.46s	remaining: 1.16s
# 68:	learn: 1.4374644	total: 2.49s	remaining: 1.12s
# 69:	learn: 1.4279496	total: 2.52s	remaining: 1.08s
# 70:	learn: 1.4068044	total: 2.55s	remaining: 1.04s
# 71:	learn: 1.3841148	total: 2.58s	remaining: 1s
# 72:	learn: 1.3580157	total: 2.62s	remaining: 971ms
# 73:	learn: 1.3403719	total: 2.66s	remaining: 933ms
# 74:	learn: 1.3154981	total: 2.69s	remaining: 896ms
# 75:	learn: 1.2986111	total: 2.72s	remaining: 859ms
# 76:	learn: 1.2795308	total: 2.75s	remaining: 822ms
# 77:	learn: 1.2622996	total: 2.79s	remaining: 788ms
# 78:	learn: 1.2411400	total: 2.84s	remaining: 755ms
# 79:	learn: 1.2299348	total: 2.87s	remaining: 718ms
# 80:	learn: 1.2101081	total: 2.9s	remaining: 681ms
# 81:	learn: 1.1966916	total: 2.94s	remaining: 645ms
# 82:	learn: 1.1791023	total: 2.98s	remaining: 610ms
# 83:	learn: 1.1666846	total: 3.02s	remaining: 575ms
# 84:	learn: 1.1538891	total: 3.05s	remaining: 538ms
# 85:	learn: 1.1371932	total: 3.08s	remaining: 501ms
# 86:	learn: 1.1198596	total: 3.11s	remaining: 465ms
# 87:	learn: 1.1014065	total: 3.16s	remaining: 431ms
# 88:	learn: 1.0891277	total: 3.19s	remaining: 394ms
# 89:	learn: 1.0826883	total: 3.23s	remaining: 359ms
# 90:	learn: 1.0605111	total: 3.26s	remaining: 323ms
# 91:	learn: 1.0467046	total: 3.29s	remaining: 286ms
# 92:	learn: 1.0355114	total: 3.33s	remaining: 250ms
# 93:	learn: 1.0286418	total: 3.36s	remaining: 214ms
# 94:	learn: 1.0105553	total: 3.39s	remaining: 178ms
# 95:	learn: 0.9943135	total: 3.42s	remaining: 143ms
# 96:	learn: 0.9780521	total: 3.47s	remaining: 107ms
# 97:	learn: 0.9670315	total: 3.5s	remaining: 71.5ms
# 98:	learn: 0.9533914	total: 3.53s	remaining: 35.7ms
# 99:	learn: 0.9433600	total: 3.57s	remaining: 0us
# 0:	learn: 11.4181506	total: 3.56ms	remaining: 353ms
# 1:	learn: 10.7066774	total: 7.16ms	remaining: 351ms
# 2:	learn: 10.1345493	total: 10.7ms	remaining: 347ms
# 3:	learn: 9.5174119	total: 14.2ms	remaining: 340ms
# 4:	learn: 8.9894474	total: 17.6ms	remaining: 335ms
# 5:	learn: 8.5369318	total: 21.5ms	remaining: 337ms
# 6:	learn: 8.1410287	total: 25.1ms	remaining: 334ms
# 7:	learn: 7.7032202	total: 28.6ms	remaining: 329ms
# 8:	learn: 7.2940469	total: 32.2ms	remaining: 325ms
# 9:	learn: 6.9708316	total: 35.7ms	remaining: 321ms
# 10:	learn: 6.6447825	total: 39.1ms	remaining: 316ms
# 11:	learn: 6.3701360	total: 42.7ms	remaining: 313ms
# 12:	learn: 6.0846037	total: 46.3ms	remaining: 310ms
# 13:	learn: 5.7859816	total: 50ms	remaining: 307ms
# 14:	learn: 5.5225770	total: 54.8ms	remaining: 311ms
# 15:	learn: 5.3112145	total: 63ms	remaining: 331ms
# 16:	learn: 5.0911303	total: 70.7ms	remaining: 345ms
# 17:	learn: 4.8555598	total: 74.5ms	remaining: 339ms
# 18:	learn: 4.7015779	total: 78.2ms	remaining: 333ms
# 19:	learn: 4.5353605	total: 81.7ms	remaining: 327ms
# 20:	learn: 4.4213148	total: 85.2ms	remaining: 321ms
# 21:	learn: 4.2830971	total: 88.8ms	remaining: 315ms
# 22:	learn: 4.1405617	total: 92.2ms	remaining: 309ms
# 23:	learn: 4.0340816	total: 95.9ms	remaining: 304ms
# 24:	learn: 3.9231504	total: 99.6ms	remaining: 299ms
# 25:	learn: 3.8091908	total: 103ms	remaining: 293ms
# 26:	learn: 3.7093867	total: 107ms	remaining: 289ms
# 27:	learn: 3.5846056	total: 111ms	remaining: 285ms
# 28:	learn: 3.4448638	total: 114ms	remaining: 280ms
# 29:	learn: 3.3436639	total: 118ms	remaining: 276ms
# 30:	learn: 3.2826352	total: 122ms	remaining: 271ms
# 31:	learn: 3.1795774	total: 125ms	remaining: 266ms
# 32:	learn: 3.1064841	total: 129ms	remaining: 262ms
# 33:	learn: 3.0106739	total: 132ms	remaining: 257ms
# 34:	learn: 2.9366715	total: 136ms	remaining: 253ms
# 35:	learn: 2.8669443	total: 140ms	remaining: 248ms
# 36:	learn: 2.8192232	total: 143ms	remaining: 244ms
# 37:	learn: 2.7534041	total: 147ms	remaining: 239ms
# 38:	learn: 2.6827673	total: 150ms	remaining: 235ms
# 39:	learn: 2.6390516	total: 154ms	remaining: 231ms
# 40:	learn: 2.5908817	total: 157ms	remaining: 227ms
# 41:	learn: 2.5354902	total: 161ms	remaining: 222ms
# 42:	learn: 2.5027907	total: 164ms	remaining: 218ms
# 43:	learn: 2.4278013	total: 168ms	remaining: 214ms
# 44:	learn: 2.4041135	total: 172ms	remaining: 210ms
# 45:	learn: 2.3607512	total: 175ms	remaining: 206ms
# 46:	learn: 2.3237059	total: 179ms	remaining: 201ms
# 47:	learn: 2.2828358	total: 182ms	remaining: 197ms
# 48:	learn: 2.2417588	total: 188ms	remaining: 196ms
# 49:	learn: 2.2089302	total: 198ms	remaining: 198ms
# 50:	learn: 2.1722087	total: 206ms	remaining: 198ms
# 51:	learn: 2.1247079	total: 214ms	remaining: 198ms
# 52:	learn: 2.1143350	total: 217ms	remaining: 193ms
# 53:	learn: 2.0783445	total: 221ms	remaining: 189ms
# 54:	learn: 2.0453730	total: 226ms	remaining: 185ms
# 55:	learn: 2.0243811	total: 229ms	remaining: 180ms
# 56:	learn: 2.0011748	total: 236ms	remaining: 178ms
# 57:	learn: 1.9710909	total: 239ms	remaining: 173ms
# 58:	learn: 1.9409631	total: 247ms	remaining: 172ms
# 59:	learn: 1.9237479	total: 252ms	remaining: 168ms
# 60:	learn: 1.9037850	total: 256ms	remaining: 163ms
# 61:	learn: 1.8864462	total: 259ms	remaining: 159ms
# 62:	learn: 1.8713099	total: 262ms	remaining: 154ms
# 63:	learn: 1.8374660	total: 266ms	remaining: 149ms
# 64:	learn: 1.8219547	total: 269ms	remaining: 145ms
# 65:	learn: 1.8072265	total: 273ms	remaining: 141ms
# 66:	learn: 1.7820926	total: 276ms	remaining: 136ms
# 67:	learn: 1.7562645	total: 280ms	remaining: 132ms
# 68:	learn: 1.7257604	total: 283ms	remaining: 127ms
# 69:	learn: 1.7008765	total: 287ms	remaining: 123ms
# 70:	learn: 1.6808291	total: 290ms	remaining: 118ms
# 71:	learn: 1.6540034	total: 294ms	remaining: 114ms
# 72:	learn: 1.6271916	total: 297ms	remaining: 110ms
# 73:	learn: 1.6085341	total: 301ms	remaining: 106ms
# 74:	learn: 1.5965425	total: 304ms	remaining: 101ms
# 75:	learn: 1.5665020	total: 308ms	remaining: 97.1ms
# 76:	learn: 1.5440714	total: 311ms	remaining: 92.9ms
# 77:	learn: 1.5251415	total: 314ms	remaining: 88.7ms
# 78:	learn: 1.5163922	total: 318ms	remaining: 84.5ms
# 79:	learn: 1.5090727	total: 321ms	remaining: 80.3ms
# 80:	learn: 1.4994800	total: 324ms	remaining: 76.1ms
# 81:	learn: 1.4872233	total: 328ms	remaining: 72ms
# 82:	learn: 1.4653922	total: 331ms	remaining: 67.9ms
# 83:	learn: 1.4443852	total: 335ms	remaining: 63.7ms
# 84:	learn: 1.4380498	total: 338ms	remaining: 59.7ms
# 85:	learn: 1.4312507	total: 342ms	remaining: 55.6ms
# 86:	learn: 1.4155750	total: 345ms	remaining: 51.6ms
# 87:	learn: 1.4117828	total: 349ms	remaining: 47.5ms
# 88:	learn: 1.3968724	total: 352ms	remaining: 43.5ms
# 89:	learn: 1.3776106	total: 356ms	remaining: 39.5ms
# 90:	learn: 1.3724604	total: 359ms	remaining: 35.5ms
# 91:	learn: 1.3594689	total: 363ms	remaining: 31.5ms
# 92:	learn: 1.3422717	total: 366ms	remaining: 27.6ms
# 93:	learn: 1.3221721	total: 370ms	remaining: 23.6ms
# 94:	learn: 1.3087952	total: 373ms	remaining: 19.6ms
# 95:	learn: 1.2879923	total: 376ms	remaining: 15.7ms
# 96:	learn: 1.2729858	total: 380ms	remaining: 11.8ms
# 97:	learn: 1.2617511	total: 383ms	remaining: 7.83ms
# 98:	learn: 1.2435063	total: 387ms	remaining: 3.91ms
# 99:	learn: 1.2342354	total: 390ms	remaining: 0us
# 0:	learn: 11.4181506	total: 3.42ms	remaining: 339ms
# 1:	learn: 10.7066774	total: 6.87ms	remaining: 337ms
# 2:	learn: 10.1345493	total: 10.5ms	remaining: 340ms
# 3:	learn: 9.5174119	total: 15.6ms	remaining: 374ms
# 4:	learn: 8.9894474	total: 26.1ms	remaining: 496ms
# 5:	learn: 8.5369318	total: 31.2ms	remaining: 489ms
# 6:	learn: 8.1410287	total: 36.1ms	remaining: 479ms
# 7:	learn: 7.7032202	total: 40.1ms	remaining: 461ms
# 8:	learn: 7.2940469	total: 44.1ms	remaining: 446ms
# 9:	learn: 6.9708316	total: 47.8ms	remaining: 430ms
# 10:	learn: 6.6447825	total: 51.6ms	remaining: 418ms
# 11:	learn: 6.3701360	total: 55ms	remaining: 403ms
# 12:	learn: 6.0846037	total: 58.7ms	remaining: 393ms
# 13:	learn: 5.7859816	total: 62.3ms	remaining: 383ms
# 14:	learn: 5.5225770	total: 65.9ms	remaining: 373ms
# 15:	learn: 5.3112145	total: 69.2ms	remaining: 363ms
# 16:	learn: 5.0911303	total: 72.7ms	remaining: 355ms
# 17:	learn: 4.8555598	total: 76.1ms	remaining: 347ms
# 18:	learn: 4.7015779	total: 79.6ms	remaining: 339ms
# 19:	learn: 4.5353605	total: 83.1ms	remaining: 332ms
# 20:	learn: 4.4213148	total: 86.7ms	remaining: 326ms
# 21:	learn: 4.2830971	total: 90.4ms	remaining: 321ms
# 22:	learn: 4.1405617	total: 94ms	remaining: 315ms
# 23:	learn: 4.0340816	total: 100ms	remaining: 317ms
# 24:	learn: 3.9231504	total: 103ms	remaining: 310ms
# 25:	learn: 3.8091908	total: 107ms	remaining: 305ms
# 26:	learn: 3.7093867	total: 111ms	remaining: 299ms
# 27:	learn: 3.5846056	total: 115ms	remaining: 295ms
# 28:	learn: 3.4448638	total: 118ms	remaining: 289ms
# 29:	learn: 3.3436639	total: 122ms	remaining: 284ms
# 30:	learn: 3.2826352	total: 126ms	remaining: 280ms
# 31:	learn: 3.1795774	total: 129ms	remaining: 275ms
# 32:	learn: 3.1064841	total: 133ms	remaining: 270ms
# 33:	learn: 3.0106739	total: 137ms	remaining: 265ms
# 34:	learn: 2.9366715	total: 140ms	remaining: 260ms
# 35:	learn: 2.8669443	total: 144ms	remaining: 256ms
# 36:	learn: 2.8192232	total: 147ms	remaining: 251ms
# 37:	learn: 2.7534041	total: 151ms	remaining: 246ms
# 38:	learn: 2.6827673	total: 154ms	remaining: 241ms
# 39:	learn: 2.6390516	total: 158ms	remaining: 237ms
# 40:	learn: 2.5908817	total: 161ms	remaining: 232ms
# 41:	learn: 2.5354902	total: 165ms	remaining: 227ms
# 42:	learn: 2.5027907	total: 168ms	remaining: 223ms
# 43:	learn: 2.4278013	total: 172ms	remaining: 219ms
# 44:	learn: 2.4041135	total: 175ms	remaining: 214ms
# 45:	learn: 2.3607512	total: 179ms	remaining: 210ms
# 46:	learn: 2.3237059	total: 182ms	remaining: 205ms
# 47:	learn: 2.2828358	total: 186ms	remaining: 201ms
# 48:	learn: 2.2417588	total: 189ms	remaining: 197ms
# 49:	learn: 2.2089302	total: 193ms	remaining: 193ms
# 50:	learn: 2.1722087	total: 196ms	remaining: 189ms
# 51:	learn: 2.1247079	total: 200ms	remaining: 185ms
# 52:	learn: 2.1143350	total: 206ms	remaining: 183ms
# 53:	learn: 2.0783445	total: 214ms	remaining: 182ms
# 54:	learn: 2.0453730	total: 220ms	remaining: 180ms
# 55:	learn: 2.0243811	total: 223ms	remaining: 175ms
# 56:	learn: 2.0011748	total: 226ms	remaining: 171ms
# 57:	learn: 1.9710909	total: 229ms	remaining: 166ms
# 58:	learn: 1.9409631	total: 233ms	remaining: 162ms
# 59:	learn: 1.9237479	total: 237ms	remaining: 158ms
# 60:	learn: 1.9037850	total: 240ms	remaining: 153ms
# 61:	learn: 1.8864462	total: 244ms	remaining: 149ms
# 62:	learn: 1.8713099	total: 247ms	remaining: 145ms
# 63:	learn: 1.8374660	total: 251ms	remaining: 141ms
# 64:	learn: 1.8219547	total: 255ms	remaining: 137ms
# 65:	learn: 1.8072265	total: 258ms	remaining: 133ms
# 66:	learn: 1.7820926	total: 262ms	remaining: 129ms
# 67:	learn: 1.7562645	total: 265ms	remaining: 125ms
# 68:	learn: 1.7257604	total: 269ms	remaining: 121ms
# 69:	learn: 1.7008765	total: 272ms	remaining: 117ms
# 70:	learn: 1.6808291	total: 276ms	remaining: 113ms
# 71:	learn: 1.6540034	total: 280ms	remaining: 109ms
# 72:	learn: 1.6271916	total: 283ms	remaining: 105ms
# 73:	learn: 1.6085341	total: 287ms	remaining: 101ms
# 74:	learn: 1.5965425	total: 291ms	remaining: 96.9ms
# 75:	learn: 1.5665020	total: 294ms	remaining: 92.9ms
# 76:	learn: 1.5440714	total: 298ms	remaining: 88.9ms
# 77:	learn: 1.5251415	total: 301ms	remaining: 85ms
# 78:	learn: 1.5163922	total: 305ms	remaining: 81ms
# 79:	learn: 1.5090727	total: 308ms	remaining: 77ms
# 80:	learn: 1.4994800	total: 312ms	remaining: 73.1ms
# 81:	learn: 1.4872233	total: 315ms	remaining: 69.2ms
# 82:	learn: 1.4653922	total: 319ms	remaining: 65.3ms
# 83:	learn: 1.4443852	total: 322ms	remaining: 61.4ms
# 84:	learn: 1.4380498	total: 326ms	remaining: 57.5ms
# 85:	learn: 1.4312507	total: 330ms	remaining: 53.7ms
# 86:	learn: 1.4155750	total: 333ms	remaining: 49.8ms
# 87:	learn: 1.4117828	total: 337ms	remaining: 45.9ms
# 88:	learn: 1.3968724	total: 340ms	remaining: 42.1ms
# 89:	learn: 1.3776106	total: 344ms	remaining: 38.2ms
# 90:	learn: 1.3724604	total: 348ms	remaining: 34.4ms
# 91:	learn: 1.3594689	total: 351ms	remaining: 30.5ms
# 92:	learn: 1.3422717	total: 355ms	remaining: 26.7ms
# 93:	learn: 1.3221721	total: 359ms	remaining: 22.9ms
# 94:	learn: 1.3087952	total: 364ms	remaining: 19.2ms
# 95:	learn: 1.2879923	total: 367ms	remaining: 15.3ms
# 96:	learn: 1.2729858	total: 371ms	remaining: 11.5ms
# 97:	learn: 1.2617511	total: 375ms	remaining: 7.65ms
# 98:	learn: 1.2435063	total: 379ms	remaining: 3.82ms
# 99:	learn: 1.2342354	total: 382ms	remaining: 0us
# Random Forest: Train R2 Score - 0.9971583288043819, Test R2 Score - 0.9863158961404626, MSE - 1.8419370253880818, MAE - 0.737762451171875
# Decision Tree: Train R2 Score - 1.0, Test R2 Score - 0.4896493322211579, MSE - 68.6953125, MAE - 5.565104166666667
# Gradient Boosting: Train R2 Score - 0.9872204527188735, Test R2 Score - 0.9241856678566982, MSE - 10.204922942943638, MAE - 2.3402665844406605
# Linear Regression: Train R2 Score - 0.591967266644972, Test R2 Score - 0.6167764047832125, MSE - 51.58348228555432, MAE - 5.628918144380331
# XGBRegressor: Train R2 Score - 0.9996916989305938, Test R2 Score - 0.9920748532187741, MSE - 1.0667575632145592, MAE - 0.6579587509495468
# CatBoosting Regressor: Train R2 Score - 0.989774009124166, Test R2 Score - 0.9710989874819888, MSE - 3.8901959218196587, MAE - 1.3551970658245738
# AdaBoost Regressor: Train R2 Score - 0.9238561310012863, Test R2 Score - 0.9053145213065451, MSE - 12.745057386458924, MAE - 2.4861743102483884
# Final Best Model after Fine-tune with Hyper Paramaters
# (0.9920748532187741, 1.0667575632145592, 0.6579587509495468)

# %% [markdown]
# ## **Push to github**

# %%
# !git config --global user.email "ehthanhtruc@gmail.com"
# !git config --global user.name "truc-nmt"

# %% [markdown]
# <a href="https://colab.research.google.com/github/truc-nmt/tiki_discount_rate/blob/main/4_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 4: Modeling - TrucNMT**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install dill catboost xgboost

# %%
import os
import sys
import pandas as pd
import numpy as np
from dataclasses import dataclass

# Packages for logger
import logging
from datetime import datetime

# Packages for model evaluation
import dill
import pickle
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GridSearchCV, train_test_split


# Packages for data transformation
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder

# Packages for data transformation
from catboost import CatBoostRegressor
from sklearn.ensemble import (
    AdaBoostRegressor,
    GradientBoostingRegressor,
    RandomForestRegressor
)

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score, f1_score, recall_score, precision_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %% [markdown]
# ## **Logger**

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
logs_path = os.path.join(os.getcwd(), "logs", LOG_FILE)
os.makedirs(logs_path, exist_ok=True)

LOG_FILE_PATH = os.path.join(logs_path, LOG_FILE)

logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(lineno)d %(name)s - %(levelname)s - %(message)s",
    level=logging.INFO,
)

# %% [markdown]
# ## **Exception**

# %%
def error_message_detail(error, error_detail:sys):

    _, _, exc_tb = error_detail.exc_info()          # Get info about traceback(Info about error position)
    file_name = exc_tb.tb_frame.f_code.co_filename  # Get name of file script Python from "exc_tb"
    error_message="Error occured in python script name [{0}] line number [{1}] error message[{2}]".format(
    file_name,exc_tb.tb_lineno,str(error))

    return error_message


class CustomException(Exception):

    def __init__(self, error_message, error_detail:sys):
        super().__init__(error_message)
        self.error_message = error_message_detail(error_message, error_detail=error_detail)

    def __str__(self):
        return self.error_message

# %% [markdown]
# ## **Utils**

# %%
def save_object(file_path, obj):
    try:
        dir_path = os.path.dirname(file_path) #  is used to get the directory path of the file_path.
        os.makedirs(dir_path, exist_ok=True)

        with open(file_path, "wb") as file_obj:
            pickle.dump(obj, file_obj)

    except Exception as e:
        raise CustomException(e, sys)


def load_object(file_path):
    try:
        with open(file_path, "rb") as file_obj:
            return pickle.load(file_obj)

    except Exception as e:
        raise CustomException(e, sys)

def evaluate_models(X_train, y_train, X_test, y_test, models, param):
    try:
        report = {}

        for model_name, model in models.items():
            para = param[model_name]

            gs = GridSearchCV(model, para, cv=3)
            gs.fit(X_train, y_train)

            model.set_params(**gs.best_params_)
            model.fit(X_train, y_train)

            y_train_pred = model.predict(X_train)
            y_test_pred = model.predict(X_test)

            train_r2_score = r2_score(y_train, y_train_pred)
            test_r2_score = r2_score(y_test, y_test_pred)
            mse = mean_squared_error(y_test, y_test_pred)
            mae = mean_absolute_error(y_test, y_test_pred)

            report[model_name] = (train_r2_score, test_r2_score, mse, mae)

        return report

    except Exception as e:
        raise CustomException(e, sys)

# %% [markdown]
# ##**1. Data Ingestion**

# %%
@dataclass
class DataIngestionConfig:
    train_path: str = os.path.join('/content/data', 'train.csv')
    test_path: str = os.path.join('/content/data', 'test.csv')
    raw_path: str = os.path.join('/content/data', 'raw.csv')

class DataIngestion:

    def __init__(self):
        self.ingestion_config = DataIngestionConfig()

    def initiate_data_ingestion(self):
        logging.info("Entered the data ingestion method or component")

        try:
            df = pd.read_csv('/content/Data_Tiki_Cleaned.csv')
            logging.info("Read the dataset as dataframe")

            os.makedirs(os.path.dirname(self.ingestion_config.train_path), exist_ok= True)

            df.to_csv(self.ingestion_config.raw_path, index = False, header = True)

            logging.info("Train test split initiated")

            # Make dataset
            train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
            train_set.to_csv(self.ingestion_config.train_path, index = False, header = True)
            test_set.to_csv(self.ingestion_config.test_path, index = False, header = True)


            logging.info("Data Ingestion Completed!")

            return(
                self.ingestion_config.train_path,
                self.ingestion_config.test_path,
            )

        except Exception as e:
            raise CustomException(e, sys)

# %% [markdown]
# ##**2. Data Transformation**

# %%
class MultiColumnLabelEncoder:

    def __init__(self, columns=None):
        self.columns = columns if columns else []

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_ = X.copy()
        for col in self.columns:
            le = LabelEncoder()
            X_[col] = le.fit_transform(X_[col])
        return X_

    def fit_transform(self, X, y=None):
        return self.fit(X).transform(X)

@dataclass
class DataTransformationConfig:
    preprocessor_obj_file_path = os.path.join("data", "preprocessor.pkl")

class DataTransformation:

    def __init__(self):
        self.data_transformation_config = DataTransformationConfig()

    def get_data_transformation_object(self):
        '''

        This function is responsible for data transformation

        '''

        '''
            Information of columns data types after cleaned and filled null values!
            RangeIndex: 1916 entries, 0 to 1915
            Data columns (total 24 columns):
            #   Column             Non-Null Count  Dtype
            ---  ------             --------------  -----
            0   Name               1916 non-null   object
            1   Link Product       1916 non-null   object
            2   Store              1916 non-null   object
            3   Type               1916 non-null   object
            4   Author Name        1916 non-null   object
            5   Short Description  1916 non-null   object
            6   Publisher          1916 non-null   object
            7   Translators        1916 non-null   object
            8   Categories         1916 non-null   object
            9   Width              1916 non-null   float64
            10  Length             1916 non-null   float64
            11  Height             1916 non-null   float64
            12  Product ID         1916 non-null   int64
            13  Price              1916 non-null   int64
            14  Original Price     1916 non-null   int64
            15  Discount           1916 non-null   int64
            16  Discount Rate      1916 non-null   int64
            17  Rating             1916 non-null   float64
            18  Review Count       1916 non-null   int64
            19  Quantity Sold      1916 non-null   float64
            20  Number of page     1916 non-null   float64
            21  Range Price        1916 non-null   object
            22  Publication Date   1916 non-null   object
            23  Publication Year   1916 non-null   float64
            dtypes: float64(7), int64(6), object(11)
        '''
        try:

            # numerical_columns = df.select_dtypes(include=['number']).columns.tolist()

            numerical_columns = [
                                'Width',
                                'Length',
                                'Height',
                                'Product_ID',
                                'Price',
                                'Original_Price',
                                'Discount',
                                # 'Discount_Rate', # target
                                'Rating',
                                'Review_Count',
                                'Quantity_Sold',
                                'Number_of_page',
                                'Publication_Year'
                                ]
            # categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
            categorical_columns = [
                                'Store',
                                'Type',
                                'Author_Name',
                                'Publisher',
                                'Translators',
                                'Categories',
                                'Range_Price',
                            ]

            # Pipeline

            num_pipeline = Pipeline(
                steps = [
                    # ("imputer", SimpleImputer(strategy="median")),
                    ("scaler", StandardScaler())
                ]
            )

            cate_pipeline = Pipeline(
                steps=[
                    ("label_encoder", MultiColumnLabelEncoder(columns=categorical_columns)),
                    ("scaler", StandardScaler(with_mean=False))
                ]
            )

            # Log info

            logging.info(f"Categorical columns: {categorical_columns}")
            logging.info(f"Numerical columns: {numerical_columns}")

            # Preprocessor

            preprocessor = ColumnTransformer(
                [
                    ("num_pipeline", num_pipeline, numerical_columns),
                    ("cate_pipeline", cate_pipeline, categorical_columns),
                ]
            )

            return preprocessor

        except Exception as e:
            raise CustomException(e, sys)

    def initiate_data_transformation(self, train_path, test_path):

        try:
            train_df = pd.read_csv(train_path)
            test_df = pd.read_csv(test_path)

            # print(train_df.columns)
            # print(test_df.columns)

            logging.info("read train and test data completed!")
            logging.info("Obtaining preprocessing object")

            preprocessing_obj = self.get_data_transformation_object()

            target_column_name = "Discount_Rate"
            numerical_columns = train_df.select_dtypes(include=['number']).columns.tolist()
            # print(numerical_columns)


            input_feature_train_df = train_df.drop(columns=[target_column_name], axis = 1)
            # print(input_feature_train_df.info)
            target_feature_train_df = train_df[target_column_name]

            input_feature_test_df = test_df.drop(columns=[target_column_name], axis = 1)
            target_feature_test_df = test_df[target_column_name]

            logging.info(f"Applying preprocessing object on training dataframe and testing dataframe")

            input_feature_train_arr = preprocessing_obj.fit_transform(input_feature_train_df)
            input_feature_test_arr = preprocessing_obj.transform(input_feature_test_df)

            train_arr = np.c_[input_feature_train_arr, np.array(target_feature_train_df)]
            test_arr = np.c_[input_feature_test_arr, np.array(target_feature_test_df)]

            logging.info(f"Saved preprocessing object.")

            save_object(
                file_path= self.data_transformation_config.preprocessor_obj_file_path,
                obj=preprocessing_obj
            )

            return(train_arr, test_arr, self.data_transformation_config.preprocessor_obj_file_path)

        except Exception as e:
            raise CustomException(e, sys)

# %% [markdown]
# ##**3. Model Trainer**

# %%
@dataclass
class ModelTrainerConfig:
    train_model_file_path = os.path.join("models", "model.pkl")


class ModelTrainer:

    def __init__(self):
        self.model_trainer_config = ModelTrainerConfig()


    def initiate_model_trainer(self, train_array, test_array):
        try:
            logging.info("Splitting training and test input data")
            X_train, y_train, X_test, y_test = (
                train_array[:, :-1],
                train_array[:, -1],
                test_array[:, :-1],
                test_array[:, -1]
            )

            models = {
                "Random Forest": RandomForestRegressor(),
                "Decision Tree": DecisionTreeRegressor(),
                "Gradient Boosting": GradientBoostingRegressor(),
                "Linear Regression": LinearRegression(),
                "XGBRegressor": XGBRegressor(),
                "CatBoosting Regressor": CatBoostRegressor(verbose=True),
                "AdaBoost Regressor": AdaBoostRegressor(),
            }

            # Fine-tune Hyper Parameter
            params = {
                "Decision Tree": {
                    'criterion': ['poisson', 'absolute_error', 'friedman_mse', 'squared_error'],
                    'splitter': ['best', 'random'],
                    'max_features': ['sqrt', 'log2'],
                },
                "Random Forest": {
                    'criterion': ['squared_error', 'friedman_mse', 'poisson', 'absolute_error'],
                    'max_features': ['sqrt', 'log2', None],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                },
                "Gradient Boosting": {
                    'loss': ['ls', 'lad', 'huber', 'quantile'],
                    'learning_rate': [0.1, 0.01, 0.05, 0.001],
                    'subsample': [0.6, 0.7, 0.75, 0.8, 0.85, 0.9],
                    'max_features': ['None', 'sqrt', 'log2'],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                },
                "Linear Regression": {},
                "XGBRegressor": {
                    'learning_rate': [0.1, 0.01, 0.05, 0.001],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                },
                "CatBoosting Regressor": {
                    'depth': [6, 8, 10],
                    'learning_rate': [0.01, 0.05, 0.1],
                    'iterations': [30, 50, 100]
                },
                "AdaBoost Regressor": {
                    'learning_rate': [0.1, 0.01, 0.5, 0.001],
                    'loss': ['linear', 'square', 'exponential'],
                    'n_estimators': [8, 16, 32, 64, 128, 256]
                }
            }

            model_report = evaluate_models(X_train, y_train, X_test, y_test, models, params)

            # Print all model results
            logging.info("Model results:")
            for model_name, scores in model_report.items():
                logging.info(f"{model_name}: Train R2 Score - {scores[0]}, Test R2 Score - {scores[1]}, MSE - {scores[2]}, MAE - {scores[3]}") # Save in log file
                print((f"{model_name}: Train R2 Score - {scores[0]}, Test R2 Score - {scores[1]}, MSE - {scores[2]}, MAE - {scores[3]}"))

            # Find the best model based on test R2 score
            best_model_name = max(model_report, key=lambda k: model_report[k][1])  # Choose based on test R2 score
            best_model_scores = model_report[best_model_name]

            # Check if the test R2 score of the best model meets the threshold
            if best_model_scores[1] < 0.6:
                raise CustomException("No best model found")

            # Retrieve the best model
            best_model = models[best_model_name]

            # Save the best model
            save_object(file_path=self.model_trainer_config.train_model_file_path, obj=best_model)

            # Return the test R2 score, MSE, and MAE of the best model
            return best_model_scores[1], best_model_scores[2], best_model_scores[3]

        except Exception as e:
            raise CustomException(e, sys)

# %% [markdown]
# ## **4. Results**

# %%
obj = DataIngestion()
train_data, test_data = obj.initiate_data_ingestion()

data_transformation = DataTransformation()
train_arr, test_arr, _ = data_transformation.initiate_data_transformation(train_data, test_data)

modeltrainer = ModelTrainer()
print(modeltrainer.initiate_model_trainer(train_arr, test_arr))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 3456 fits failed out of a total of 5184.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1296 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py", line 420, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingRegressor must be a str among {'squared_error', 'absolute_error', 'quantile', 'huber'}. Got 'ls' instead.
#
# --------------------------------------------------------------------------------
# 1296 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py", line 420, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingRegressor must be a str among {'squared_error', 'absolute_error', 'quantile', 'huber'}. Got 'lad' instead.
#
# --------------------------------------------------------------------------------
# 864 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py", line 420, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of GradientBoostingRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'auto' (deprecated), 'log2'} or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan ... -1.15989307 -1.16228894
#  -1.15747755]
#   warnings.warn(
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# 8:	learn: 11.6383024	total: 32ms	remaining: 74.6ms
# 9:	learn: 11.5660014	total: 35.2ms	remaining: 70.5ms
# 10:	learn: 11.4946196	total: 38.6ms	remaining: 66.7ms
# 11:	learn: 11.4207493	total: 42.2ms	remaining: 63.2ms
# 12:	learn: 11.3461089	total: 45.7ms	remaining: 59.8ms
# 13:	learn: 11.2666259	total: 49.2ms	remaining: 56.2ms
# 14:	learn: 11.1885251	total: 52.5ms	remaining: 52.5ms
# 15:	learn: 11.1209663	total: 56ms	remaining: 49ms
# 16:	learn: 11.0508081	total: 59.3ms	remaining: 45.3ms
# 17:	learn: 10.9822952	total: 62.9ms	remaining: 42ms
# 18:	learn: 10.9096954	total: 69.6ms	remaining: 40.3ms
# 19:	learn: 10.8414087	total: 72.8ms	remaining: 36.4ms
# 20:	learn: 10.7837768	total: 75.9ms	remaining: 32.5ms
# 21:	learn: 10.7162213	total: 79ms	remaining: 28.7ms
# 22:	learn: 10.6542976	total: 85.8ms	remaining: 26.1ms
# 23:	learn: 10.5938525	total: 92.3ms	remaining: 23.1ms
# 24:	learn: 10.5250411	total: 95.9ms	remaining: 19.2ms
# 25:	learn: 10.4568657	total: 99ms	remaining: 15.2ms
# 26:	learn: 10.3955711	total: 102ms	remaining: 11.3ms
# 27:	learn: 10.3337178	total: 106ms	remaining: 7.54ms
# 28:	learn: 10.2678682	total: 109ms	remaining: 3.76ms
# 29:	learn: 10.2094397	total: 112ms	remaining: 0us
# 0:	learn: 11.7371678	total: 3.25ms	remaining: 94.2ms
# 1:	learn: 11.4249029	total: 7.11ms	remaining: 99.5ms
# 2:	learn: 11.1255478	total: 10.6ms	remaining: 95.2ms
# 3:	learn: 10.7830159	total: 14ms	remaining: 90.9ms
# 4:	learn: 10.4746286	total: 17.4ms	remaining: 86.9ms
# 5:	learn: 10.1815730	total: 20.9ms	remaining: 83.6ms
# 6:	learn: 9.9226266	total: 24.3ms	remaining: 79.9ms
# 7:	learn: 9.6279769	total: 27.7ms	remaining: 76.1ms
# 8:	learn: 9.3410207	total: 31ms	remaining: 72.3ms
# 9:	learn: 9.1005872	total: 34.4ms	remaining: 68.7ms
# 10:	learn: 8.8600093	total: 37.7ms	remaining: 65.1ms
# 11:	learn: 8.6417687	total: 40.9ms	remaining: 61.4ms
# 12:	learn: 8.4021775	total: 44.3ms	remaining: 57.9ms
# 13:	learn: 8.1402440	total: 47.7ms	remaining: 54.5ms
# 14:	learn: 7.9172339	total: 51.5ms	remaining: 51.5ms
# 15:	learn: 7.7096108	total: 55.1ms	remaining: 48.2ms
# 16:	learn: 7.5069440	total: 58.7ms	remaining: 44.9ms
# 17:	learn: 7.3323124	total: 62.1ms	remaining: 41.4ms
# 18:	learn: 7.1727287	total: 65.5ms	remaining: 37.9ms
# 19:	learn: 6.9910156	total: 69.1ms	remaining: 34.5ms
# 20:	learn: 6.8637840	total: 72.6ms	remaining: 31.1ms
# 21:	learn: 6.7041921	total: 76.1ms	remaining: 27.7ms
# 22:	learn: 6.5773906	total: 79.5ms	remaining: 24.2ms
# 23:	learn: 6.4539426	total: 82.7ms	remaining: 20.7ms
# 24:	learn: 6.3011132	total: 86.1ms	remaining: 17.2ms
# 25:	learn: 6.1992023	total: 89.5ms	remaining: 13.8ms
# 26:	learn: 6.0862278	total: 92.8ms	remaining: 10.3ms
# 27:	learn: 5.9580580	total: 96.2ms	remaining: 6.87ms
# 28:	learn: 5.8214915	total: 99.9ms	remaining: 3.44ms
# 29:	learn: 5.6930476	total: 103ms	remaining: 0us
# 0:	learn: 11.7887853	total: 3.68ms	remaining: 107ms
# 1:	learn: 11.4084316	total: 7.29ms	remaining: 102ms
# 2:	learn: 11.1177022	total: 10.8ms	remaining: 97ms
# 3:	learn: 10.8110105	total: 14.1ms	remaining: 91.6ms
# 4:	learn: 10.4882965	total: 17.5ms	remaining: 87.6ms
# 5:	learn: 10.1995189	total: 20.9ms	remaining: 83.5ms
# 6:	learn: 9.9339889	total: 24.2ms	remaining: 79.5ms
# 7:	learn: 9.6349820	total: 27.5ms	remaining: 75.6ms
# 8:	learn: 9.3403122	total: 30.9ms	remaining: 72.1ms
# 9:	learn: 9.0948843	total: 34.4ms	remaining: 68.7ms
# 10:	learn: 8.8469038	total: 37.8ms	remaining: 65.3ms
# 11:	learn: 8.6140906	total: 41.3ms	remaining: 62ms
# 12:	learn: 8.3787208	total: 44.9ms	remaining: 58.7ms
# 13:	learn: 8.1270282	total: 48.4ms	remaining: 55.4ms
# 14:	learn: 7.8916450	total: 52ms	remaining: 52ms
# 15:	learn: 7.6699679	total: 55.5ms	remaining: 48.5ms
# 16:	learn: 7.4587531	total: 59.1ms	remaining: 45.2ms
# 17:	learn: 7.2695922	total: 62.8ms	remaining: 41.9ms
# 18:	learn: 7.0911534	total: 66.3ms	remaining: 38.4ms
# 19:	learn: 6.9403145	total: 69.8ms	remaining: 34.9ms
# 20:	learn: 6.7978286	total: 73.2ms	remaining: 31.4ms
# 21:	learn: 6.6818708	total: 76.7ms	remaining: 27.9ms
# 22:	learn: 6.5598187	total: 80.2ms	remaining: 24.4ms
# 23:	learn: 6.4164870	total: 83.8ms	remaining: 20.9ms
# 24:	learn: 6.3093439	total: 87.4ms	remaining: 17.5ms
# 25:	learn: 6.1923230	total: 93.5ms	remaining: 14.4ms
# 26:	learn: 6.0408143	total: 97.1ms	remaining: 10.8ms
# 27:	learn: 5.9315947	total: 100ms	remaining: 7.17ms
# 28:	learn: 5.8108461	total: 104ms	remaining: 3.57ms
# 29:	learn: 5.6661036	total: 107ms	remaining: 0us
# 0:	learn: 11.9262218	total: 3.53ms	remaining: 102ms
# 1:	learn: 11.5410284	total: 6.91ms	remaining: 96.8ms
# 2:	learn: 11.2162597	total: 10.5ms	remaining: 94.3ms
# 3:	learn: 10.8592516	total: 14.2ms	remaining: 92.2ms
# 4:	learn: 10.5250672	total: 17.7ms	remaining: 88.6ms
# 5:	learn: 10.2643689	total: 21.3ms	remaining: 85.4ms
# 6:	learn: 9.9936870	total: 24.7ms	remaining: 81.1ms
# 7:	learn: 9.6832311	total: 28ms	remaining: 77.1ms
# 8:	learn: 9.4134625	total: 34.1ms	remaining: 79.5ms
# 9:	learn: 9.1591485	total: 37.4ms	remaining: 74.9ms
# 10:	learn: 8.9008568	total: 43.4ms	remaining: 75ms
# 11:	learn: 8.6623901	total: 50.4ms	remaining: 75.5ms
# 12:	learn: 8.4095659	total: 53.8ms	remaining: 70.4ms
# 13:	learn: 8.1444580	total: 57.4ms	remaining: 65.6ms
# 14:	learn: 7.9132616	total: 61ms	remaining: 61ms
# 15:	learn: 7.7263389	total: 64.6ms	remaining: 56.5ms
# 16:	learn: 7.5375652	total: 68.3ms	remaining: 52.2ms
# 17:	learn: 7.3497801	total: 72.2ms	remaining: 48.2ms
# 18:	learn: 7.1481795	total: 75.8ms	remaining: 43.9ms
# 19:	learn: 6.9731763	total: 79.7ms	remaining: 39.9ms
# 20:	learn: 6.8453100	total: 86.1ms	remaining: 36.9ms
# 21:	learn: 6.6764946	total: 98.8ms	remaining: 35.9ms
# 22:	learn: 6.5442900	total: 106ms	remaining: 32.4ms
# 23:	learn: 6.3783528	total: 113ms	remaining: 28.3ms
# 24:	learn: 6.2399800	total: 122ms	remaining: 24.5ms
# 25:	learn: 6.1100955	total: 130ms	remaining: 20.1ms
# 26:	learn: 5.9911095	total: 134ms	remaining: 14.8ms
# 27:	learn: 5.8734647	total: 137ms	remaining: 9.8ms
# 28:	learn: 5.7489487	total: 141ms	remaining: 4.85ms
# 29:	learn: 5.6197717	total: 144ms	remaining: 0us
# 0:	learn: 11.3553705	total: 3.21ms	remaining: 93ms
# 1:	learn: 10.7727863	total: 6.67ms	remaining: 93.4ms
# 2:	learn: 10.2425768	total: 10ms	remaining: 90.4ms
# 3:	learn: 9.6400848	total: 13.3ms	remaining: 86.7ms
# 4:	learn: 9.1411460	total: 16.6ms	remaining: 83ms
# 5:	learn: 8.6871315	total: 20.2ms	remaining: 80.7ms
# 6:	learn: 8.3131782	total: 24.2ms	remaining: 79.5ms
# 7:	learn: 7.8670826	total: 27.7ms	remaining: 76.2ms
# 8:	learn: 7.5010069	total: 31.2ms	remaining: 72.7ms
# 9:	learn: 7.1843051	total: 34.5ms	remaining: 68.9ms
# 10:	learn: 6.9251572	total: 37.8ms	remaining: 65.3ms
# 11:	learn: 6.6599581	total: 41.5ms	remaining: 62.3ms
# 12:	learn: 6.3624899	total: 44.9ms	remaining: 58.7ms
# 13:	learn: 6.0539288	total: 48.3ms	remaining: 55.2ms
# 14:	learn: 5.7690878	total: 51.7ms	remaining: 51.7ms
# 15:	learn: 5.5587055	total: 59ms	remaining: 51.6ms
# 16:	learn: 5.3336201	total: 63.3ms	remaining: 48.4ms
# 17:	learn: 5.1402284	total: 66.9ms	remaining: 44.6ms
# 18:	learn: 4.9690087	total: 70.1ms	remaining: 40.6ms
# 19:	learn: 4.8262016	total: 73.2ms	remaining: 36.6ms
# 20:	learn: 4.7255142	total: 76.5ms	remaining: 32.8ms
# 21:	learn: 4.5957024	total: 79.6ms	remaining: 29ms
# 22:	learn: 4.4880693	total: 85.6ms	remaining: 26.1ms
# 23:	learn: 4.3995372	total: 89.1ms	remaining: 22.3ms
# 24:	learn: 4.2913804	total: 92.5ms	remaining: 18.5ms
# 25:	learn: 4.1886451	total: 96ms	remaining: 14.8ms
# 26:	learn: 4.1193525	total: 99.6ms	remaining: 11.1ms
# 27:	learn: 4.0066093	total: 103ms	remaining: 7.38ms
# 28:	learn: 3.9017326	total: 107ms	remaining: 3.69ms
# 29:	learn: 3.7851406	total: 110ms	remaining: 0us
# 0:	learn: 11.4211024	total: 3.73ms	remaining: 108ms
# 1:	learn: 10.6980587	total: 7.31ms	remaining: 102ms
# 2:	learn: 10.1778914	total: 10.7ms	remaining: 96ms
# 3:	learn: 9.5669097	total: 14ms	remaining: 90.9ms
# 4:	learn: 9.0402591	total: 20ms	remaining: 100ms
# 5:	learn: 8.5351592	total: 23.1ms	remaining: 92.5ms
# 6:	learn: 8.1500808	total: 26.2ms	remaining: 86ms
# 7:	learn: 7.7125359	total: 29ms	remaining: 79.7ms
# 8:	learn: 7.3056745	total: 32.3ms	remaining: 75.4ms
# 9:	learn: 7.0012815	total: 35.5ms	remaining: 71ms
# 10:	learn: 6.6799951	total: 38.7ms	remaining: 66.9ms
# 11:	learn: 6.4134038	total: 42ms	remaining: 63.1ms
# 12:	learn: 6.1325495	total: 45.2ms	remaining: 59.1ms
# 13:	learn: 5.8293081	total: 48.4ms	remaining: 55.4ms
# 14:	learn: 5.6035109	total: 51.7ms	remaining: 51.7ms
# 15:	learn: 5.4180202	total: 55.1ms	remaining: 48.2ms
# 16:	learn: 5.2247342	total: 58.4ms	remaining: 44.7ms
# 17:	learn: 5.0468601	total: 61.8ms	remaining: 41.2ms
# 18:	learn: 4.8909254	total: 65.2ms	remaining: 37.7ms
# 19:	learn: 4.6817153	total: 68.5ms	remaining: 34.3ms
# 20:	learn: 4.5836675	total: 71.8ms	remaining: 30.8ms
# 21:	learn: 4.3961353	total: 75ms	remaining: 27.3ms
# 22:	learn: 4.2983973	total: 78.2ms	remaining: 23.8ms
# 23:	learn: 4.1740758	total: 81.4ms	remaining: 20.4ms
# 24:	learn: 4.0767632	total: 84.8ms	remaining: 16.9ms
# 25:	learn: 3.9686340	total: 88.2ms	remaining: 13.6ms
# 26:	learn: 3.8539033	total: 97.3ms	remaining: 10.8ms
# 27:	learn: 3.7678156	total: 100ms	remaining: 7.17ms
# 28:	learn: 3.6553975	total: 104ms	remaining: 3.57ms
# 29:	learn: 3.5509880	total: 107ms	remaining: 0us
# 0:	learn: 11.5346453	total: 3.27ms	remaining: 94.7ms
# 1:	learn: 10.8050644	total: 6.39ms	remaining: 89.4ms
# 2:	learn: 10.2269850	total: 9.38ms	remaining: 84.4ms
# 3:	learn: 9.6058770	total: 12.4ms	remaining: 80.7ms
# 4:	learn: 9.0683269	total: 15.8ms	remaining: 79ms
# 5:	learn: 8.5863208	total: 19.4ms	remaining: 77.5ms
# 6:	learn: 8.1906558	total: 23ms	remaining: 75.7ms
# 7:	learn: 7.7583650	total: 26.8ms	remaining: 73.6ms
# 8:	learn: 7.3474592	total: 30.5ms	remaining: 71.1ms
# 9:	learn: 7.0117595	total: 34ms	remaining: 67.9ms
# 10:	learn: 6.6841657	total: 37.4ms	remaining: 64.5ms
# 11:	learn: 6.3986390	total: 40.8ms	remaining: 61.2ms
# 12:	learn: 6.0707933	total: 44.3ms	remaining: 57.9ms
# 13:	learn: 5.7480267	total: 48ms	remaining: 54.9ms
# 14:	learn: 5.5112950	total: 51.8ms	remaining: 51.8ms
# 15:	learn: 5.2713682	total: 55.2ms	remaining: 48.3ms
# 16:	learn: 5.0695457	total: 58.8ms	remaining: 44.9ms
# 17:	learn: 4.8892269	total: 62.1ms	remaining: 41.4ms
# 18:	learn: 4.7035606	total: 65.9ms	remaining: 38.1ms
# 19:	learn: 4.5364614	total: 69.1ms	remaining: 34.6ms
# 20:	learn: 4.4089842	total: 72.8ms	remaining: 31.2ms
# 21:	learn: 4.2522490	total: 78.8ms	remaining: 28.7ms
# 22:	learn: 4.1467359	total: 82.6ms	remaining: 25.1ms
# 23:	learn: 4.0100055	total: 86.2ms	remaining: 21.5ms
# 24:	learn: 3.9082364	total: 89.7ms	remaining: 17.9ms
# 25:	learn: 3.7755290	total: 93.2ms	remaining: 14.3ms
# 26:	learn: 3.6794094	total: 96.8ms	remaining: 10.8ms
# 27:	learn: 3.6053269	total: 100ms	remaining: 7.17ms
# 28:	learn: 3.5119280	total: 104ms	remaining: 3.58ms
# 29:	learn: 3.4193710	total: 107ms	remaining: 0us
# 0:	learn: 12.0474412	total: 3.6ms	remaining: 176ms
# 1:	learn: 11.9717073	total: 7.5ms	remaining: 180ms
# 2:	learn: 11.9059822	total: 11ms	remaining: 173ms
# 3:	learn: 11.8289107	total: 14.3ms	remaining: 165ms
# 4:	learn: 11.7557857	total: 17.6ms	remaining: 158ms
# 5:	learn: 11.6845494	total: 21.4ms	remaining: 157ms
# 6:	learn: 11.6181709	total: 24.7ms	remaining: 151ms
# 7:	learn: 11.5403476	total: 27.8ms	remaining: 146ms
# 8:	learn: 11.4695802	total: 31.2ms	remaining: 142ms
# 9:	learn: 11.4015307	total: 34.4ms	remaining: 138ms
# 10:	learn: 11.3343708	total: 37.8ms	remaining: 134ms
# 11:	learn: 11.2648526	total: 41.2ms	remaining: 130ms
# 12:	learn: 11.1904938	total: 44.7ms	remaining: 127ms
# 13:	learn: 11.1149024	total: 48.1ms	remaining: 124ms
# 14:	learn: 11.0413905	total: 51.5ms	remaining: 120ms
# 15:	learn: 10.9743156	total: 55.1ms	remaining: 117ms
# 16:	learn: 10.9066946	total: 58.4ms	remaining: 113ms
# 17:	learn: 10.8406812	total: 61.7ms	remaining: 110ms
# 18:	learn: 10.7795569	total: 65.2ms	remaining: 106ms
# 19:	learn: 10.7188733	total: 68.5ms	remaining: 103ms
# 20:	learn: 10.6622903	total: 71.7ms	remaining: 99ms
# 21:	learn: 10.6064787	total: 75.1ms	remaining: 95.5ms
# 22:	learn: 10.5482488	total: 78.3ms	remaining: 92ms
# 23:	learn: 10.4850483	total: 81.7ms	remaining: 88.5ms
# 24:	learn: 10.4293920	total: 85ms	remaining: 85ms
# 25:	learn: 10.3637645	total: 88.3ms	remaining: 81.5ms
# 26:	learn: 10.3039968	total: 91.4ms	remaining: 77.8ms
# 27:	learn: 10.2391840	total: 94.7ms	remaining: 74.4ms
# 28:	learn: 10.1844578	total: 98ms	remaining: 71ms
# 29:	learn: 10.1269974	total: 101ms	remaining: 67.5ms
# 30:	learn: 10.0721983	total: 104ms	remaining: 64ms
# 31:	learn: 10.0174720	total: 108ms	remaining: 60.6ms
# 32:	learn: 9.9639640	total: 111ms	remaining: 57.1ms
# 33:	learn: 9.9109616	total: 114ms	remaining: 53.8ms
# 34:	learn: 9.8483429	total: 118ms	remaining: 50.4ms
# 35:	learn: 9.7961489	total: 121ms	remaining: 47ms
# 36:	learn: 9.7404011	total: 124ms	remaining: 43.7ms
# 37:	learn: 9.6847317	total: 128ms	remaining: 40.3ms
# 38:	learn: 9.6277063	total: 131ms	remaining: 36.9ms
# 39:	learn: 9.5708521	total: 135ms	remaining: 33.6ms
# 40:	learn: 9.5141396	total: 138ms	remaining: 30.3ms
# 41:	learn: 9.4626795	total: 142ms	remaining: 27ms
# 42:	learn: 9.4136052	total: 144ms	remaining: 23.4ms
# 43:	learn: 9.3557706	total: 147ms	remaining: 20.1ms
# 44:	learn: 9.3017360	total: 151ms	remaining: 16.7ms
# 45:	learn: 9.2464749	total: 154ms	remaining: 13.4ms
# 46:	learn: 9.1933727	total: 157ms	remaining: 10ms
# 47:	learn: 9.1429677	total: 161ms	remaining: 6.71ms
# 48:	learn: 9.0898165	total: 165ms	remaining: 3.36ms
# 49:	learn: 9.0317548	total: 168ms	remaining: 0us
# 0:	learn: 12.0876188	total: 3.37ms	remaining: 165ms
# 1:	learn: 12.0101542	total: 7.18ms	remaining: 172ms
# 2:	learn: 11.9462280	total: 10.5ms	remaining: 164ms
# 3:	learn: 11.8766055	total: 14.1ms	remaining: 162ms
# 4:	learn: 11.7993281	total: 17.9ms	remaining: 161ms
# 5:	learn: 11.7295218	total: 21.3ms	remaining: 157ms
# 6:	learn: 11.6623892	total: 24.6ms	remaining: 151ms
# 7:	learn: 11.5853543	total: 27.9ms	remaining: 147ms
# 8:	learn: 11.5049736	total: 33.2ms	remaining: 151ms
# 9:	learn: 11.4351770	total: 36.1ms	remaining: 145ms
# 10:	learn: 11.3609023	total: 39.5ms	remaining: 140ms
# 11:	learn: 11.2913618	total: 42.7ms	remaining: 135ms
# 12:	learn: 11.2213774	total: 45.8ms	remaining: 130ms
# 13:	learn: 11.1419547	total: 49ms	remaining: 126ms
# 14:	learn: 11.0666027	total: 52.4ms	remaining: 122ms
# 15:	learn: 11.0009093	total: 55.7ms	remaining: 118ms
# 16:	learn: 10.9378978	total: 59ms	remaining: 115ms
# 17:	learn: 10.8718306	total: 62.3ms	remaining: 111ms
# 18:	learn: 10.8025223	total: 66.1ms	remaining: 108ms
# 19:	learn: 10.7360424	total: 70.1ms	remaining: 105ms
# 20:	learn: 10.6792105	total: 73.5ms	remaining: 102ms
# 21:	learn: 10.6220447	total: 76.9ms	remaining: 97.9ms
# 22:	learn: 10.5552748	total: 80.7ms	remaining: 94.7ms
# 23:	learn: 10.4895436	total: 84ms	remaining: 91.1ms
# 24:	learn: 10.4331873	total: 87.4ms	remaining: 87.4ms
# 25:	learn: 10.3688947	total: 91.1ms	remaining: 84.1ms
# 26:	learn: 10.3134943	total: 94.4ms	remaining: 80.4ms
# 27:	learn: 10.2544168	total: 97.8ms	remaining: 76.8ms
# 28:	learn: 10.1934568	total: 101ms	remaining: 73.2ms
# 29:	learn: 10.1345617	total: 105ms	remaining: 69.8ms
# 30:	learn: 10.0823560	total: 108ms	remaining: 66.2ms
# 31:	learn: 10.0236730	total: 111ms	remaining: 62.6ms
# 32:	learn: 9.9669532	total: 115ms	remaining: 59.1ms
# 33:	learn: 9.9122968	total: 118ms	remaining: 55.6ms
# 34:	learn: 9.8490374	total: 122ms	remaining: 52.1ms
# 35:	learn: 9.7976747	total: 125ms	remaining: 48.6ms
# 36:	learn: 9.7365266	total: 128ms	remaining: 45.1ms
# 37:	learn: 9.6808952	total: 132ms	remaining: 41.6ms
# 38:	learn: 9.6215331	total: 135ms	remaining: 38.1ms
# 39:	learn: 9.5692442	total: 138ms	remaining: 34.6ms
# 40:	learn: 9.5095304	total: 142ms	remaining: 31.1ms
# 41:	learn: 9.4496014	total: 145ms	remaining: 27.7ms
# 42:	learn: 9.3972741	total: 149ms	remaining: 24.2ms
# 43:	learn: 9.3432035	total: 152ms	remaining: 20.7ms
# 44:	learn: 9.2920843	total: 155ms	remaining: 17.2ms
# 45:	learn: 9.2466171	total: 158ms	remaining: 13.8ms
# 46:	learn: 9.1962071	total: 162ms	remaining: 10.3ms
# 47:	learn: 9.1444185	total: 165ms	remaining: 6.87ms
# 48:	learn: 9.1008643	total: 168ms	remaining: 3.43ms
# 49:	learn: 9.0506506	total: 172ms	remaining: 0us
# 0:	learn: 12.2439202	total: 7.52ms	remaining: 368ms
# 1:	learn: 12.1636759	total: 14.3ms	remaining: 343ms
# 2:	learn: 12.0928441	total: 19.4ms	remaining: 304ms
# 3:	learn: 12.0126725	total: 24.7ms	remaining: 284ms
# 4:	learn: 11.9342153	total: 28.3ms	remaining: 255ms
# 5:	learn: 11.8698934	total: 31.7ms	remaining: 233ms
# 6:	learn: 11.8020036	total: 35.2ms	remaining: 216ms
# 7:	learn: 11.7200300	total: 38.7ms	remaining: 203ms
# 8:	learn: 11.6383024	total: 42.1ms	remaining: 192ms
# 9:	learn: 11.5660014	total: 45.7ms	remaining: 183ms
# 10:	learn: 11.4946196	total: 49.3ms	remaining: 175ms
# 11:	learn: 11.4207493	total: 52.8ms	remaining: 167ms
# 12:	learn: 11.3461089	total: 56.2ms	remaining: 160ms
# 13:	learn: 11.2666259	total: 60.6ms	remaining: 156ms
# 14:	learn: 11.1885251	total: 63.9ms	remaining: 149ms
# 15:	learn: 11.1209663	total: 67.3ms	remaining: 143ms
# 16:	learn: 11.0508081	total: 70.7ms	remaining: 137ms
# 17:	learn: 10.9822952	total: 74ms	remaining: 132ms
# 18:	learn: 10.9096954	total: 77.4ms	remaining: 126ms
# 19:	learn: 10.8414087	total: 80.7ms	remaining: 121ms
# 20:	learn: 10.7837768	total: 83.9ms	remaining: 116ms
# 21:	learn: 10.7162213	total: 87.1ms	remaining: 111ms
# 22:	learn: 10.6542976	total: 90.3ms	remaining: 106ms
# 23:	learn: 10.5938525	total: 93.6ms	remaining: 101ms
# 24:	learn: 10.5250411	total: 96.9ms	remaining: 96.9ms
# 25:	learn: 10.4568657	total: 100ms	remaining: 92.5ms
# 26:	learn: 10.3955711	total: 104ms	remaining: 88.3ms
# 27:	learn: 10.3337178	total: 107ms	remaining: 84ms
# 28:	learn: 10.2678682	total: 110ms	remaining: 79.9ms
# 29:	learn: 10.2094397	total: 114ms	remaining: 75.7ms
# 30:	learn: 10.1535152	total: 117ms	remaining: 71.6ms
# 31:	learn: 10.0918472	total: 123ms	remaining: 69.1ms
# 32:	learn: 10.0302151	total: 126ms	remaining: 64.8ms
# 33:	learn: 9.9751362	total: 129ms	remaining: 60.7ms
# 34:	learn: 9.9119890	total: 132ms	remaining: 56.7ms
# 35:	learn: 9.8552126	total: 136ms	remaining: 53ms
# 36:	learn: 9.7972956	total: 140ms	remaining: 49.1ms
# 37:	learn: 9.7345926	total: 143ms	remaining: 45.2ms
# 38:	learn: 9.6764191	total: 147ms	remaining: 41.3ms
# 39:	learn: 9.6186125	total: 150ms	remaining: 37.5ms
# 40:	learn: 9.5592405	total: 154ms	remaining: 33.7ms
# 41:	learn: 9.4993978	total: 157ms	remaining: 29.9ms
# 42:	learn: 9.4436181	total: 161ms	remaining: 26.2ms
# 43:	learn: 9.3837555	total: 164ms	remaining: 22.4ms
# 44:	learn: 9.3370566	total: 168ms	remaining: 18.6ms
# 45:	learn: 9.2886429	total: 171ms	remaining: 14.9ms
# 46:	learn: 9.2414893	total: 175ms	remaining: 11.2ms
# 47:	learn: 9.1926666	total: 178ms	remaining: 7.43ms
# 48:	learn: 9.1470896	total: 182ms	remaining: 3.71ms
# 49:	learn: 9.0945292	total: 185ms	remaining: 0us
# 0:	learn: 11.7371678	total: 3.14ms	remaining: 154ms
# 1:	learn: 11.4249029	total: 6.75ms	remaining: 162ms
# 2:	learn: 11.1255478	total: 10.3ms	remaining: 162ms
# 3:	learn: 10.7830159	total: 13.7ms	remaining: 157ms
# 4:	learn: 10.4746286	total: 17ms	remaining: 153ms
# 5:	learn: 10.1815730	total: 20.6ms	remaining: 151ms
# 6:	learn: 9.9226266	total: 23.9ms	remaining: 147ms
# 7:	learn: 9.6279769	total: 27.3ms	remaining: 144ms
# 8:	learn: 9.3410207	total: 30.7ms	remaining: 140ms
# 9:	learn: 9.1005872	total: 34ms	remaining: 136ms
# 10:	learn: 8.8600093	total: 37.8ms	remaining: 134ms
# 11:	learn: 8.6417687	total: 41.2ms	remaining: 131ms
# 12:	learn: 8.4021775	total: 44.6ms	remaining: 127ms
# 13:	learn: 8.1402440	total: 48.5ms	remaining: 125ms
# 14:	learn: 7.9172339	total: 52ms	remaining: 121ms
# 15:	learn: 7.7096108	total: 56ms	remaining: 119ms
# 16:	learn: 7.5069440	total: 59.7ms	remaining: 116ms
# 17:	learn: 7.3323124	total: 63ms	remaining: 112ms
# 18:	learn: 7.1727287	total: 66.3ms	remaining: 108ms
# 19:	learn: 6.9910156	total: 69.7ms	remaining: 105ms
# 20:	learn: 6.8637840	total: 73.1ms	remaining: 101ms
# 21:	learn: 6.7041921	total: 76.4ms	remaining: 97.2ms
# 22:	learn: 6.5773906	total: 79.9ms	remaining: 93.8ms
# 23:	learn: 6.4539426	total: 83.9ms	remaining: 90.9ms
# 24:	learn: 6.3011132	total: 87.6ms	remaining: 87.6ms
# 25:	learn: 6.1992023	total: 90.6ms	remaining: 83.6ms
# 26:	learn: 6.0862278	total: 93.7ms	remaining: 79.8ms
# 27:	learn: 5.9580580	total: 97.2ms	remaining: 76.4ms
# 28:	learn: 5.8214915	total: 101ms	remaining: 73.1ms
# 29:	learn: 5.6930476	total: 104ms	remaining: 69.4ms
# 30:	learn: 5.6270442	total: 108ms	remaining: 66ms
# 31:	learn: 5.5394550	total: 111ms	remaining: 62.5ms
# 32:	learn: 5.4596805	total: 114ms	remaining: 58.9ms
# 33:	learn: 5.3721826	total: 118ms	remaining: 55.4ms
# 34:	learn: 5.2605996	total: 121ms	remaining: 51.9ms
# 35:	learn: 5.1911321	total: 125ms	remaining: 48.4ms
# 36:	learn: 5.1028915	total: 128ms	remaining: 45ms
# 37:	learn: 4.9999632	total: 131ms	remaining: 41.5ms
# 38:	learn: 4.9062614	total: 135ms	remaining: 38ms
# 39:	learn: 4.8107795	total: 138ms	remaining: 34.5ms
# 40:	learn: 4.7168719	total: 141ms	remaining: 31ms
# 41:	learn: 4.6401623	total: 145ms	remaining: 27.6ms
# 42:	learn: 4.5628875	total: 148ms	remaining: 24.1ms
# 43:	learn: 4.4971022	total: 151ms	remaining: 20.7ms
# 44:	learn: 4.4466142	total: 155ms	remaining: 17.2ms
# 45:	learn: 4.3776326	total: 158ms	remaining: 13.7ms
# 46:	learn: 4.3207645	total: 162ms	remaining: 10.3ms
# 47:	learn: 4.2638266	total: 165ms	remaining: 6.89ms
# 48:	learn: 4.1997192	total: 169ms	remaining: 3.44ms
# 49:	learn: 4.1477306	total: 172ms	remaining: 0us
# 0:	learn: 11.7887853	total: 3.24ms	remaining: 159ms
# 1:	learn: 11.4084316	total: 6.39ms	remaining: 153ms
# 2:	learn: 11.1177022	total: 9.29ms	remaining: 146ms
# 3:	learn: 10.8110105	total: 12.6ms	remaining: 145ms
# 4:	learn: 10.4882965	total: 16.1ms	remaining: 145ms
# 5:	learn: 10.1995189	total: 19.5ms	remaining: 143ms
# 6:	learn: 9.9339889	total: 22.7ms	remaining: 140ms
# 7:	learn: 9.6349820	total: 26ms	remaining: 137ms
# 8:	learn: 9.3403122	total: 29.4ms	remaining: 134ms
# 9:	learn: 9.0948843	total: 33.2ms	remaining: 133ms
# 10:	learn: 8.8469038	total: 36.8ms	remaining: 130ms
# 11:	learn: 8.6140906	total: 40.2ms	remaining: 127ms
# 12:	learn: 8.3787208	total: 43.8ms	remaining: 125ms
# 13:	learn: 8.1270282	total: 47.3ms	remaining: 122ms
# 14:	learn: 7.8916450	total: 51ms	remaining: 119ms
# 15:	learn: 7.6699679	total: 53.9ms	remaining: 115ms
# 16:	learn: 7.4587531	total: 57ms	remaining: 111ms
# 17:	learn: 7.2695922	total: 60.1ms	remaining: 107ms
# 18:	learn: 7.0911534	total: 63.2ms	remaining: 103ms
# 19:	learn: 6.9403145	total: 66.6ms	remaining: 99.9ms
# 20:	learn: 6.7978286	total: 69.7ms	remaining: 96.2ms
# 21:	learn: 6.6818708	total: 73ms	remaining: 92.9ms
# 22:	learn: 6.5598187	total: 76.2ms	remaining: 89.5ms
# 23:	learn: 6.4164870	total: 79.6ms	remaining: 86.2ms
# 24:	learn: 6.3093439	total: 82.8ms	remaining: 82.8ms
# 25:	learn: 6.1923230	total: 86.3ms	remaining: 79.6ms
# 26:	learn: 6.0408143	total: 89.6ms	remaining: 76.3ms
# 27:	learn: 5.9315947	total: 92.8ms	remaining: 72.9ms
# 28:	learn: 5.8108461	total: 96ms	remaining: 69.5ms
# 29:	learn: 5.6661036	total: 99.4ms	remaining: 66.2ms
# 30:	learn: 5.5464753	total: 103ms	remaining: 62.9ms
# 31:	learn: 5.4538866	total: 106ms	remaining: 59.5ms
# 32:	learn: 5.3388129	total: 109ms	remaining: 56.2ms
# 33:	learn: 5.2584524	total: 112ms	remaining: 52.9ms
# 34:	learn: 5.1383206	total: 116ms	remaining: 49.7ms
# 35:	learn: 5.0628682	total: 119ms	remaining: 46.5ms
# 36:	learn: 4.9621358	total: 123ms	remaining: 43.3ms
# 37:	learn: 4.8756387	total: 127ms	remaining: 40ms
# 38:	learn: 4.7951350	total: 130ms	remaining: 36.6ms
# 39:	learn: 4.7199943	total: 133ms	remaining: 33.3ms
# 40:	learn: 4.6173663	total: 136ms	remaining: 29.9ms
# 41:	learn: 4.5317280	total: 140ms	remaining: 26.6ms
# 42:	learn: 4.4645344	total: 143ms	remaining: 23.3ms
# 43:	learn: 4.3755120	total: 146ms	remaining: 19.9ms
# 44:	learn: 4.3230224	total: 150ms	remaining: 16.6ms
# 45:	learn: 4.2573478	total: 153ms	remaining: 13.3ms
# 46:	learn: 4.1977767	total: 156ms	remaining: 9.97ms
# 47:	learn: 4.1344576	total: 161ms	remaining: 6.72ms
# 48:	learn: 4.0660433	total: 165ms	remaining: 3.36ms
# 49:	learn: 4.0077327	total: 168ms	remaining: 0us
# 0:	learn: 11.9262218	total: 3.28ms	remaining: 161ms
# 1:	learn: 11.5410284	total: 7.49ms	remaining: 180ms
# 2:	learn: 11.2162597	total: 11ms	remaining: 172ms
# 3:	learn: 10.8592516	total: 14.7ms	remaining: 169ms
# 4:	learn: 10.5250672	total: 18.2ms	remaining: 163ms
# 5:	learn: 10.2643689	total: 22.2ms	remaining: 163ms
# 6:	learn: 9.9936870	total: 25.8ms	remaining: 158ms
# 7:	learn: 9.6832311	total: 29.6ms	remaining: 156ms
# 8:	learn: 9.4134625	total: 33.3ms	remaining: 152ms
# 9:	learn: 9.1591485	total: 37.1ms	remaining: 148ms
# 10:	learn: 8.9008568	total: 40.5ms	remaining: 144ms
# 11:	learn: 8.6623901	total: 43.9ms	remaining: 139ms
# 12:	learn: 8.4095659	total: 47.3ms	remaining: 135ms
# 13:	learn: 8.1444580	total: 50.7ms	remaining: 130ms
# 14:	learn: 7.9132616	total: 54.2ms	remaining: 126ms
# 15:	learn: 7.7263389	total: 57.8ms	remaining: 123ms
# 16:	learn: 7.5375652	total: 61.1ms	remaining: 119ms
# 17:	learn: 7.3497801	total: 66ms	remaining: 117ms
# 18:	learn: 7.1481795	total: 69.8ms	remaining: 114ms
# 19:	learn: 6.9731763	total: 73.3ms	remaining: 110ms
# 20:	learn: 6.8453100	total: 76.7ms	remaining: 106ms
# 21:	learn: 6.6764946	total: 80ms	remaining: 102ms
# 22:	learn: 6.5442900	total: 83.4ms	remaining: 97.9ms
# 23:	learn: 6.3783528	total: 87ms	remaining: 94.2ms
# 24:	learn: 6.2399800	total: 90.7ms	remaining: 90.7ms
# 25:	learn: 6.1100955	total: 94.4ms	remaining: 87.1ms
# 26:	learn: 5.9911095	total: 97.7ms	remaining: 83.2ms
# 27:	learn: 5.8734647	total: 101ms	remaining: 79.5ms
# 28:	learn: 5.7489487	total: 105ms	remaining: 75.8ms
# 29:	learn: 5.6197717	total: 108ms	remaining: 72.2ms
# 30:	learn: 5.5339796	total: 112ms	remaining: 68.6ms
# 31:	learn: 5.4361825	total: 115ms	remaining: 64.9ms
# 32:	learn: 5.3450347	total: 119ms	remaining: 61.2ms
# 33:	learn: 5.2520132	total: 122ms	remaining: 57.5ms
# 34:	learn: 5.1506129	total: 126ms	remaining: 53.8ms
# 35:	learn: 5.0515688	total: 129ms	remaining: 50.1ms
# 36:	learn: 4.9521653	total: 132ms	remaining: 46.4ms
# 37:	learn: 4.8639359	total: 135ms	remaining: 42.8ms
# 38:	learn: 4.7701646	total: 139ms	remaining: 39.1ms
# 39:	learn: 4.6902501	total: 142ms	remaining: 35.5ms
# 40:	learn: 4.5962240	total: 146ms	remaining: 31.9ms
# 41:	learn: 4.5122899	total: 149ms	remaining: 28.4ms
# 42:	learn: 4.4316381	total: 152ms	remaining: 24.8ms
# 43:	learn: 4.3564322	total: 156ms	remaining: 21.2ms
# 44:	learn: 4.3007585	total: 159ms	remaining: 17.7ms
# 45:	learn: 4.2380768	total: 163ms	remaining: 14.2ms
# 46:	learn: 4.1747959	total: 167ms	remaining: 10.6ms
# 47:	learn: 4.0870185	total: 170ms	remaining: 7.09ms
# 48:	learn: 4.0099797	total: 174ms	remaining: 3.55ms
# 49:	learn: 3.9616950	total: 178ms	remaining: 0us
# 0:	learn: 11.3553705	total: 3.5ms	remaining: 171ms
# 1:	learn: 10.7727863	total: 6.76ms	remaining: 162ms
# 2:	learn: 10.2425768	total: 9.78ms	remaining: 153ms
# 3:	learn: 9.6400848	total: 13ms	remaining: 149ms
# 4:	learn: 9.1411460	total: 16.3ms	remaining: 147ms
# 5:	learn: 8.6871315	total: 19.8ms	remaining: 145ms
# 6:	learn: 8.3131782	total: 23.3ms	remaining: 143ms
# 7:	learn: 7.8670826	total: 26.7ms	remaining: 140ms
# 8:	learn: 7.5010069	total: 30.1ms	remaining: 137ms
# 9:	learn: 7.1843051	total: 33.8ms	remaining: 135ms
# 10:	learn: 6.9251572	total: 37.4ms	remaining: 132ms
# 11:	learn: 6.6599581	total: 40.7ms	remaining: 129ms
# 12:	learn: 6.3624899	total: 43.9ms	remaining: 125ms
# 13:	learn: 6.0539288	total: 47.3ms	remaining: 122ms
# 14:	learn: 5.7690878	total: 50.8ms	remaining: 119ms
# 15:	learn: 5.5587055	total: 54.2ms	remaining: 115ms
# 16:	learn: 5.3336201	total: 57.5ms	remaining: 112ms
# 17:	learn: 5.1402284	total: 64.4ms	remaining: 115ms
# 18:	learn: 4.9690087	total: 72.2ms	remaining: 118ms
# 19:	learn: 4.8262016	total: 81.5ms	remaining: 122ms
# 20:	learn: 4.7255142	total: 88.2ms	remaining: 122ms
# 21:	learn: 4.5957024	total: 92.2ms	remaining: 117ms
# 22:	learn: 4.4880693	total: 95.7ms	remaining: 112ms
# 23:	learn: 4.3995372	total: 99ms	remaining: 107ms
# 24:	learn: 4.2913804	total: 103ms	remaining: 103ms
# 25:	learn: 4.1886451	total: 106ms	remaining: 98.1ms
# 26:	learn: 4.1193525	total: 109ms	remaining: 93.1ms
# 27:	learn: 4.0066093	total: 113ms	remaining: 88.4ms
# 28:	learn: 3.9017326	total: 116ms	remaining: 84.1ms
# 29:	learn: 3.7851406	total: 120ms	remaining: 79.8ms
# 30:	learn: 3.7237544	total: 123ms	remaining: 75.4ms
# 31:	learn: 3.6452386	total: 126ms	remaining: 71.1ms
# 32:	learn: 3.5648873	total: 130ms	remaining: 66.9ms
# 33:	learn: 3.4690909	total: 133ms	remaining: 62.7ms
# 34:	learn: 3.3949388	total: 137ms	remaining: 58.5ms
# 35:	learn: 3.3310581	total: 140ms	remaining: 54.5ms
# 36:	learn: 3.2756706	total: 143ms	remaining: 50.4ms
# 37:	learn: 3.2175321	total: 147ms	remaining: 46.4ms
# 38:	learn: 3.1595239	total: 150ms	remaining: 42.4ms
# 39:	learn: 3.0903686	total: 154ms	remaining: 38.5ms
# 40:	learn: 3.0506348	total: 157ms	remaining: 34.5ms
# 41:	learn: 3.0267387	total: 161ms	remaining: 30.6ms
# 42:	learn: 2.9886788	total: 166ms	remaining: 27.1ms
# 43:	learn: 2.9387998	total: 169ms	remaining: 23.1ms
# 44:	learn: 2.9052882	total: 172ms	remaining: 19.1ms
# 45:	learn: 2.8887360	total: 175ms	remaining: 15.3ms
# 46:	learn: 2.8465968	total: 179ms	remaining: 11.4ms
# 47:	learn: 2.8311120	total: 182ms	remaining: 7.6ms
# 48:	learn: 2.7655350	total: 186ms	remaining: 3.79ms
# 49:	learn: 2.7402361	total: 195ms	remaining: 0us
# 0:	learn: 11.4211024	total: 3.21ms	remaining: 157ms
# 1:	learn: 10.6980587	total: 6.39ms	remaining: 153ms
# 2:	learn: 10.1778914	total: 9.39ms	remaining: 147ms
# 3:	learn: 9.5669097	total: 12.8ms	remaining: 147ms
# 4:	learn: 9.0402591	total: 16.6ms	remaining: 149ms
# 5:	learn: 8.5351592	total: 20.3ms	remaining: 149ms
# 6:	learn: 8.1500808	total: 26.3ms	remaining: 162ms
# 7:	learn: 7.7125359	total: 30.4ms	remaining: 160ms
# 8:	learn: 7.3056745	total: 33.5ms	remaining: 152ms
# 9:	learn: 7.0012815	total: 36.5ms	remaining: 146ms
# 10:	learn: 6.6799951	total: 39.4ms	remaining: 140ms
# 11:	learn: 6.4134038	total: 42.6ms	remaining: 135ms
# 12:	learn: 6.1325495	total: 45.9ms	remaining: 131ms
# 13:	learn: 5.8293081	total: 49.6ms	remaining: 127ms
# 14:	learn: 5.6035109	total: 52.9ms	remaining: 123ms
# 15:	learn: 5.4180202	total: 56.3ms	remaining: 120ms
# 16:	learn: 5.2247342	total: 59.7ms	remaining: 116ms
# 17:	learn: 5.0468601	total: 63ms	remaining: 112ms
# 18:	learn: 4.8909254	total: 66.4ms	remaining: 108ms
# 19:	learn: 4.6817153	total: 69.6ms	remaining: 104ms
# 20:	learn: 4.5836675	total: 73ms	remaining: 101ms
# 21:	learn: 4.3961353	total: 76.2ms	remaining: 97ms
# 22:	learn: 4.2983973	total: 79.5ms	remaining: 93.3ms
# 23:	learn: 4.1740758	total: 82.9ms	remaining: 89.8ms
# 24:	learn: 4.0767632	total: 86.3ms	remaining: 86.3ms
# 25:	learn: 3.9686340	total: 89.7ms	remaining: 82.8ms
# 26:	learn: 3.8539033	total: 93.2ms	remaining: 79.4ms
# 27:	learn: 3.7678156	total: 96.6ms	remaining: 75.9ms
# 28:	learn: 3.6553975	total: 99.9ms	remaining: 72.4ms
# 29:	learn: 3.5509880	total: 103ms	remaining: 68.9ms
# 30:	learn: 3.4649298	total: 107ms	remaining: 65.3ms
# 31:	learn: 3.3908900	total: 110ms	remaining: 61.8ms
# 32:	learn: 3.3234935	total: 113ms	remaining: 58.3ms
# 33:	learn: 3.2615791	total: 117ms	remaining: 54.8ms
# 34:	learn: 3.1794113	total: 120ms	remaining: 51.4ms
# 35:	learn: 3.1186992	total: 123ms	remaining: 47.9ms
# 36:	learn: 3.0483558	total: 127ms	remaining: 44.5ms
# 37:	learn: 2.9753750	total: 130ms	remaining: 41.1ms
# 38:	learn: 2.9124251	total: 133ms	remaining: 37.6ms
# 39:	learn: 2.8543182	total: 137ms	remaining: 34.3ms
# 40:	learn: 2.8075398	total: 141ms	remaining: 31ms
# 41:	learn: 2.7485446	total: 147ms	remaining: 28.1ms
# 42:	learn: 2.7091782	total: 155ms	remaining: 25.3ms
# 43:	learn: 2.6544052	total: 159ms	remaining: 21.6ms
# 44:	learn: 2.6159642	total: 162ms	remaining: 18ms
# 45:	learn: 2.5776953	total: 166ms	remaining: 14.4ms
# 46:	learn: 2.5432378	total: 169ms	remaining: 10.8ms
# 47:	learn: 2.5194452	total: 173ms	remaining: 7.22ms
# 48:	learn: 2.4770033	total: 177ms	remaining: 3.61ms
# 49:	learn: 2.4303221	total: 181ms	remaining: 0us
# 0:	learn: 11.5346453	total: 3.34ms	remaining: 164ms
# 1:	learn: 10.8050644	total: 8.97ms	remaining: 215ms
# 2:	learn: 10.2269850	total: 12.1ms	remaining: 189ms
# 3:	learn: 9.6058770	total: 15.7ms	remaining: 181ms
# 4:	learn: 9.0683269	total: 19.1ms	remaining: 172ms
# 5:	learn: 8.5863208	total: 22.6ms	remaining: 165ms
# 6:	learn: 8.1906558	total: 25.9ms	remaining: 159ms
# 7:	learn: 7.7583650	total: 29.5ms	remaining: 155ms
# 8:	learn: 7.3474592	total: 33.2ms	remaining: 151ms
# 9:	learn: 7.0117595	total: 36.6ms	remaining: 146ms
# 10:	learn: 6.6841657	total: 39.9ms	remaining: 141ms
# 11:	learn: 6.3986390	total: 43.2ms	remaining: 137ms
# 12:	learn: 6.0707933	total: 46.6ms	remaining: 133ms
# 13:	learn: 5.7480267	total: 50ms	remaining: 129ms
# 14:	learn: 5.5112950	total: 53.6ms	remaining: 125ms
# 15:	learn: 5.2713682	total: 56.9ms	remaining: 121ms
# 16:	learn: 5.0695457	total: 60.6ms	remaining: 118ms
# 17:	learn: 4.8892269	total: 64ms	remaining: 114ms
# 18:	learn: 4.7035606	total: 67.5ms	remaining: 110ms
# 19:	learn: 4.5364614	total: 71ms	remaining: 106ms
# 20:	learn: 4.4089842	total: 74.6ms	remaining: 103ms
# 21:	learn: 4.2522490	total: 78.2ms	remaining: 99.5ms
# 22:	learn: 4.1467359	total: 81.6ms	remaining: 95.8ms
# 23:	learn: 4.0100055	total: 85.1ms	remaining: 92.1ms
# 24:	learn: 3.9082364	total: 88.5ms	remaining: 88.5ms
# 25:	learn: 3.7755290	total: 91.8ms	remaining: 84.7ms
# 26:	learn: 3.6794094	total: 95.2ms	remaining: 81.1ms
# 27:	learn: 3.6053269	total: 98.8ms	remaining: 77.7ms
# 28:	learn: 3.5119280	total: 102ms	remaining: 74.1ms
# 29:	learn: 3.4193710	total: 106ms	remaining: 70.5ms
# 30:	learn: 3.3720133	total: 109ms	remaining: 66.9ms
# 31:	learn: 3.2949335	total: 112ms	remaining: 63.2ms
# 32:	learn: 3.2304757	total: 116ms	remaining: 59.7ms
# 33:	learn: 3.1771797	total: 124ms	remaining: 58.5ms
# 34:	learn: 3.1194191	total: 129ms	remaining: 55.2ms
# 35:	learn: 3.0310134	total: 132ms	remaining: 51.4ms
# 36:	learn: 2.9486816	total: 136ms	remaining: 47.7ms
# 37:	learn: 2.8702217	total: 139ms	remaining: 43.9ms
# 38:	learn: 2.8146967	total: 143ms	remaining: 40.2ms
# 39:	learn: 2.7553270	total: 146ms	remaining: 36.5ms
# 40:	learn: 2.6895926	total: 149ms	remaining: 32.8ms
# 41:	learn: 2.6228943	total: 153ms	remaining: 29.1ms
# 42:	learn: 2.5886193	total: 156ms	remaining: 25.4ms
# 43:	learn: 2.5468549	total: 159ms	remaining: 21.7ms
# 44:	learn: 2.5255339	total: 163ms	remaining: 18.1ms
# 45:	learn: 2.4848133	total: 166ms	remaining: 14.4ms
# 46:	learn: 2.4523220	total: 169ms	remaining: 10.8ms
# 47:	learn: 2.3989532	total: 173ms	remaining: 7.2ms
# 48:	learn: 2.3643734	total: 176ms	remaining: 3.59ms
# 49:	learn: 2.3161348	total: 179ms	remaining: 0us
# 0:	learn: 12.0474412	total: 3.27ms	remaining: 324ms
# 1:	learn: 11.9717073	total: 6.42ms	remaining: 314ms
# 2:	learn: 11.9059822	total: 9.44ms	remaining: 305ms
# 3:	learn: 11.8289107	total: 12.7ms	remaining: 306ms
# 4:	learn: 11.7557857	total: 16.3ms	remaining: 310ms
# 5:	learn: 11.6845494	total: 19.7ms	remaining: 309ms
# 6:	learn: 11.6181709	total: 23ms	remaining: 305ms
# 7:	learn: 11.5403476	total: 26.1ms	remaining: 301ms
# 8:	learn: 11.4695802	total: 29.4ms	remaining: 297ms
# 9:	learn: 11.4015307	total: 32.6ms	remaining: 294ms
# 10:	learn: 11.3343708	total: 35.9ms	remaining: 291ms
# 11:	learn: 11.2648526	total: 39.3ms	remaining: 288ms
# 12:	learn: 11.1904938	total: 42.6ms	remaining: 285ms
# 13:	learn: 11.1149024	total: 46ms	remaining: 283ms
# 14:	learn: 11.0413905	total: 49.4ms	remaining: 280ms
# 15:	learn: 10.9743156	total: 52.6ms	remaining: 276ms
# 16:	learn: 10.9066946	total: 56ms	remaining: 273ms
# 17:	learn: 10.8406812	total: 59.2ms	remaining: 270ms
# 18:	learn: 10.7795569	total: 62.5ms	remaining: 266ms
# 19:	learn: 10.7188733	total: 66ms	remaining: 264ms
# 20:	learn: 10.6622903	total: 69.4ms	remaining: 261ms
# 21:	learn: 10.6064787	total: 72.8ms	remaining: 258ms
# 22:	learn: 10.5482488	total: 76ms	remaining: 255ms
# 23:	learn: 10.4850483	total: 79.8ms	remaining: 253ms
# 24:	learn: 10.4293920	total: 83.3ms	remaining: 250ms
# 25:	learn: 10.3637645	total: 86.8ms	remaining: 247ms
# 26:	learn: 10.3039968	total: 90.4ms	remaining: 244ms
# 27:	learn: 10.2391840	total: 93.6ms	remaining: 241ms
# 28:	learn: 10.1844578	total: 103ms	remaining: 252ms
# 29:	learn: 10.1269974	total: 106ms	remaining: 248ms
# 30:	learn: 10.0721983	total: 109ms	remaining: 243ms
# 31:	learn: 10.0174720	total: 112ms	remaining: 238ms
# 32:	learn: 9.9639640	total: 115ms	remaining: 234ms
# 33:	learn: 9.9109616	total: 119ms	remaining: 230ms
# 34:	learn: 9.8483429	total: 122ms	remaining: 226ms
# 35:	learn: 9.7961489	total: 125ms	remaining: 223ms
# 36:	learn: 9.7404011	total: 129ms	remaining: 219ms
# 37:	learn: 9.6847317	total: 132ms	remaining: 216ms
# 38:	learn: 9.6277063	total: 136ms	remaining: 212ms
# 39:	learn: 9.5708521	total: 140ms	remaining: 209ms
# 40:	learn: 9.5141396	total: 143ms	remaining: 206ms
# 41:	learn: 9.4626795	total: 146ms	remaining: 202ms
# 42:	learn: 9.4136052	total: 148ms	remaining: 197ms
# 43:	learn: 9.3557706	total: 152ms	remaining: 193ms
# 44:	learn: 9.3017360	total: 155ms	remaining: 190ms
# 45:	learn: 9.2464749	total: 164ms	remaining: 193ms
# 46:	learn: 9.1933727	total: 169ms	remaining: 191ms
# 47:	learn: 9.1429677	total: 173ms	remaining: 187ms
# 48:	learn: 9.0898165	total: 176ms	remaining: 183ms
# 49:	learn: 9.0317548	total: 179ms	remaining: 179ms
# 50:	learn: 8.9872033	total: 183ms	remaining: 176ms
# 51:	learn: 8.9370077	total: 186ms	remaining: 172ms
# 52:	learn: 8.8904013	total: 189ms	remaining: 168ms
# 53:	learn: 8.8422730	total: 193ms	remaining: 164ms
# 54:	learn: 8.7953010	total: 196ms	remaining: 160ms
# 55:	learn: 8.7495214	total: 199ms	remaining: 156ms
# 56:	learn: 8.7019609	total: 203ms	remaining: 153ms
# 57:	learn: 8.6535154	total: 206ms	remaining: 149ms
# 58:	learn: 8.6050293	total: 209ms	remaining: 146ms
# 59:	learn: 8.5672636	total: 213ms	remaining: 142ms
# 60:	learn: 8.5234701	total: 216ms	remaining: 138ms
# 61:	learn: 8.4778356	total: 219ms	remaining: 134ms
# 62:	learn: 8.4339580	total: 223ms	remaining: 131ms
# 63:	learn: 8.3912984	total: 226ms	remaining: 127ms
# 64:	learn: 8.3494392	total: 230ms	remaining: 124ms
# 65:	learn: 8.3050773	total: 233ms	remaining: 120ms
# 66:	learn: 8.2630564	total: 236ms	remaining: 116ms
# 67:	learn: 8.2206665	total: 239ms	remaining: 113ms
# 68:	learn: 8.1808246	total: 243ms	remaining: 109ms
# 69:	learn: 8.1418424	total: 246ms	remaining: 106ms
# 70:	learn: 8.0971085	total: 250ms	remaining: 102ms
# 71:	learn: 8.0560321	total: 253ms	remaining: 98.5ms
# 72:	learn: 8.0123230	total: 257ms	remaining: 95ms
# 73:	learn: 7.9709821	total: 260ms	remaining: 91.5ms
# 74:	learn: 7.9299314	total: 264ms	remaining: 87.9ms
# 75:	learn: 7.8949401	total: 267ms	remaining: 84.4ms
# 76:	learn: 7.8560428	total: 270ms	remaining: 80.8ms
# 77:	learn: 7.8197009	total: 274ms	remaining: 77.3ms
# 78:	learn: 7.7840103	total: 277ms	remaining: 73.7ms
# 79:	learn: 7.7396009	total: 281ms	remaining: 70.3ms
# 80:	learn: 7.7016655	total: 285ms	remaining: 66.8ms
# 81:	learn: 7.6654442	total: 292ms	remaining: 64.2ms
# 82:	learn: 7.6263150	total: 297ms	remaining: 60.8ms
# 83:	learn: 7.5856223	total: 301ms	remaining: 57.3ms
# 84:	learn: 7.5460810	total: 304ms	remaining: 53.7ms
# 85:	learn: 7.5083906	total: 308ms	remaining: 50.1ms
# 86:	learn: 7.4727447	total: 311ms	remaining: 46.5ms
# 87:	learn: 7.4371514	total: 314ms	remaining: 42.8ms
# 88:	learn: 7.4020872	total: 317ms	remaining: 39.2ms
# 89:	learn: 7.3662962	total: 321ms	remaining: 35.6ms
# 90:	learn: 7.3340240	total: 324ms	remaining: 32.1ms
# 91:	learn: 7.3008579	total: 328ms	remaining: 28.5ms
# 92:	learn: 7.2637968	total: 331ms	remaining: 24.9ms
# 93:	learn: 7.2327908	total: 339ms	remaining: 21.6ms
# 94:	learn: 7.1930668	total: 344ms	remaining: 18.1ms
# 95:	learn: 7.1595502	total: 351ms	remaining: 14.6ms
# 96:	learn: 7.1298398	total: 363ms	remaining: 11.2ms
# 97:	learn: 7.0997555	total: 372ms	remaining: 7.6ms
# 98:	learn: 7.0679092	total: 378ms	remaining: 3.82ms
# 99:	learn: 7.0318533	total: 382ms	remaining: 0us
# 0:	learn: 12.0876188	total: 3.48ms	remaining: 344ms
# 1:	learn: 12.0101542	total: 7.34ms	remaining: 360ms
# 2:	learn: 11.9462280	total: 11.1ms	remaining: 359ms
# 3:	learn: 11.8766055	total: 14.8ms	remaining: 355ms
# 4:	learn: 11.7993281	total: 18.2ms	remaining: 346ms
# 5:	learn: 11.7295218	total: 21.6ms	remaining: 339ms
# 6:	learn: 11.6623892	total: 25ms	remaining: 332ms
# 7:	learn: 11.5853543	total: 28.4ms	remaining: 327ms
# 8:	learn: 11.5049736	total: 32ms	remaining: 323ms
# 9:	learn: 11.4351770	total: 35.4ms	remaining: 319ms
# 10:	learn: 11.3609023	total: 38.7ms	remaining: 313ms
# 11:	learn: 11.2913618	total: 41.9ms	remaining: 307ms
# 12:	learn: 11.2213774	total: 45.5ms	remaining: 304ms
# 13:	learn: 11.1419547	total: 49.2ms	remaining: 302ms
# 14:	learn: 11.0666027	total: 56.2ms	remaining: 319ms
# 15:	learn: 11.0009093	total: 60.8ms	remaining: 319ms
# 16:	learn: 10.9378978	total: 63.8ms	remaining: 311ms
# 17:	learn: 10.8718306	total: 67.3ms	remaining: 306ms
# 18:	learn: 10.8025223	total: 70.8ms	remaining: 302ms
# 19:	learn: 10.7360424	total: 74.3ms	remaining: 297ms
# 20:	learn: 10.6792105	total: 77.7ms	remaining: 292ms
# 21:	learn: 10.6220447	total: 81.2ms	remaining: 288ms
# 22:	learn: 10.5552748	total: 87.2ms	remaining: 292ms
# 23:	learn: 10.4895436	total: 90.6ms	remaining: 287ms
# 24:	learn: 10.4331873	total: 94.1ms	remaining: 282ms
# 25:	learn: 10.3688947	total: 97.6ms	remaining: 278ms
# 26:	learn: 10.3134943	total: 101ms	remaining: 274ms
# 27:	learn: 10.2544168	total: 105ms	remaining: 269ms
# 28:	learn: 10.1934568	total: 108ms	remaining: 264ms
# 29:	learn: 10.1345617	total: 111ms	remaining: 260ms
# 30:	learn: 10.0823560	total: 115ms	remaining: 255ms
# 31:	learn: 10.0236730	total: 118ms	remaining: 250ms
# 32:	learn: 9.9669532	total: 121ms	remaining: 246ms
# 33:	learn: 9.9122968	total: 124ms	remaining: 242ms
# 34:	learn: 9.8490374	total: 128ms	remaining: 238ms
# 35:	learn: 9.7976747	total: 131ms	remaining: 233ms
# 36:	learn: 9.7365266	total: 135ms	remaining: 229ms
# 37:	learn: 9.6808952	total: 138ms	remaining: 225ms
# 38:	learn: 9.6215331	total: 141ms	remaining: 221ms
# 39:	learn: 9.5692442	total: 145ms	remaining: 217ms
# 40:	learn: 9.5095304	total: 148ms	remaining: 213ms
# 41:	learn: 9.4496014	total: 152ms	remaining: 209ms
# 42:	learn: 9.3972741	total: 155ms	remaining: 206ms
# 43:	learn: 9.3432035	total: 159ms	remaining: 202ms
# 44:	learn: 9.2920843	total: 162ms	remaining: 198ms
# 45:	learn: 9.2466171	total: 165ms	remaining: 194ms
# 46:	learn: 9.1962071	total: 169ms	remaining: 190ms
# 47:	learn: 9.1444185	total: 172ms	remaining: 187ms
# 48:	learn: 9.1008643	total: 176ms	remaining: 183ms
# 49:	learn: 9.0506506	total: 179ms	remaining: 179ms
# 50:	learn: 8.9982072	total: 183ms	remaining: 176ms
# 51:	learn: 8.9437360	total: 186ms	remaining: 172ms
# 52:	learn: 8.8869790	total: 190ms	remaining: 168ms
# 53:	learn: 8.8368566	total: 193ms	remaining: 164ms
# 54:	learn: 8.7943287	total: 197ms	remaining: 162ms
# 55:	learn: 8.7427454	total: 201ms	remaining: 158ms
# 56:	learn: 8.7041782	total: 204ms	remaining: 154ms
# 57:	learn: 8.6548271	total: 207ms	remaining: 150ms
# 58:	learn: 8.6120471	total: 210ms	remaining: 146ms
# 59:	learn: 8.5662324	total: 214ms	remaining: 142ms
# 60:	learn: 8.5196662	total: 217ms	remaining: 139ms
# 61:	learn: 8.4738482	total: 221ms	remaining: 135ms
# 62:	learn: 8.4230444	total: 224ms	remaining: 132ms
# 63:	learn: 8.3813942	total: 228ms	remaining: 128ms
# 64:	learn: 8.3386906	total: 231ms	remaining: 125ms
# 65:	learn: 8.3033660	total: 235ms	remaining: 121ms
# 66:	learn: 8.2561473	total: 238ms	remaining: 117ms
# 67:	learn: 8.2206745	total: 248ms	remaining: 116ms
# 68:	learn: 8.1749769	total: 252ms	remaining: 113ms
# 69:	learn: 8.1338333	total: 256ms	remaining: 110ms
# 70:	learn: 8.0963785	total: 259ms	remaining: 106ms
# 71:	learn: 8.0559336	total: 262ms	remaining: 102ms
# 72:	learn: 8.0166444	total: 270ms	remaining: 99.8ms
# 73:	learn: 7.9814769	total: 273ms	remaining: 96ms
# 74:	learn: 7.9448235	total: 277ms	remaining: 92.2ms
# 75:	learn: 7.9040884	total: 280ms	remaining: 88.4ms
# 76:	learn: 7.8609468	total: 285ms	remaining: 85ms
# 77:	learn: 7.8219955	total: 288ms	remaining: 81.3ms
# 78:	learn: 7.7841426	total: 291ms	remaining: 77.5ms
# 79:	learn: 7.7424153	total: 294ms	remaining: 73.6ms
# 80:	learn: 7.7043633	total: 298ms	remaining: 69.8ms
# 81:	learn: 7.6664015	total: 302ms	remaining: 66.2ms
# 82:	learn: 7.6255633	total: 305ms	remaining: 62.5ms
# 83:	learn: 7.5904360	total: 309ms	remaining: 58.9ms
# 84:	learn: 7.5518600	total: 313ms	remaining: 55.2ms
# 85:	learn: 7.5112463	total: 316ms	remaining: 51.5ms
# 86:	learn: 7.4786914	total: 320ms	remaining: 47.8ms
# 87:	learn: 7.4462592	total: 323ms	remaining: 44.1ms
# 88:	learn: 7.4107402	total: 327ms	remaining: 40.4ms
# 89:	learn: 7.3718115	total: 330ms	remaining: 36.7ms
# 90:	learn: 7.3432501	total: 334ms	remaining: 33ms
# 91:	learn: 7.3107479	total: 338ms	remaining: 29.4ms
# 92:	learn: 7.2727285	total: 342ms	remaining: 25.7ms
# 93:	learn: 7.2417437	total: 346ms	remaining: 22.1ms
# 94:	learn: 7.2007577	total: 349ms	remaining: 18.4ms
# 95:	learn: 7.1668874	total: 353ms	remaining: 14.7ms
# 96:	learn: 7.1322405	total: 356ms	remaining: 11ms
# 97:	learn: 7.1051507	total: 360ms	remaining: 7.34ms
# 98:	learn: 7.0710384	total: 363ms	remaining: 3.67ms
# 99:	learn: 7.0390563	total: 367ms	remaining: 0us
# 0:	learn: 12.2439202	total: 3.38ms	remaining: 334ms
# 1:	learn: 12.1636759	total: 7.09ms	remaining: 347ms
# ...
# 7:	learn: 7.6212230	total: 473ms	remaining: 5.44s
# 8:	learn: 7.2783280	total: 531ms	remaining: 5.37s
# 9:	learn: 6.9031498	total: 594ms	remaining: 5.34s
# 10:	learn: 6.5455396	total: 667ms	remaining: 5.4s
# 11:	learn: 6.1893064	total: 735ms	remaining: 5.39s
# 12:	learn: 5.9132409	total: 786ms	remaining: 5.26s
# 13:	learn: 5.6236777	total: 854ms	remaining: 5.25s
# 14:	learn: 5.3938268	total: 934ms	remaining: 5.29s
# 15:	learn: 5.1860924	total: 1s	remaining: 5.25s
# 16:	learn: 5.0030920	total: 1.06s	remaining: 5.2s
# 17:	learn: 4.7677124	total: 1.15s	remaining: 5.24s
# 18:	learn: 4.6056271	total: 1.19s	remaining: 5.08s
# 19:	learn: 4.4657600	total: 1.23s	remaining: 4.92s
# 20:	learn: 4.2789090	total: 1.26s	remaining: 4.75s
# 21:	learn: 4.1124347	total: 1.29s	remaining: 4.59s
# 22:	learn: 3.9810788	total: 1.33s	remaining: 4.45s
# 23:	learn: 3.8606206	total: 1.33s	remaining: 4.22s
# 24:	learn: 3.7205668	total: 1.38s	remaining: 4.13s
# 25:	learn: 3.6033275	total: 1.41s	remaining: 4.01s
# 26:	learn: 3.5052845	total: 1.44s	remaining: 3.9s
# 27:	learn: 3.3870458	total: 1.48s	remaining: 3.8s
# 28:	learn: 3.2690632	total: 1.51s	remaining: 3.71s
# 29:	learn: 3.1759652	total: 1.55s	remaining: 3.62s
# 30:	learn: 3.0698266	total: 1.59s	remaining: 3.54s
# 31:	learn: 2.9580507	total: 1.63s	remaining: 3.45s
# 32:	learn: 2.8708405	total: 1.66s	remaining: 3.37s
# 33:	learn: 2.7830694	total: 1.7s	remaining: 3.29s
# 34:	learn: 2.7130077	total: 1.73s	remaining: 3.22s
# 35:	learn: 2.6341657	total: 1.77s	remaining: 3.14s
# 36:	learn: 2.5697967	total: 1.81s	remaining: 3.09s
# 37:	learn: 2.4889349	total: 1.85s	remaining: 3.01s
# 38:	learn: 2.4334652	total: 1.88s	remaining: 2.94s
# 39:	learn: 2.3863431	total: 1.91s	remaining: 2.87s
# 40:	learn: 2.3361114	total: 1.95s	remaining: 2.8s
# 41:	learn: 2.2946689	total: 1.98s	remaining: 2.73s
# 42:	learn: 2.2396892	total: 2.02s	remaining: 2.67s
# 43:	learn: 2.1926043	total: 2.06s	remaining: 2.62s
# 44:	learn: 2.1286316	total: 2.09s	remaining: 2.55s
# 45:	learn: 2.0837485	total: 2.12s	remaining: 2.49s
# 46:	learn: 2.0454533	total: 2.16s	remaining: 2.44s
# 47:	learn: 2.0086537	total: 2.2s	remaining: 2.39s
# 48:	learn: 1.9776209	total: 2.25s	remaining: 2.34s
# 49:	learn: 1.9449145	total: 2.28s	remaining: 2.28s
# 50:	learn: 1.8996451	total: 2.32s	remaining: 2.23s
# 51:	learn: 1.8622928	total: 2.35s	remaining: 2.17s
# 52:	learn: 1.8300854	total: 2.38s	remaining: 2.11s
# 53:	learn: 1.8009621	total: 2.42s	remaining: 2.06s
# 54:	learn: 1.7672412	total: 2.46s	remaining: 2.01s
# 55:	learn: 1.7271363	total: 2.5s	remaining: 1.96s
# 56:	learn: 1.6961682	total: 2.53s	remaining: 1.91s
# 57:	learn: 1.6742505	total: 2.56s	remaining: 1.85s
# 58:	learn: 1.6431323	total: 2.59s	remaining: 1.8s
# 59:	learn: 1.6191174	total: 2.63s	remaining: 1.75s
# 60:	learn: 1.5947406	total: 2.67s	remaining: 1.71s
# 61:	learn: 1.5740273	total: 2.71s	remaining: 1.66s
# 62:	learn: 1.5546550	total: 2.74s	remaining: 1.61s
# 63:	learn: 1.5362200	total: 2.78s	remaining: 1.56s
# 64:	learn: 1.5168441	total: 2.81s	remaining: 1.51s
# 65:	learn: 1.4950385	total: 2.85s	remaining: 1.47s
# 66:	learn: 1.4747275	total: 2.89s	remaining: 1.42s
# 67:	learn: 1.4539153	total: 2.92s	remaining: 1.38s
# 68:	learn: 1.4374644	total: 2.96s	remaining: 1.33s
# 69:	learn: 1.4279496	total: 2.99s	remaining: 1.28s
# 70:	learn: 1.4068044	total: 3.02s	remaining: 1.24s
# 71:	learn: 1.3841148	total: 3.06s	remaining: 1.19s
# 72:	learn: 1.3580157	total: 3.1s	remaining: 1.15s
# 73:	learn: 1.3403719	total: 3.14s	remaining: 1.1s
# 74:	learn: 1.3154981	total: 3.18s	remaining: 1.06s
# 75:	learn: 1.2986111	total: 3.22s	remaining: 1.02s
# 76:	learn: 1.2795308	total: 3.26s	remaining: 973ms
# 77:	learn: 1.2622996	total: 3.29s	remaining: 928ms
# 78:	learn: 1.2411400	total: 3.34s	remaining: 888ms
# 79:	learn: 1.2299348	total: 3.37s	remaining: 843ms
# 80:	learn: 1.2101081	total: 3.4s	remaining: 799ms
# 81:	learn: 1.1966916	total: 3.44s	remaining: 754ms
# 82:	learn: 1.1791023	total: 3.47s	remaining: 711ms
# 83:	learn: 1.1666846	total: 3.5s	remaining: 667ms
# 84:	learn: 1.1538891	total: 3.53s	remaining: 624ms
# 85:	learn: 1.1371932	total: 3.58s	remaining: 583ms
# 86:	learn: 1.1198596	total: 3.61s	remaining: 540ms
# 87:	learn: 1.1014065	total: 3.65s	remaining: 498ms
# 88:	learn: 1.0891277	total: 3.69s	remaining: 456ms
# 89:	learn: 1.0826883	total: 3.72s	remaining: 413ms
# 90:	learn: 1.0605111	total: 3.76s	remaining: 372ms
# 91:	learn: 1.0467046	total: 3.8s	remaining: 330ms
# 92:	learn: 1.0355114	total: 3.83s	remaining: 289ms
# 93:	learn: 1.0286418	total: 3.87s	remaining: 247ms
# 94:	learn: 1.0105553	total: 3.91s	remaining: 206ms
# 95:	learn: 0.9943135	total: 3.94s	remaining: 164ms
# 96:	learn: 0.9780521	total: 3.98s	remaining: 123ms
# 97:	learn: 0.9670315	total: 4.02s	remaining: 82ms
# 98:	learn: 0.9533914	total: 4.05s	remaining: 40.9ms
# 99:	learn: 0.9433600	total: 4.09s	remaining: 0us
# 0:	learn: 11.4181506	total: 3.68ms	remaining: 365ms
# 1:	learn: 10.7066774	total: 7.52ms	remaining: 368ms
# 2:	learn: 10.1345493	total: 11.5ms	remaining: 373ms
# 3:	learn: 9.5174119	total: 16ms	remaining: 384ms
# 4:	learn: 8.9894474	total: 19.7ms	remaining: 375ms
# 5:	learn: 8.5369318	total: 23.6ms	remaining: 369ms
# 6:	learn: 8.1410287	total: 27.9ms	remaining: 370ms
# 7:	learn: 7.7032202	total: 31.6ms	remaining: 364ms
# 8:	learn: 7.2940469	total: 35.6ms	remaining: 360ms
# 9:	learn: 6.9708316	total: 39.6ms	remaining: 356ms
# 10:	learn: 6.6447825	total: 43.5ms	remaining: 352ms
# 11:	learn: 6.3701360	total: 47.2ms	remaining: 346ms
# 12:	learn: 6.0846037	total: 53.2ms	remaining: 356ms
# 13:	learn: 5.7859816	total: 62ms	remaining: 381ms
# 14:	learn: 5.5225770	total: 72.7ms	remaining: 412ms
# 15:	learn: 5.3112145	total: 90.4ms	remaining: 475ms
# 16:	learn: 5.0911303	total: 95.6ms	remaining: 467ms
# 17:	learn: 4.8555598	total: 99.5ms	remaining: 453ms
# 18:	learn: 4.7015779	total: 103ms	remaining: 441ms
# 19:	learn: 4.5353605	total: 107ms	remaining: 428ms
# 20:	learn: 4.4213148	total: 111ms	remaining: 416ms
# 21:	learn: 4.2830971	total: 114ms	remaining: 405ms
# 22:	learn: 4.1405617	total: 118ms	remaining: 395ms
# 23:	learn: 4.0340816	total: 122ms	remaining: 385ms
# 24:	learn: 3.9231504	total: 125ms	remaining: 376ms
# 25:	learn: 3.8091908	total: 129ms	remaining: 367ms
# 26:	learn: 3.7093867	total: 133ms	remaining: 359ms
# 27:	learn: 3.5846056	total: 136ms	remaining: 351ms
# 28:	learn: 3.4448638	total: 140ms	remaining: 343ms
# 29:	learn: 3.3436639	total: 144ms	remaining: 336ms
# 30:	learn: 3.2826352	total: 148ms	remaining: 329ms
# 31:	learn: 3.1795774	total: 151ms	remaining: 322ms
# 32:	learn: 3.1064841	total: 155ms	remaining: 315ms
# 33:	learn: 3.0106739	total: 159ms	remaining: 308ms
# 34:	learn: 2.9366715	total: 162ms	remaining: 301ms
# 35:	learn: 2.8669443	total: 166ms	remaining: 295ms
# 36:	learn: 2.8192232	total: 170ms	remaining: 289ms
# 37:	learn: 2.7534041	total: 174ms	remaining: 283ms
# 38:	learn: 2.6827673	total: 177ms	remaining: 278ms
# 39:	learn: 2.6390516	total: 181ms	remaining: 272ms
# 40:	learn: 2.5908817	total: 186ms	remaining: 267ms
# 41:	learn: 2.5354902	total: 189ms	remaining: 261ms
# 42:	learn: 2.5027907	total: 193ms	remaining: 255ms
# 43:	learn: 2.4278013	total: 196ms	remaining: 250ms
# 44:	learn: 2.4041135	total: 200ms	remaining: 244ms
# 45:	learn: 2.3607512	total: 204ms	remaining: 239ms
# 46:	learn: 2.3237059	total: 207ms	remaining: 234ms
# 47:	learn: 2.2828358	total: 210ms	remaining: 228ms
# 48:	learn: 2.2417588	total: 214ms	remaining: 223ms
# 49:	learn: 2.2089302	total: 217ms	remaining: 217ms
# 50:	learn: 2.1722087	total: 221ms	remaining: 212ms
# 51:	learn: 2.1247079	total: 225ms	remaining: 207ms
# 52:	learn: 2.1143350	total: 228ms	remaining: 202ms
# 53:	learn: 2.0783445	total: 232ms	remaining: 197ms
# 54:	learn: 2.0453730	total: 235ms	remaining: 193ms
# 55:	learn: 2.0243811	total: 243ms	remaining: 191ms
# 56:	learn: 2.0011748	total: 249ms	remaining: 188ms
# 57:	learn: 1.9710909	total: 252ms	remaining: 183ms
# 58:	learn: 1.9409631	total: 256ms	remaining: 178ms
# 59:	learn: 1.9237479	total: 259ms	remaining: 173ms
# 60:	learn: 1.9037850	total: 262ms	remaining: 168ms
# 61:	learn: 1.8864462	total: 266ms	remaining: 163ms
# 62:	learn: 1.8713099	total: 269ms	remaining: 158ms
# 63:	learn: 1.8374660	total: 272ms	remaining: 153ms
# 64:	learn: 1.8219547	total: 279ms	remaining: 150ms
# 65:	learn: 1.8072265	total: 287ms	remaining: 148ms
# 66:	learn: 1.7820926	total: 296ms	remaining: 146ms
# 67:	learn: 1.7562645	total: 300ms	remaining: 141ms
# 68:	learn: 1.7257604	total: 303ms	remaining: 136ms
# 69:	learn: 1.7008765	total: 306ms	remaining: 131ms
# 70:	learn: 1.6808291	total: 310ms	remaining: 126ms
# 71:	learn: 1.6540034	total: 314ms	remaining: 122ms
# 72:	learn: 1.6271916	total: 317ms	remaining: 117ms
# 73:	learn: 1.6085341	total: 322ms	remaining: 113ms
# 74:	learn: 1.5965425	total: 327ms	remaining: 109ms
# 75:	learn: 1.5665020	total: 333ms	remaining: 105ms
# 76:	learn: 1.5440714	total: 337ms	remaining: 101ms
# 77:	learn: 1.5251415	total: 341ms	remaining: 96ms
# 78:	learn: 1.5163922	total: 344ms	remaining: 91.5ms
# 79:	learn: 1.5090727	total: 347ms	remaining: 86.9ms
# 80:	learn: 1.4994800	total: 351ms	remaining: 82.4ms
# 81:	learn: 1.4872233	total: 355ms	remaining: 77.8ms
# 82:	learn: 1.4653922	total: 359ms	remaining: 73.4ms
# 83:	learn: 1.4443852	total: 362ms	remaining: 69ms
# 84:	learn: 1.4380498	total: 366ms	remaining: 64.6ms
# 85:	learn: 1.4312507	total: 370ms	remaining: 60.2ms
# 86:	learn: 1.4155750	total: 373ms	remaining: 55.7ms
# 87:	learn: 1.4117828	total: 376ms	remaining: 51.3ms
# 88:	learn: 1.3968724	total: 380ms	remaining: 47ms
# 89:	learn: 1.3776106	total: 384ms	remaining: 42.6ms
# 90:	learn: 1.3724604	total: 387ms	remaining: 38.3ms
# 91:	learn: 1.3594689	total: 391ms	remaining: 34ms
# 92:	learn: 1.3422717	total: 394ms	remaining: 29.7ms
# 93:	learn: 1.3221721	total: 398ms	remaining: 25.4ms
# 94:	learn: 1.3087952	total: 401ms	remaining: 21.1ms
# 95:	learn: 1.2879923	total: 404ms	remaining: 16.8ms
# 96:	learn: 1.2729858	total: 408ms	remaining: 12.6ms
# 97:	learn: 1.2617511	total: 411ms	remaining: 8.4ms
# 98:	learn: 1.2435063	total: 415ms	remaining: 4.19ms
# 99:	learn: 1.2342354	total: 419ms	remaining: 0us
# 0:	learn: 11.4181506	total: 3.51ms	remaining: 348ms
# 1:	learn: 10.7066774	total: 8.1ms	remaining: 397ms
# 2:	learn: 10.1345493	total: 12.2ms	remaining: 395ms
# 3:	learn: 9.5174119	total: 18.7ms	remaining: 449ms
# 4:	learn: 8.9894474	total: 26.3ms	remaining: 499ms
# 5:	learn: 8.5369318	total: 37.5ms	remaining: 588ms
# 6:	learn: 8.1410287	total: 41.7ms	remaining: 554ms
# 7:	learn: 7.7032202	total: 45.2ms	remaining: 519ms
# 8:	learn: 7.2940469	total: 48.6ms	remaining: 492ms
# 9:	learn: 6.9708316	total: 52ms	remaining: 468ms
# 10:	learn: 6.6447825	total: 55.7ms	remaining: 451ms
# 11:	learn: 6.3701360	total: 59.5ms	remaining: 437ms
# 12:	learn: 6.0846037	total: 63.4ms	remaining: 424ms
# 13:	learn: 5.7859816	total: 67.2ms	remaining: 413ms
# 14:	learn: 5.5225770	total: 70.8ms	remaining: 401ms
# 15:	learn: 5.3112145	total: 74.2ms	remaining: 390ms
# 16:	learn: 5.0911303	total: 77.8ms	remaining: 380ms
# 17:	learn: 4.8555598	total: 81.5ms	remaining: 371ms
# 18:	learn: 4.7015779	total: 85.2ms	remaining: 363ms
# 19:	learn: 4.5353605	total: 89.1ms	remaining: 356ms
# 20:	learn: 4.4213148	total: 92.9ms	remaining: 349ms
# 21:	learn: 4.2830971	total: 96.3ms	remaining: 342ms
# 22:	learn: 4.1405617	total: 103ms	remaining: 345ms
# 23:	learn: 4.0340816	total: 107ms	remaining: 338ms
# 24:	learn: 3.9231504	total: 111ms	remaining: 332ms
# 25:	learn: 3.8091908	total: 114ms	remaining: 325ms
# 26:	learn: 3.7093867	total: 118ms	remaining: 320ms
# 27:	learn: 3.5846056	total: 122ms	remaining: 314ms
# 28:	learn: 3.4448638	total: 126ms	remaining: 308ms
# 29:	learn: 3.3436639	total: 129ms	remaining: 302ms
# 30:	learn: 3.2826352	total: 133ms	remaining: 296ms
# 31:	learn: 3.1795774	total: 137ms	remaining: 290ms
# 32:	learn: 3.1064841	total: 140ms	remaining: 285ms
# 33:	learn: 3.0106739	total: 144ms	remaining: 280ms
# 34:	learn: 2.9366715	total: 148ms	remaining: 274ms
# 35:	learn: 2.8669443	total: 151ms	remaining: 269ms
# 36:	learn: 2.8192232	total: 155ms	remaining: 263ms
# 37:	learn: 2.7534041	total: 158ms	remaining: 258ms
# 38:	learn: 2.6827673	total: 162ms	remaining: 253ms
# 39:	learn: 2.6390516	total: 165ms	remaining: 248ms
# 40:	learn: 2.5908817	total: 169ms	remaining: 243ms
# 41:	learn: 2.5354902	total: 173ms	remaining: 238ms
# 42:	learn: 2.5027907	total: 176ms	remaining: 234ms
# 43:	learn: 2.4278013	total: 180ms	remaining: 229ms
# 44:	learn: 2.4041135	total: 183ms	remaining: 224ms
# 45:	learn: 2.3607512	total: 187ms	remaining: 219ms
# 46:	learn: 2.3237059	total: 190ms	remaining: 215ms
# 47:	learn: 2.2828358	total: 195ms	remaining: 211ms
# 48:	learn: 2.2417588	total: 198ms	remaining: 206ms
# 49:	learn: 2.2089302	total: 202ms	remaining: 202ms
# 50:	learn: 2.1722087	total: 206ms	remaining: 198ms
# 51:	learn: 2.1247079	total: 210ms	remaining: 193ms
# 52:	learn: 2.1143350	total: 217ms	remaining: 193ms
# 53:	learn: 2.0783445	total: 228ms	remaining: 195ms
# 54:	learn: 2.0453730	total: 232ms	remaining: 190ms
# 55:	learn: 2.0243811	total: 236ms	remaining: 185ms
# 56:	learn: 2.0011748	total: 239ms	remaining: 180ms
# 57:	learn: 1.9710909	total: 243ms	remaining: 176ms
# 58:	learn: 1.9409631	total: 246ms	remaining: 171ms
# 59:	learn: 1.9237479	total: 250ms	remaining: 167ms
# 60:	learn: 1.9037850	total: 254ms	remaining: 162ms
# 61:	learn: 1.8864462	total: 257ms	remaining: 158ms
# 62:	learn: 1.8713099	total: 261ms	remaining: 153ms
# 63:	learn: 1.8374660	total: 265ms	remaining: 149ms
# 64:	learn: 1.8219547	total: 268ms	remaining: 144ms
# 65:	learn: 1.8072265	total: 272ms	remaining: 140ms
# 66:	learn: 1.7820926	total: 276ms	remaining: 136ms
# 67:	learn: 1.7562645	total: 281ms	remaining: 132ms
# 68:	learn: 1.7257604	total: 286ms	remaining: 128ms
# 69:	learn: 1.7008765	total: 290ms	remaining: 124ms
# 70:	learn: 1.6808291	total: 293ms	remaining: 120ms
# 71:	learn: 1.6540034	total: 297ms	remaining: 115ms
# 72:	learn: 1.6271916	total: 300ms	remaining: 111ms
# 73:	learn: 1.6085341	total: 304ms	remaining: 107ms
# 74:	learn: 1.5965425	total: 307ms	remaining: 102ms
# 75:	learn: 1.5665020	total: 311ms	remaining: 98.2ms
# 76:	learn: 1.5440714	total: 315ms	remaining: 94ms
# 77:	learn: 1.5251415	total: 318ms	remaining: 89.7ms
# 78:	learn: 1.5163922	total: 322ms	remaining: 85.5ms
# 79:	learn: 1.5090727	total: 326ms	remaining: 81.4ms
# 80:	learn: 1.4994800	total: 329ms	remaining: 77.3ms
# 81:	learn: 1.4872233	total: 333ms	remaining: 73.2ms
# 82:	learn: 1.4653922	total: 337ms	remaining: 69ms
# 83:	learn: 1.4443852	total: 341ms	remaining: 64.9ms
# 84:	learn: 1.4380498	total: 344ms	remaining: 60.7ms
# 85:	learn: 1.4312507	total: 348ms	remaining: 56.6ms
# 86:	learn: 1.4155750	total: 352ms	remaining: 52.5ms
# 87:	learn: 1.4117828	total: 355ms	remaining: 48.4ms
# 88:	learn: 1.3968724	total: 359ms	remaining: 44.4ms
# 89:	learn: 1.3776106	total: 363ms	remaining: 40.3ms
# 90:	learn: 1.3724604	total: 366ms	remaining: 36.2ms
# 91:	learn: 1.3594689	total: 370ms	remaining: 32.1ms
# 92:	learn: 1.3422717	total: 373ms	remaining: 28.1ms
# 93:	learn: 1.3221721	total: 377ms	remaining: 24.1ms
# 94:	learn: 1.3087952	total: 381ms	remaining: 20ms
# 95:	learn: 1.2879923	total: 384ms	remaining: 16ms
# 96:	learn: 1.2729858	total: 388ms	remaining: 12ms
# 97:	learn: 1.2617511	total: 391ms	remaining: 7.99ms
# 98:	learn: 1.2435063	total: 395ms	remaining: 3.99ms
# 99:	learn: 1.2342354	total: 399ms	remaining: 0us
# Random Forest: Train R2 Score - 0.9970987679882553, Test R2 Score - 0.9859775228009794, MSE - 1.8874834775924683, MAE - 0.719085693359375
# Decision Tree: Train R2 Score - 1.0, Test R2 Score - 0.25046417335426274, MSE - 100.890625, MAE - 6.869791666666667
# Gradient Boosting: Train R2 Score - 0.9793414626958352, Test R2 Score - 0.8982817827315274, MSE - 13.691693110958461, MAE - 2.5883614624732805
# Linear Regression: Train R2 Score - 0.591967266644972, Test R2 Score - 0.6167764047832125, MSE - 51.58348228555432, MAE - 5.628918144380331
# XGBRegressor: Train R2 Score - 0.9996916989305938, Test R2 Score - 0.9920748532187741, MSE - 1.0667575632145592, MAE - 0.6579587509495468
# CatBoosting Regressor: Train R2 Score - 0.989774009124166, Test R2 Score - 0.9710989874819888, MSE - 3.8901959218196587, MAE - 1.3551970658245738
# AdaBoost Regressor: Train R2 Score - 0.9261231460373656, Test R2 Score - 0.9086284125057179, MSE - 12.298993913065315, MAE - 2.587616806933527
# (0.9920748532187741, 1.0667575632145592, 0.6579587509495468)

# %% [markdown]
# ## **Push to github**

# %%
# !git config --global user.email "ehthanhtruc@gmail.com"
# !git config --global user.name "truc-nmt"

# %%
# !git add 4. Modeling.ipynb

# Commit với một thông điệp
# !git commit -m "Add notebook 4. Modeling - TrucNMT"

# Đẩy lên kho lưu trữ
# !git push origin main:tiki_discount_rate/notebooks
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
